# %% [markdown]
# # GLLVM Longitudinal

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from torch.utils.data import DataLoader, TensorDataset
from GLLVM_longitudinal import LongitudinalGLLVM


# Check if CUDA is available
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("CUDA is available. Using GPU.")
else:
    device = torch.device("cpu")
    print("CUDA is not available. Using CPU.")
# Out:
# CUDA is available. Using GPU.

# %% [markdown]
# A Longitudinal GLLVM is a model with 1 variable per period for T periods, n observations, and p responses, and k covariates. We also have a random effect for each observation x response.

# %%
n = 1000
p = 13
q = 1
k = 3
T = 10

DIMENSIONS_Y = (n, T, p) 
DIMENSIONS_X = (n, T, k)
DIMENSIONS_Z = (n, T, q)
DIMENSIONS_U = (n, 1, p)
response_types = {
    'binary': [0,1,2,3,4,5,6,7, 9, 10],
    'counts': [8, 11, 12]
}

# %% [markdown]
# They can be of many response types. Here for the sake of illutration we will consider 3 response types: gaussian, binary, and poisson.
#
# We allow for transformation of the data, which we account for in the estimation. In particular, Poisson data may be numerically problematic because their conditional expectation is the exponential of the linear predictor. Small differences in the latter can result in dramatic differences in the gradient. For instance, we can transform poisson with the following function $x \rightarrow \log(x+1)$. This transforms is needed in 2 places: for encoding, and at the loss function for computing the gradient.
#
# ## Computing the scale parameter
#
# The scale parameter is computed in a second step (on the fit residual). They are updated at every iteration. This is not yet implemented.
#
#
# ### Modules
#
# We need LongitudinalGLLVM as the overarching module, Sample which samples the data and takes additional arguments (such as nuisance parameters), Decoder which contains all the parameters of interest, and Encoder which encodes the data using a Neural Network.
#
# ### Design of the Encoder
# Since the estimation problem for Z is the same at each time step, we model the encoder using a RNN. At each time step, the same encoder is used to compute the Z. At the same time, the hidden state of the RNN is used to predict the U variable, which is constant over time for each observation.
#
# ### Accounting for missing values
# Missing values are simply imputed every period by their (conditional) mean.

# %%
model_true = LongitudinalGLLVM(num_var=p, num_latent=q, num_covar=k, num_period=T, response_types=response_types).to(device)

# %%
data_sample = model_true.sample(x=None, n=n)

# %%
# adding missing data
probability_missing = 0.4
mask = torch.rand_like(data_sample['y']).to(device) < probability_missing
data_sample['y'][mask] = 0.5

# %%
model = LongitudinalGLLVM(num_var=p, num_latent=q, num_covar=k, num_period=T, response_types=response_types).to(device)

# %%
fit = model.fit(x=data_sample['x'], y=data_sample['y'], mask=mask, epochs=100, lr_model=0.1, lr_encoder=0.01)
# Out:
# var_u: Parameter containing:
# tensor([0.9997], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7410], device='cuda:0', requires_grad=True)
#
# Epoch 1/100, loss_fit = 60707.50, encoder_loss = 1.40.
# var_u: Parameter containing:
# tensor([0.9779], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7092], device='cuda:0', requires_grad=True)
#
# Epoch 2/100, loss_fit = 60322.59, encoder_loss = 1.24.
# var_u: Parameter containing:
# tensor([0.9835], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.6710], device='cuda:0', requires_grad=True)
#
# Epoch 3/100, loss_fit = 60066.06, encoder_loss = 1.09.
# var_u: Parameter containing:
# tensor([0.9976], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.6549], device='cuda:0', requires_grad=True)
#
# Epoch 4/100, loss_fit = 57648.86, encoder_loss = 1.02.
# var_u: Parameter containing:
# tensor([1.0089], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.6335], device='cuda:0', requires_grad=True)
#
# Epoch 5/100, loss_fit = 55865.38, encoder_loss = 0.98.
# var_u: Parameter containing:
# tensor([1.0262], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.6273], device='cuda:0', requires_grad=True)
#
# Epoch 6/100, loss_fit = 48950.29, encoder_loss = 0.92.
# var_u: Parameter containing:
# tensor([1.0478], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.6306], device='cuda:0', requires_grad=True)
#
# Epoch 7/100, loss_fit = 39074.67, encoder_loss = 0.93.
# var_u: Parameter containing:
# tensor([1.0673], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.6289], device='cuda:0', requires_grad=True)
#
# Epoch 8/100, loss_fit = 43837.42, encoder_loss = 0.97.
# var_u: Parameter containing:
# tensor([1.0882], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.6401], device='cuda:0', requires_grad=True)
#
# Epoch 9/100, loss_fit = 37264.41, encoder_loss = 0.93.
# var_u: Parameter containing:
# tensor([1.0962], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.6487], device='cuda:0', requires_grad=True)
#
# Epoch 10/100, loss_fit = 41250.30, encoder_loss = 0.96.
# var_u: Parameter containing:
# tensor([1.1203], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.6625], device='cuda:0', requires_grad=True)
#
# Epoch 11/100, loss_fit = 40506.55, encoder_loss = 0.89.
# var_u: Parameter containing:
# tensor([1.1243], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.6754], device='cuda:0', requires_grad=True)
#
# Epoch 12/100, loss_fit = 37599.20, encoder_loss = 0.90.
# var_u: Parameter containing:
# tensor([1.1380], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.6882], device='cuda:0', requires_grad=True)
#
# Epoch 13/100, loss_fit = 26129.89, encoder_loss = 0.81.
# var_u: Parameter containing:
# tensor([1.1508], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.6946], device='cuda:0', requires_grad=True)
#
# Epoch 14/100, loss_fit = 31361.12, encoder_loss = 0.85.
# var_u: Parameter containing:
# tensor([1.1604], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7031], device='cuda:0', requires_grad=True)
#
# Epoch 15/100, loss_fit = 32550.20, encoder_loss = 0.86.
# var_u: Parameter containing:
# tensor([1.1667], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7120], device='cuda:0', requires_grad=True)
#
# Epoch 16/100, loss_fit = 31409.63, encoder_loss = 0.82.
# var_u: Parameter containing:
# tensor([1.1643], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7214], device='cuda:0', requires_grad=True)
#
# Epoch 17/100, loss_fit = 19198.35, encoder_loss = 0.83.
# var_u: Parameter containing:
# tensor([1.1663], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7298], device='cuda:0', requires_grad=True)
#
# Epoch 18/100, loss_fit = 43987.81, encoder_loss = 0.77.
# var_u: Parameter containing:
# tensor([1.1716], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7403], device='cuda:0', requires_grad=True)
#
# Epoch 19/100, loss_fit = 36851.07, encoder_loss = 0.80.
# var_u: Parameter containing:
# tensor([1.1734], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7509], device='cuda:0', requires_grad=True)
#
# Epoch 20/100, loss_fit = 37667.00, encoder_loss = 0.75.
# var_u: Parameter containing:
# tensor([1.1758], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7602], device='cuda:0', requires_grad=True)
#
# Epoch 21/100, loss_fit = 26487.22, encoder_loss = 0.79.
# var_u: Parameter containing:
# tensor([1.1766], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7678], device='cuda:0', requires_grad=True)
#
# Epoch 22/100, loss_fit = 16556.75, encoder_loss = 0.82.
# var_u: Parameter containing:
# tensor([1.1831], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7706], device='cuda:0', requires_grad=True)
#
# Epoch 23/100, loss_fit = 25046.10, encoder_loss = 0.78.
# var_u: Parameter containing:
# tensor([1.1923], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7758], device='cuda:0', requires_grad=True)
#
# Epoch 24/100, loss_fit = 25352.38, encoder_loss = 0.79.
# var_u: Parameter containing:
# tensor([1.1914], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7801], device='cuda:0', requires_grad=True)
#
# Epoch 25/100, loss_fit = 22471.59, encoder_loss = 0.78.
# var_u: Parameter containing:
# tensor([1.1931], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7813], device='cuda:0', requires_grad=True)
#
# Epoch 26/100, loss_fit = 27439.04, encoder_loss = 0.77.
# var_u: Parameter containing:
# tensor([1.1977], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7798], device='cuda:0', requires_grad=True)
#
# Epoch 27/100, loss_fit = 31233.68, encoder_loss = 0.78.
# var_u: Parameter containing:
# tensor([1.2019], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7844], device='cuda:0', requires_grad=True)
#
# Epoch 28/100, loss_fit = 28031.38, encoder_loss = 0.74.
# var_u: Parameter containing:
# tensor([1.1964], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7870], device='cuda:0', requires_grad=True)
#
# Epoch 29/100, loss_fit = 29858.04, encoder_loss = 0.77.
# var_u: Parameter containing:
# tensor([1.1931], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7898], device='cuda:0', requires_grad=True)
#
# Epoch 30/100, loss_fit = 33121.32, encoder_loss = 0.73.
# var_u: Parameter containing:
# tensor([1.1829], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7932], device='cuda:0', requires_grad=True)
#
# Epoch 31/100, loss_fit = 32582.62, encoder_loss = 0.76.
# var_u: Parameter containing:
# tensor([1.1757], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7941], device='cuda:0', requires_grad=True)
#
# Epoch 32/100, loss_fit = 22170.10, encoder_loss = 0.79.
# var_u: Parameter containing:
# tensor([1.1623], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7956], device='cuda:0', requires_grad=True)
#
# Epoch 33/100, loss_fit = 9573.44, encoder_loss = 0.83.
# var_u: Parameter containing:
# tensor([1.1535], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7951], device='cuda:0', requires_grad=True)
#
# Epoch 34/100, loss_fit = 18441.08, encoder_loss = 0.79.
# var_u: Parameter containing:
# tensor([1.1489], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7939], device='cuda:0', requires_grad=True)
#
# Epoch 35/100, loss_fit = 18890.12, encoder_loss = 0.80.
# var_u: Parameter containing:
# tensor([1.1359], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7973], device='cuda:0', requires_grad=True)
#
# Epoch 36/100, loss_fit = 24227.96, encoder_loss = 0.78.
# var_u: Parameter containing:
# tensor([1.1303], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8007], device='cuda:0', requires_grad=True)
#
# Epoch 37/100, loss_fit = 26599.03, encoder_loss = 0.74.
# var_u: Parameter containing:
# tensor([1.1181], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8003], device='cuda:0', requires_grad=True)
#
# Epoch 38/100, loss_fit = 25024.09, encoder_loss = 0.71.
# var_u: Parameter containing:
# tensor([1.1105], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8032], device='cuda:0', requires_grad=True)
#
# Epoch 39/100, loss_fit = 25685.12, encoder_loss = 0.79.
# var_u: Parameter containing:
# tensor([1.0998], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8014], device='cuda:0', requires_grad=True)
#
# Epoch 40/100, loss_fit = 16141.69, encoder_loss = 0.73.
# var_u: Parameter containing:
# tensor([1.0910], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7997], device='cuda:0', requires_grad=True)
#
# Epoch 41/100, loss_fit = 16184.14, encoder_loss = 0.71.
# var_u: Parameter containing:
# tensor([1.0841], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7977], device='cuda:0', requires_grad=True)
#
# Epoch 42/100, loss_fit = 12809.72, encoder_loss = 0.69.
# var_u: Parameter containing:
# tensor([1.0730], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7963], device='cuda:0', requires_grad=True)
#
# Epoch 43/100, loss_fit = 18212.71, encoder_loss = 0.71.
# var_u: Parameter containing:
# tensor([1.0672], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7983], device='cuda:0', requires_grad=True)
#
# Epoch 44/100, loss_fit = 17633.05, encoder_loss = 0.68.
# var_u: Parameter containing:
# tensor([1.0589], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7977], device='cuda:0', requires_grad=True)
#
# Epoch 45/100, loss_fit = 27508.21, encoder_loss = 0.67.
# var_u: Parameter containing:
# tensor([1.0542], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7970], device='cuda:0', requires_grad=True)
#
# Epoch 46/100, loss_fit = 18094.78, encoder_loss = 0.75.
# var_u: Parameter containing:
# tensor([1.0504], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7994], device='cuda:0', requires_grad=True)
#
# Epoch 47/100, loss_fit = 22298.38, encoder_loss = 0.67.
# var_u: Parameter containing:
# tensor([1.0453], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7978], device='cuda:0', requires_grad=True)
#
# Epoch 48/100, loss_fit = 17859.09, encoder_loss = 0.66.
# var_u: Parameter containing:
# tensor([1.0398], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7964], device='cuda:0', requires_grad=True)
#
# Epoch 49/100, loss_fit = 11743.20, encoder_loss = 0.66.
# var_u: Parameter containing:
# tensor([1.0357], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8009], device='cuda:0', requires_grad=True)
#
# Epoch 50/100, loss_fit = 17801.43, encoder_loss = 0.66.
# var_u: Parameter containing:
# tensor([1.0312], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8025], device='cuda:0', requires_grad=True)
#
# Epoch 51/100, loss_fit = 19439.70, encoder_loss = 0.62.
# var_u: Parameter containing:
# tensor([1.0262], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7991], device='cuda:0', requires_grad=True)
#
# Epoch 52/100, loss_fit = 26361.52, encoder_loss = 0.62.
# var_u: Parameter containing:
# tensor([1.0208], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8012], device='cuda:0', requires_grad=True)
#
# Epoch 53/100, loss_fit = 23835.37, encoder_loss = 0.66.
# var_u: Parameter containing:
# tensor([1.0173], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7988], device='cuda:0', requires_grad=True)
#
# Epoch 54/100, loss_fit = 16407.68, encoder_loss = 0.70.
# var_u: Parameter containing:
# tensor([1.0139], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7939], device='cuda:0', requires_grad=True)
#
# Epoch 55/100, loss_fit = 19807.54, encoder_loss = 0.65.
# var_u: Parameter containing:
# tensor([1.0111], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7898], device='cuda:0', requires_grad=True)
#
# Epoch 56/100, loss_fit = 22525.59, encoder_loss = 0.64.
# var_u: Parameter containing:
# tensor([1.0104], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7878], device='cuda:0', requires_grad=True)
#
# Epoch 57/100, loss_fit = 21029.21, encoder_loss = 0.64.
# var_u: Parameter containing:
# tensor([1.0072], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7859], device='cuda:0', requires_grad=True)
#
# Epoch 58/100, loss_fit = 11185.36, encoder_loss = 0.64.
# var_u: Parameter containing:
# tensor([1.0060], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7931], device='cuda:0', requires_grad=True)
#
# Epoch 59/100, loss_fit = 19803.69, encoder_loss = 0.63.
# var_u: Parameter containing:
# tensor([1.0021], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7936], device='cuda:0', requires_grad=True)
#
# Epoch 60/100, loss_fit = 9748.68, encoder_loss = 0.66.
# var_u: Parameter containing:
# tensor([1.0043], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7955], device='cuda:0', requires_grad=True)
#
# Epoch 61/100, loss_fit = 31370.41, encoder_loss = 0.64.
# var_u: Parameter containing:
# tensor([1.0021], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7986], device='cuda:0', requires_grad=True)
#
# Epoch 62/100, loss_fit = 8455.43, encoder_loss = 0.62.
# var_u: Parameter containing:
# tensor([1.0028], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7989], device='cuda:0', requires_grad=True)
#
# Epoch 63/100, loss_fit = 6584.25, encoder_loss = 0.64.
# var_u: Parameter containing:
# tensor([1.0040], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7972], device='cuda:0', requires_grad=True)
#
# Epoch 64/100, loss_fit = 11147.87, encoder_loss = 0.64.
# var_u: Parameter containing:
# tensor([1.0052], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7980], device='cuda:0', requires_grad=True)
#
# Epoch 65/100, loss_fit = 8515.14, encoder_loss = 0.61.
# var_u: Parameter containing:
# tensor([0.9988], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8003], device='cuda:0', requires_grad=True)
#
# Epoch 66/100, loss_fit = 7514.00, encoder_loss = 0.63.
# var_u: Parameter containing:
# tensor([0.9919], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8013], device='cuda:0', requires_grad=True)
#
# Epoch 67/100, loss_fit = 11389.54, encoder_loss = 0.65.
# var_u: Parameter containing:
# tensor([0.9915], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8031], device='cuda:0', requires_grad=True)
#
# Epoch 68/100, loss_fit = 8465.33, encoder_loss = 0.68.
# var_u: Parameter containing:
# tensor([0.9906], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8033], device='cuda:0', requires_grad=True)
#
# Epoch 69/100, loss_fit = 12157.58, encoder_loss = 0.60.
# var_u: Parameter containing:
# tensor([0.9882], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8082], device='cuda:0', requires_grad=True)
#
# Epoch 70/100, loss_fit = 14819.81, encoder_loss = 0.59.
# var_u: Parameter containing:
# tensor([0.9896], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8063], device='cuda:0', requires_grad=True)
#
# Epoch 71/100, loss_fit = 16432.53, encoder_loss = 0.59.
# var_u: Parameter containing:
# tensor([0.9895], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8017], device='cuda:0', requires_grad=True)
#
# Epoch 72/100, loss_fit = 17447.09, encoder_loss = 0.62.
# var_u: Parameter containing:
# tensor([0.9952], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8015], device='cuda:0', requires_grad=True)
#
# Epoch 73/100, loss_fit = 27846.43, encoder_loss = 0.57.
# var_u: Parameter containing:
# tensor([0.9976], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8017], device='cuda:0', requires_grad=True)
#
# Epoch 74/100, loss_fit = 22196.83, encoder_loss = 0.60.
# var_u: Parameter containing:
# tensor([0.9951], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7977], device='cuda:0', requires_grad=True)
#
# Epoch 75/100, loss_fit = 22712.16, encoder_loss = 0.58.
# var_u: Parameter containing:
# tensor([0.9934], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7969], device='cuda:0', requires_grad=True)
#
# Epoch 76/100, loss_fit = 15325.75, encoder_loss = 0.65.
# var_u: Parameter containing:
# tensor([0.9900], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7939], device='cuda:0', requires_grad=True)
#
# Epoch 77/100, loss_fit = 15283.67, encoder_loss = 0.61.
# var_u: Parameter containing:
# tensor([0.9833], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7951], device='cuda:0', requires_grad=True)
#
# Epoch 78/100, loss_fit = 12124.22, encoder_loss = 0.63.
# var_u: Parameter containing:
# tensor([0.9820], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7938], device='cuda:0', requires_grad=True)
#
# Epoch 79/100, loss_fit = 9826.75, encoder_loss = 0.58.
# var_u: Parameter containing:
# tensor([0.9793], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7977], device='cuda:0', requires_grad=True)
#
# Epoch 80/100, loss_fit = 13805.65, encoder_loss = 0.59.
# var_u: Parameter containing:
# tensor([0.9749], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7958], device='cuda:0', requires_grad=True)
#
# Epoch 81/100, loss_fit = 16204.71, encoder_loss = 0.57.
# var_u: Parameter containing:
# tensor([0.9766], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7968], device='cuda:0', requires_grad=True)
#
# Epoch 82/100, loss_fit = 15181.68, encoder_loss = 0.59.
# var_u: Parameter containing:
# tensor([0.9747], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7953], device='cuda:0', requires_grad=True)
#
# Epoch 83/100, loss_fit = 9748.38, encoder_loss = 0.58.
# var_u: Parameter containing:
# tensor([0.9742], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7937], device='cuda:0', requires_grad=True)
#
# Epoch 84/100, loss_fit = 12686.61, encoder_loss = 0.57.
# var_u: Parameter containing:
# tensor([0.9744], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7991], device='cuda:0', requires_grad=True)
#
# Epoch 85/100, loss_fit = 6257.42, encoder_loss = 0.58.
# var_u: Parameter containing:
# tensor([0.9758], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7986], device='cuda:0', requires_grad=True)
#
# Epoch 86/100, loss_fit = 14400.66, encoder_loss = 0.58.
# var_u: Parameter containing:
# tensor([0.9757], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7993], device='cuda:0', requires_grad=True)
#
# Epoch 87/100, loss_fit = 13040.53, encoder_loss = 0.59.
# var_u: Parameter containing:
# tensor([0.9741], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7976], device='cuda:0', requires_grad=True)
#
# Epoch 88/100, loss_fit = 9194.45, encoder_loss = 0.58.
# var_u: Parameter containing:
# tensor([0.9701], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7996], device='cuda:0', requires_grad=True)
#
# Epoch 89/100, loss_fit = 9832.86, encoder_loss = 0.59.
# var_u: Parameter containing:
# tensor([0.9657], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8008], device='cuda:0', requires_grad=True)
#
# Epoch 90/100, loss_fit = 16315.57, encoder_loss = 0.59.
# var_u: Parameter containing:
# tensor([0.9630], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8018], device='cuda:0', requires_grad=True)
#
# Epoch 91/100, loss_fit = 6536.68, encoder_loss = 0.60.
# var_u: Parameter containing:
# tensor([0.9613], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8009], device='cuda:0', requires_grad=True)
#
# Epoch 92/100, loss_fit = 12710.52, encoder_loss = 0.58.
# var_u: Parameter containing:
# tensor([0.9600], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7990], device='cuda:0', requires_grad=True)
#
# Epoch 93/100, loss_fit = 10088.46, encoder_loss = 0.58.
# var_u: Parameter containing:
# tensor([0.9602], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7955], device='cuda:0', requires_grad=True)
#
# Epoch 94/100, loss_fit = 10405.83, encoder_loss = 0.59.
# var_u: Parameter containing:
# tensor([0.9636], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7921], device='cuda:0', requires_grad=True)
#
# Epoch 95/100, loss_fit = 11939.44, encoder_loss = 0.58.
# var_u: Parameter containing:
# tensor([0.9677], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7927], device='cuda:0', requires_grad=True)
#
# Epoch 96/100, loss_fit = 10071.92, encoder_loss = 0.58.
# var_u: Parameter containing:
# tensor([0.9693], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7950], device='cuda:0', requires_grad=True)
#
# Epoch 97/100, loss_fit = 9361.92, encoder_loss = 0.57.
# var_u: Parameter containing:
# tensor([0.9688], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8010], device='cuda:0', requires_grad=True)
#
# Epoch 98/100, loss_fit = 7862.48, encoder_loss = 0.58.
# var_u: Parameter containing:
# tensor([0.9711], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.8008], device='cuda:0', requires_grad=True)
#
# Epoch 99/100, loss_fit = 7413.55, encoder_loss = 0.57.
# var_u: Parameter containing:
# tensor([0.9726], device='cuda:0', requires_grad=True), phi: Parameter containing:
# tensor([0.7976], device='cuda:0', requires_grad=True)
#
# Epoch 100/100, loss_fit = 6324.57, encoder_loss = 0.57.

# %%
plt.plot(fit['learning_rates'])
plt.plot(fit['learning_rates_encoder'])

# %%
data = np.stack([tensor.flatten().cpu().numpy() for tensor in fit['loading_values']], axis=0)

# Create figure and axes
fig, ax = plt.subplots()

# Loop through each feature
for i in range(data.shape[1]):
    ax.plot(data[:, i])

# Add legend and labels
ax.legend()
plt.xlabel('Time period')
plt.ylabel('Feature value')
plt.title('Evolution of features over time')

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data = np.stack([tensor.flatten().cpu().numpy() for tensor in fit['coef_values']], axis=0)

# Create figure and axes
fig, ax = plt.subplots()

# Loop through each feature
for i in range(data.shape[1]):
    ax.plot(data[:, i])

# Add legend and labels
ax.legend()
plt.xlabel('Time period')
plt.ylabel('Feature value')
plt.title('Evolution of features over time')

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data = np.stack([tensor.flatten().cpu().numpy() for tensor in fit['intercept_values']], axis=0)

# Create figure and axes
fig, ax = plt.subplots()

# Loop through each feature
for i in range(data.shape[1]):
    ax.plot(data[:, i])

# Add legend and labels
ax.legend()
plt.xlabel('Time period')
plt.ylabel('Feature value')
plt.title('Evolution of features over time')

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(model_true.decoder.wz.detach().cpu().numpy(), model.decoder.wz.detach().cpu().numpy())
plt.plot([-3,3], [-3,3], color="red")
plt.plot([-3,3], [3,-3], color="red")
plt.show()

plt.scatter(model_true.decoder.wx.detach().cpu().numpy(), model.decoder.wx.detach().cpu().numpy())
plt.plot([-3,3], [-3,3], color="red")
plt.plot([-3,3], [3,-3], color="red")
plt.show()

# %%
dat1 = torch.reshape(model_true.sample(x=data_sample['x'])['y'].detach().cpu(), (data_sample['y'].shape[0], -1))
cor1 = np.corrcoef(dat1, rowvar=False)
dat2 = torch.reshape(model.sample(x=data_sample['x'])['y'].detach().cpu(), (data_sample['y'].shape[0], -1))
cor2 = np.corrcoef(dat2, rowvar=False)

plt.scatter(cor1, cor2)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cor1, annot=False, fmt='g')
plt.show()
plt.figure(figsize=(10,10))
sns.heatmap(cor2, annot=False, fmt='g')
plt.show()

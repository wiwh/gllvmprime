# %% [markdown]
# # GLLVM Longitudinal

# %%
import torch
from torch import nn
from torch.optim.lr_scheduler import StepLR # scheduler
import numpy as np
import seaborn as sns
import math
import matplotlib.pyplot as plt
import copy

# %% [markdown]
# A Longitudinal GLLVM is a model with 1 variable per period for T periods, n observations, and p responses, and k covariates. We also have a random effect for each observation x response.

# %%
n = 1000
p = 13
q = 1
k = 3
T = 9

DIMENSIONS_Y = (n, T, p) 
DIMENSIONS_X = (n, T, k)
DIMENSIONS_Z = (n, T, q)
DIMENSIONS_U = (n, 1, p)

# %%
response_types = {
    'binary': [0,1,2,3,4,5,6,7],
    'ordinal': [9, 10],
    'counts': [8, 11, 12]
}

response_types = {
    'binary': [0,1,2,3,4,5,6,7, 9, 10],
    'counts': [8, 11, 12]
}

link = {
    'binary' : lambda x: torch.logit(x),
    'ordinal': lambda x: torch.logit(x),
    'counts': lambda x: torch.log(x)
}


linkinv = {
    'binary': lambda x: 1/(1+torch.exp(-x)),
    'ordinal': lambda x: 1/(1+torch.exp(-x)),
    'counts': lambda x: torch.exp(x)
}

response_transform = {
    'binary' : lambda x: 2*x - 1,
    'ordinal': lambda x: 2*x - 1,
    'counts': lambda x: torch.log(x+1)
}

# %% [markdown]
# They can be of many response types. Here for the sake of illutration we will consider 3 response types: gaussian, binary, and poisson.
#
# We allow for transformation of the data, which we account for in the estimation. In particular, Poisson data may be numerically problematic because their conditional expectation is the exponential of the linear predictor. Small differences in the latter can result in dramatic differences in the gradient. For instance, we can transform poisson with the following function $x \rightarrow \log(x+1)$. This transforms is needed in 2 places: for encoding, and at the loss function for computing the gradient.
#
# ## Computing the scale parameter
#
# The scale parameter is computed in a second step (on the fit residual). They are updated at every iteration. This is not yet implemented.
#
#
# ### Modules
#
# We need LongitudinalGLLVM as the overarching module, Sample which samples the data and takes additional arguments (such as nuisance parameters), Decoder which contains all the parameters of interest, and Encoder which encodes the data using a Neural Network.
#
# ### Design of the Encoder
# Since the estimation problem for Z is the same at each time step, we model the encoder using a RNN. At each time step, the same encoder is used to compute the Z. At the same time, the hidden state of the RNN is used to predict the U variable, which is constant over time for each observation.

# %%
class LongitudinalGLLVM(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
        self.sample = Sample(self.decoder)
    
    def plot_cov(self, what="linpar", x=None):
        data_sample = self.sample(x=x)
        data =  data_sample[what].detach().view(n, -1).numpy()
        cov_matrix = np.cov(data, rowvar=False)

        plt.figure(figsize=(10,10))
        sns.heatmap(cov_matrix, annot=False, fmt='g')
        plt.show()
    
    def impute(self, x, y, mask, nsteps=10):
        """ Impute the missing values provided by the mask (True is missing) and return x imputed"""
        for _ in range(nsteps):
            z, u = self.encoder(x,y, transform_response = True)
            _, mean = self.decoder(x,z,u)
            y[mask] = mean[mask]
        return y

class Sample(nn.Module):
    def __init__(self, decoder):
        super().__init__()
        self.decoder = decoder
        self.phi = torch.ones(1) * 0.1
        self.var_u = torch.ones(1) * 1.0

    # sampling comes here
    
    def forward(self, x):
        with torch.no_grad():
            if x is None:
                Warning("x was set to None for sampling. X is usually fixed. Are you sure you want to sample x?")
                x = torch.randn((n, T, k))

            u = torch.randn((n, 1, p)) * torch.sqrt(self.var_u)
            d = torch.randn((n, T, q))
            z = self.AR(d)

            linpar, mean = self.decoder(x, z, u) # decoder gives the expectation

            y = self.sample_response(mean)

            return {"x":x, "y":y, "z":z, "u":u, "linpar":linpar, "mean":mean}

    def sample_response(self, mean):
            y = torch.zeros_like(mean)
            for response_type, response_id in response_types.items():
                if response_type == "binary":
                    y[:,:,response_id] = torch.bernoulli(mean[:,:,response_id])
                elif response_type == "ordinal":
                    cum_probs = mean[:,:,response_id]
                    # draw one uniform for the whole vector
                    random = torch.rand((*cum_probs.shape[0:2], 1)) 
                    # compare with the cumulative probabilities
                    ordinal = torch.sum(random > cum_probs, dim=2)
                    ordinal = torch.nn.functional.one_hot(ordinal).squeeze().float()
                    ordinal = ordinal[:,:,1:] # discard the first column of the one_hot encoding, as it is superfluous (as a 0)
                    y[:,:,response_id] = ordinal
                elif response_type == "counts":
                    y[:,:,response_id] = torch.poisson(mean[:,:,response_id])
            return y

    def AR(self, d):
        z = d.clone()

        for t in range(1, z.shape[1]):
            z[:,t] = z[:,t] + z[:, t-1].clone() * self.phi  # we need to clone else the gradient wants to pass through it
        return z
                
    
class Decoder(nn.Module):
    # Yields the expectation
    def __init__(self):
        super().__init__()

        # decoder part (our parameters of interest)
        self.wz = nn.Parameter(torch.randn((q, p)))
        self.wx = nn.Parameter(torch.randn((1, k, p))) # Measurement invariance!
        self.bias = nn.Parameter(torch.zeros((1, 1, p))) # Measurement invariance!

    # decoding (computing the conditional mean)
    def forward(self, x, z, u):

        xwx = (x.unsqueeze(2) @ self.wx).squeeze() # see section "details of tensorproducts"
        zwz = (z.unsqueeze(2) @ self.wz).squeeze()
        # for the ordinal variables:
        linpar = self.bias + xwx + zwz + u 

        # Apply the inverse link to get the conditional expectation
        mean  = torch.zeros_like(linpar)
        for response_type, response_id in response_types.items():
            mean[:,:,response_id] = linkinv[response_type](linpar[:,:,response_id])
        # Transform the 
        return linpar, mean



class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        # encoder part
        # input dimension is (p+k) (responses + covariates)
        # output dimension is q+p (one latent )
        input_size = p + k
        hidden_size = (p + q) * 5
        self.rnn = nn.RNN(input_size = input_size, hidden_size = hidden_size, batch_first=True)
        
        self.fc = nn.Sequential(
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
        )
        # fully connected layers for Z and U
        self.fc_Z = nn.Sequential(
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = q),
        )

        self.fc_U = nn.Sequential(
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features=hidden_size, out_features = p)
        )

        self.optimizer =  torch.optim.Adam(self.parameters(), lr=.01)
        self.scheduler = StepLR(self.optimizer, step_size=100, gamma=.95)
        self.loss = nn.MSELoss()

    
    def forward(self, x, y, transform_response = False):
        # Initialize hidden state

        # pass the input through the RNN
        if transform_response:
            y_transformed = torch.zeros_like(y)
            with torch.no_grad():
                for response_type, response_id in response_types.items():
                    y_transformed[:,:,response_id] = response_transform[response_type](y[:,:,response_id])
        else:
            y_transformed = y

        xy = torch.cat([x, y_transformed], dim=2)
        rnn_out, _ = self.rnn(xy)
        out = self.fc(rnn_out)
        z_pred = self.fc_Z(out)
        u_pred = self.fc_U(out[:, -1, :]).unsqueeze(1)
        return z_pred, u_pred
    
    def fit(self, x, y, z, u, epochs = 100, verbose = False):
        y = y.clone()
        with torch.no_grad():
            for response_type, response_id in response_types.items():
                y[:,:,response_id] = response_transform[response_type](y[:,:,response_id])
        # Fit the encoder
        for epoch in range(epochs):
            self.optimizer.zero_grad()

            z_pred, u_pred = self(x, y, transform_response = False)

            loss = self.loss(z_pred, z) + self.loss(u_pred, u)

            if verbose:
                print(f"\nEpoch {epoch}/{epochs}, loss={loss}")
            loss.backward()
            self.optimizer.step()
            self.scheduler.step()

        return loss
    
    def plot(self, x, y, z, u):
        with torch.no_grad():
            z_pred, u_pred = self(x, y, transform_response = True)

        fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,4))

        ax1.scatter(z, z_pred)
        ax1.set_xlabel('Z True')
        ax1.set_ylabel('Z Pred')
        ax1.set_title('Encoded values of Z')
        ax1.plot(ax1.get_xlim(), ax1.get_ylim(), ls="--", color="red")

        ax2.scatter(u, u_pred)
        ax2.set_xlabel('U True')
        ax2.set_ylabel('U Pred')
        ax2.set_title('Encoded values of U')
        ax2.plot(ax2.get_xlim(), ax2.get_ylim(), ls="--", color="red")


        plt.show()
        


class MELoss(nn.Module):
    def __init__(self):
        super().__init__()
    
    def forward(self, y, linpar, ys, linpars):
        """Computes the loss. hat is recontructed y, ys is simulated"""
        y_transformed = torch.zeros_like(y)
        ys_transformed = torch.zeros_like(ys)
        with torch.no_grad():
            for response_type, response_id in response_types.items():
                y_transformed[:,:,response_id] = response_transform[response_type](y[:,:,response_id])
                ys_transformed[:,:,response_id] = response_transform[response_type](ys[:,:,response_id])


        return -torch.mean(y_transformed* linpar - ys_transformed * linpars) * y.shape[1] * y.shape[2]
        # return torch.mean(torch.pow(y-linpar, 2) - torch.pow(ys - linpars, 2))
        # loss = torch.mean(y.T @ linpar - ys.T @linpars)/y.shape[0]
        # return loss

# %%
model_sample = LongitudinalGLLVM()

# %%
model_sample.plot_cov("linpar", x=None)

# %%
data_sample = model_sample.sample(x = None)

# %%
model_sample.encoder.fit(data_sample['x'], data_sample['y'], data_sample['z'], data_sample['u'], epochs = 1, verbose=True)
# Out:
# Epoch 0/1, loss=2.0127792358398438
# tensor(2.0128, grad_fn=<AddBackward0>)

# %%
data_example = model_sample.sample(x=data_sample['x'])
model_sample.encoder.plot(data_sample['x'], data_sample['y'], data_sample['z'], data_sample['u'])
model_sample.encoder.plot(data_example['x'], data_example['y'], data_example['z'], data_example['u'])

# %%
model = LongitudinalGLLVM()
criterion = MELoss()
optimizer = torch.optim.Adam(model.decoder.parameters(), lr=.1)
scheduler = StepLR(optimizer, step_size=10, gamma=.95)
mseLoss = nn.MSELoss()
epochs = 100

 # TODO: FIGURE OUT THE PROBLEM WITH IMPUTATION
 # VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
mask = torch.rand_like(data_sample['y']) < .8
data_sample['y'][mask] = 0.5
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# --------------------------------------------------------

def compute_autocorr(z):
    lagged_data = z[:,:-1, 0]
    shifted_data = z[:,1:, 0]
    autocorr = torch.mean(torch.sum(lagged_data * shifted_data, dim=1) / torch.sum(shifted_data ** 2, dim=1))
    return autocorr

# %%
losses = []
learning_rates = []
learning_rates_encoder = []
param_values = []

for epoch in range(1, epochs +1):
    optimizer.zero_grad()

    # impute and sample
    with torch.no_grad():
        # data_true["y"] = model.impute(data_true["x"], data_true["y"], mask=mask["y"], nsteps=5)
        # simulate data from the current parameter values, Unconditionally (!)
        data_sim = model.sample(x=data_sample["x"])
        data_sim['y'][mask] = 0.5
        
        assert torch.eq(data_sim["x"], data_sample["x"]).all().item()

        # compute the imputing values without the gradients
        zhat_sample, uhat_sample = model.encoder(data_sample["x"], data_sample["y"], transform_response=True)
        zhat_sim, uhat_sim = model.encoder(data_sim["x"], data_sim["y"], transform_response=True)


    # train the encoder on the simulated data
    encoder_loss = model.encoder.fit(data_sim["x"], data_sim["y"], data_sim["z"], data_sim["u"],  epochs= 5) 
    
    # compute the decoded value
    linpar_sample, mean_sample = model.decoder(data_sample["x"], zhat_sample, uhat_sample)
    linpar_sim, mean_sim = model.decoder(data_sim["x"], zhat_sim, uhat_sim)

    # # impute values
    # data_sample["y"] = model.impute(data_sample["x"], data_sample["y"], mask, nsteps=2)
    # data_sim["y"] = model.impute(data_sim["x"], data_sim["y"], mask, nsteps=2)

    # model.decoder.wz.grad = mygrad
    loss = criterion(data_sample["y"], linpar_sample,  data_sim["y"], linpar_sim)
    loss.backward()

    # Update nuisance parameters
    with torch.no_grad():
        model.sample.var_u = .95* model.sample.var_u + .05 * torch.var(uhat_sample) * (model.sample.var_u / torch.var(uhat_sim))
        model.sample.phi = .95 * model.sample.phi + .05 * compute_autocorr(zhat_sample) * model.sample.phi / compute_autocorr(zhat_sim)
        if model.sample.phi > .9:
            model.sample.phi = torch.ones(1) * .9 
        # model.sample.phi = zhat_sample[:,1:,:] - zhat_sample[:,:-1,:]
        print(f'var_u: {model.sample.var_u}, phi: {model.sample.phi}')

    # Comparison with the theoretical gradient 
    # ----------------------------------------

    #     # compute the gradient
    # y = torch.zeros_like(data_sim["y"])
    # ys = torch.zeros_like(data_sim["y"])
    # with torch.no_grad():
    #     for response_type, response_id in response_types.items():
    #         y[:,response_id] = response_transform[response_type](data_sample["y"][:,response_id])
    #         ys[:,response_id] = response_transform[response_type](data_sim["y"][:,response_id])



    # mygrad =  -(y.T @ zhat_sample - ys.T @ zhat_sim)/data_sample["y"].shape[0]
    # grad_loss = model.decoder.wz.grad.clone().detach()

    # plt.scatter(mygrad, grad_loss)
    # plt.plot([-.05, .05], [-.05,.05], color="red")
    # plt.show()

    with torch.no_grad():   
        fit = mseLoss(mean_sample, data_sample["y"])
    
    
    # for param in model.decoder.parameters():
    #     if param.grad is not None:
    #         param.grad.clamp_(-100, 100)


    optimizer.step()
    scheduler.step()

    losses.append(fit.item())
    learning_rates.append(optimizer.param_groups[0]['lr'])
    learning_rates_encoder.append(model.encoder.optimizer.param_groups[0]['lr'])
    param_values.append(model.decoder.wz.clone().detach())

    print(f"\nEpoch {epoch}/{epochs}, loss_fit = {fit.item():.2f}, encoder_loss = {encoder_loss.item():.2f}.")
# Out:
# var_u: tensor([1.0000]), phi: tensor([0.1000])
#
# Epoch 1/100, loss_fit = 5677.11, encoder_loss = 1.99.
# var_u: tensor([0.9942]), phi: tensor([0.1002])
#
# Epoch 2/100, loss_fit = 5741.33, encoder_loss = 1.86.
# var_u: tensor([0.9865]), phi: tensor([0.0998])
#
# Epoch 3/100, loss_fit = 5710.60, encoder_loss = 1.79.
# var_u: tensor([0.9821]), phi: tensor([0.0975])
#
# Epoch 4/100, loss_fit = 5588.90, encoder_loss = 1.79.
# var_u: tensor([0.9877]), phi: tensor([0.0963])
#
# Epoch 5/100, loss_fit = 5235.83, encoder_loss = 1.79.
# var_u: tensor([0.9933]), phi: tensor([0.0972])
#
# Epoch 6/100, loss_fit = 5139.35, encoder_loss = 1.82.
# var_u: tensor([0.9996]), phi: tensor([0.0960])
#
# Epoch 7/100, loss_fit = 5019.15, encoder_loss = 1.78.
# var_u: tensor([1.0031]), phi: tensor([0.0955])
#
# Epoch 8/100, loss_fit = 4918.35, encoder_loss = 1.80.
# var_u: tensor([1.0016]), phi: tensor([0.0953])
#
# Epoch 9/100, loss_fit = 4800.85, encoder_loss = 1.80.
# var_u: tensor([1.0062]), phi: tensor([0.0947])
#
# Epoch 10/100, loss_fit = 4726.00, encoder_loss = 1.81.
# var_u: tensor([1.0135]), phi: tensor([0.0945])
#
# Epoch 11/100, loss_fit = 4868.65, encoder_loss = 1.80.
# var_u: tensor([1.0187]), phi: tensor([0.0951])
#
# Epoch 12/100, loss_fit = 3957.83, encoder_loss = 1.77.
# var_u: tensor([1.0254]), phi: tensor([0.0950])
#
# Epoch 13/100, loss_fit = 4262.11, encoder_loss = 1.78.
# var_u: tensor([1.0324]), phi: tensor([0.0938])
#
# Epoch 14/100, loss_fit = 3227.99, encoder_loss = 1.82.
# var_u: tensor([1.0336]), phi: tensor([0.0941])
#
# Epoch 15/100, loss_fit = 4517.08, encoder_loss = 1.79.
# var_u: tensor([1.0364]), phi: tensor([0.0935])
#
# Epoch 16/100, loss_fit = 4420.34, encoder_loss = 1.76.
# var_u: tensor([1.0413]), phi: tensor([0.0943])
#
# Epoch 17/100, loss_fit = 3670.42, encoder_loss = 1.77.
# var_u: tensor([1.0479]), phi: tensor([0.0941])
#
# Epoch 18/100, loss_fit = 4064.28, encoder_loss = 1.76.
# var_u: tensor([1.0504]), phi: tensor([0.0937])
#
# Epoch 19/100, loss_fit = 4489.80, encoder_loss = 1.74.
# var_u: tensor([1.0553]), phi: tensor([0.0938])
#
# Epoch 20/100, loss_fit = 3390.72, encoder_loss = 1.73.
# var_u: tensor([1.0611]), phi: tensor([0.0945])
#
# Epoch 21/100, loss_fit = 3743.62, encoder_loss = 1.68.
# var_u: tensor([1.0591]), phi: tensor([0.0946])
#
# Epoch 22/100, loss_fit = 4104.39, encoder_loss = 1.74.
# var_u: tensor([1.0653]), phi: tensor([0.0951])
#
# Epoch 23/100, loss_fit = 3211.65, encoder_loss = 1.71.
# var_u: tensor([1.0654]), phi: tensor([0.0946])
#
# Epoch 24/100, loss_fit = 3185.49, encoder_loss = 1.71.
# var_u: tensor([1.0617]), phi: tensor([0.0957])
#
# Epoch 25/100, loss_fit = 3118.93, encoder_loss = 1.70.
# var_u: tensor([1.0598]), phi: tensor([0.0966])
#
# Epoch 26/100, loss_fit = 3273.70, encoder_loss = 1.67.
# var_u: tensor([1.0604]), phi: tensor([0.0974])
#
# Epoch 27/100, loss_fit = 3836.66, encoder_loss = 1.66.
# var_u: tensor([1.0615]), phi: tensor([0.0985])
#
# Epoch 28/100, loss_fit = 4140.43, encoder_loss = 1.67.
# var_u: tensor([1.0595]), phi: tensor([0.0992])
#
# Epoch 29/100, loss_fit = 4319.07, encoder_loss = 1.68.
# var_u: tensor([1.0578]), phi: tensor([0.0986])
#
# Epoch 30/100, loss_fit = 3747.18, encoder_loss = 1.70.
# var_u: tensor([1.0623]), phi: tensor([0.0980])
#
# Epoch 31/100, loss_fit = 3345.07, encoder_loss = 1.70.
# var_u: tensor([1.0604]), phi: tensor([0.0993])
#
# Epoch 32/100, loss_fit = 4112.53, encoder_loss = 1.66.
# var_u: tensor([1.0605]), phi: tensor([0.1001])
#
# Epoch 33/100, loss_fit = 3041.10, encoder_loss = 1.65.
# var_u: tensor([1.0626]), phi: tensor([0.1004])
#
# Epoch 34/100, loss_fit = 3643.61, encoder_loss = 1.70.
# var_u: tensor([1.0612]), phi: tensor([0.1032])
#
# Epoch 35/100, loss_fit = 3924.02, encoder_loss = 1.68.
# var_u: tensor([1.0615]), phi: tensor([0.1047])
#
# Epoch 36/100, loss_fit = 3445.51, encoder_loss = 1.69.
# var_u: tensor([1.0635]), phi: tensor([0.1066])
#
# Epoch 37/100, loss_fit = 3504.25, encoder_loss = 1.69.
# var_u: tensor([1.0658]), phi: tensor([0.1080])
#
# Epoch 38/100, loss_fit = 2922.67, encoder_loss = 1.72.
# var_u: tensor([1.0656]), phi: tensor([0.1091])
#
# Epoch 39/100, loss_fit = 3328.41, encoder_loss = 1.68.
# var_u: tensor([1.0658]), phi: tensor([0.1097])
#
# Epoch 40/100, loss_fit = 2539.80, encoder_loss = 1.70.
# var_u: tensor([1.0680]), phi: tensor([0.1105])
#
# Epoch 41/100, loss_fit = 3316.51, encoder_loss = 1.73.
# var_u: tensor([1.0667]), phi: tensor([0.1140])
#
# Epoch 42/100, loss_fit = 3202.10, encoder_loss = 1.70.
# var_u: tensor([1.0676]), phi: tensor([0.1155])
#
# Epoch 43/100, loss_fit = 2696.53, encoder_loss = 1.71.
# var_u: tensor([1.0699]), phi: tensor([0.1162])
#
# Epoch 44/100, loss_fit = 3472.65, encoder_loss = 1.73.
# var_u: tensor([1.0698]), phi: tensor([0.1164])
#
# Epoch 45/100, loss_fit = 1874.32, encoder_loss = 1.70.
# var_u: tensor([1.0698]), phi: tensor([0.1162])
#
# Epoch 46/100, loss_fit = 2975.37, encoder_loss = 1.69.
# var_u: tensor([1.0748]), phi: tensor([0.1164])
#
# Epoch 47/100, loss_fit = 3497.16, encoder_loss = 1.76.
# var_u: tensor([1.0723]), phi: tensor([0.1176])
#
# Epoch 48/100, loss_fit = 3089.39, encoder_loss = 1.75.
# var_u: tensor([1.0718]), phi: tensor([0.1181])
#
# Epoch 49/100, loss_fit = 2367.55, encoder_loss = 1.73.
# var_u: tensor([1.0720]), phi: tensor([0.1195])
#
# Epoch 50/100, loss_fit = 2191.44, encoder_loss = 1.73.
# var_u: tensor([1.0723]), phi: tensor([0.1199])
#
# Epoch 51/100, loss_fit = 2893.43, encoder_loss = 1.75.
# var_u: tensor([1.0767]), phi: tensor([0.1210])
#
# Epoch 52/100, loss_fit = 2604.25, encoder_loss = 1.73.
# var_u: tensor([1.0729]), phi: tensor([0.1201])
#
# Epoch 53/100, loss_fit = 1815.11, encoder_loss = 1.75.
# var_u: tensor([1.0728]), phi: tensor([0.1201])
#
# Epoch 54/100, loss_fit = 2023.44, encoder_loss = 1.73.
# var_u: tensor([1.0761]), phi: tensor([0.1200])
#
# Epoch 55/100, loss_fit = 2402.92, encoder_loss = 1.72.
# var_u: tensor([1.0749]), phi: tensor([0.1224])
#
# Epoch 56/100, loss_fit = 2634.82, encoder_loss = 1.73.
# var_u: tensor([1.0775]), phi: tensor([0.1228])
#
# Epoch 57/100, loss_fit = 2598.26, encoder_loss = 1.70.
# var_u: tensor([1.0790]), phi: tensor([0.1226])
#
# Epoch 58/100, loss_fit = 3328.06, encoder_loss = 1.70.
# var_u: tensor([1.0789]), phi: tensor([0.1241])
#
# Epoch 59/100, loss_fit = 2424.96, encoder_loss = 1.71.
# var_u: tensor([1.0804]), phi: tensor([0.1252])
#
# Epoch 60/100, loss_fit = 965.33, encoder_loss = 1.71.
# var_u: tensor([1.0807]), phi: tensor([0.1261])
#
# Epoch 61/100, loss_fit = 3365.54, encoder_loss = 1.74.
# var_u: tensor([1.0803]), phi: tensor([0.1278])
#
# Epoch 62/100, loss_fit = 2708.39, encoder_loss = 1.70.
# var_u: tensor([1.0784]), phi: tensor([0.1286])
#
# Epoch 63/100, loss_fit = 1948.07, encoder_loss = 1.71.
# var_u: tensor([1.0796]), phi: tensor([0.1306])
#
# Epoch 64/100, loss_fit = 3187.40, encoder_loss = 1.70.
# var_u: tensor([1.0791]), phi: tensor([0.1307])
#
# Epoch 65/100, loss_fit = 3343.38, encoder_loss = 1.73.
# var_u: tensor([1.0767]), phi: tensor([0.1320])
#
# Epoch 66/100, loss_fit = 2828.83, encoder_loss = 1.72.
# var_u: tensor([1.0756]), phi: tensor([0.1338])
#
# Epoch 67/100, loss_fit = 3089.51, encoder_loss = 1.71.
# var_u: tensor([1.0755]), phi: tensor([0.1342])
#
# Epoch 68/100, loss_fit = 3530.00, encoder_loss = 1.74.
# var_u: tensor([1.0718]), phi: tensor([0.1359])
#
# Epoch 69/100, loss_fit = 3384.72, encoder_loss = 1.72.
# var_u: tensor([1.0719]), phi: tensor([0.1373])
#
# Epoch 70/100, loss_fit = 3168.90, encoder_loss = 1.72.
# var_u: tensor([1.0738]), phi: tensor([0.1374])
#
# Epoch 71/100, loss_fit = 2684.83, encoder_loss = 1.71.
# var_u: tensor([1.0748]), phi: tensor([0.1390])
#
# Epoch 72/100, loss_fit = 3097.63, encoder_loss = 1.71.
# var_u: tensor([1.0747]), phi: tensor([0.1380])
#
# Epoch 73/100, loss_fit = 2460.16, encoder_loss = 1.73.
# var_u: tensor([1.0745]), phi: tensor([0.1385])
#
# Epoch 74/100, loss_fit = 3240.72, encoder_loss = 1.71.
# var_u: tensor([1.0738]), phi: tensor([0.1401])
#
# Epoch 75/100, loss_fit = 3132.57, encoder_loss = 1.71.
# var_u: tensor([1.0739]), phi: tensor([0.1401])
#
# Epoch 76/100, loss_fit = 3614.57, encoder_loss = 1.69.
# var_u: tensor([1.0733]), phi: tensor([0.1411])
#
# Epoch 77/100, loss_fit = 3001.68, encoder_loss = 1.70.
# var_u: tensor([1.0698]), phi: tensor([0.1411])
#
# Epoch 78/100, loss_fit = 3901.81, encoder_loss = 1.71.
# var_u: tensor([1.0701]), phi: tensor([0.1428])
#
# Epoch 79/100, loss_fit = 3852.23, encoder_loss = 1.69.
# var_u: tensor([1.0694]), phi: tensor([0.1425])
#
# Epoch 80/100, loss_fit = 3001.49, encoder_loss = 1.72.
# var_u: tensor([1.0681]), phi: tensor([0.1424])
#
# Epoch 81/100, loss_fit = 2706.90, encoder_loss = 1.67.
# var_u: tensor([1.0683]), phi: tensor([0.1430])
#
# Epoch 82/100, loss_fit = 3344.87, encoder_loss = 1.68.
# var_u: tensor([1.0664]), phi: tensor([0.1439])
#
# Epoch 83/100, loss_fit = 3292.79, encoder_loss = 1.71.
# var_u: tensor([1.0678]), phi: tensor([0.1443])
#
# Epoch 84/100, loss_fit = 3015.11, encoder_loss = 1.70.
# var_u: tensor([1.0678]), phi: tensor([0.1450])
#
# Epoch 85/100, loss_fit = 2169.89, encoder_loss = 1.69.
# var_u: tensor([1.0702]), phi: tensor([0.1450])
#
# Epoch 86/100, loss_fit = 3193.98, encoder_loss = 1.69.
# var_u: tensor([1.0695]), phi: tensor([0.1456])
#
# Epoch 87/100, loss_fit = 2674.65, encoder_loss = 1.70.
# var_u: tensor([1.0692]), phi: tensor([0.1462])
#
# Epoch 88/100, loss_fit = 2160.00, encoder_loss = 1.69.
# var_u: tensor([1.0690]), phi: tensor([0.1461])
#
# Epoch 89/100, loss_fit = 2624.66, encoder_loss = 1.72.
# var_u: tensor([1.0670]), phi: tensor([0.1458])
#
# Epoch 90/100, loss_fit = 3508.98, encoder_loss = 1.68.
# var_u: tensor([1.0696]), phi: tensor([0.1467])
#
# Epoch 91/100, loss_fit = 2207.74, encoder_loss = 1.73.
# var_u: tensor([1.0708]), phi: tensor([0.1461])
#
# Epoch 92/100, loss_fit = 2417.99, encoder_loss = 1.73.
# var_u: tensor([1.0748]), phi: tensor([0.1466])
#
# Epoch 93/100, loss_fit = 3820.51, encoder_loss = 1.70.
# var_u: tensor([1.0768]), phi: tensor([0.1463])
#
# Epoch 94/100, loss_fit = 3346.89, encoder_loss = 1.68.
# var_u: tensor([1.0748]), phi: tensor([0.1462])
#
# Epoch 95/100, loss_fit = 2393.09, encoder_loss = 1.71.
# var_u: tensor([1.0758]), phi: tensor([0.1468])
#
# Epoch 96/100, loss_fit = 4114.59, encoder_loss = 1.69.
# var_u: tensor([1.0752]), phi: tensor([0.1463])
#
# Epoch 97/100, loss_fit = 1911.62, encoder_loss = 1.70.
# var_u: tensor([1.0760]), phi: tensor([0.1455])
#
# Epoch 98/100, loss_fit = 3456.45, encoder_loss = 1.70.
# var_u: tensor([1.0783]), phi: tensor([0.1452])
#
# Epoch 99/100, loss_fit = 3310.47, encoder_loss = 1.65.
# var_u: tensor([1.0782]), phi: tensor([0.1465])
#
# Epoch 100/100, loss_fit = 1608.23, encoder_loss = 1.70.

# %%
plt.plot(learning_rates)
plt.plot(learning_rates_encoder)

# %%
data = np.stack([tensor.flatten().numpy() for tensor in param_values], axis=0)


# Create figure and axes
fig, ax = plt.subplots()

# Loop through each feature
for i in range(data.shape[1]):
    ax.plot(data[:, i])

# Add legend and labels
ax.legend()
plt.xlabel('Time period')
plt.ylabel('Feature value')
plt.title('Evolution of features over time')

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(model_sample.decoder.wz.detach().numpy(), model.decoder.wz.detach().numpy())
plt.plot([-3,3], [-3,3], color="red")
plt.plot([-3,3], [3,-3], color="red")
plt.show()

plt.scatter(model_sample.decoder.wx.detach().numpy(), model.decoder.wx.detach().numpy())
plt.plot([-3,3], [-3,3], color="red")
plt.plot([-3,3], [3,-3], color="red")
plt.show()

# %%
model.encoder.plot(data_sample['x'], data_sample['y'], data_sample['z'], data_sample['u'])

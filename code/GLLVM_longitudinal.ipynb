# %% [markdown]
# # GLLVM Longitudinal

# %%
import torch
from torch import nn
from torch.optim.lr_scheduler import StepLR # scheduler
import numpy as np
import seaborn as sns
import math
import matplotlib.pyplot as plt
import copy

# %% [markdown]
# A Longitudinal GLLVM is a model with 1 variable per period for T periods, n observations, and p responses, and k covariates. We also have a random effect for each observation x response.

# %%
n = 1000
p = 13
q = 1
k = 3
T = 9

DIMENSIONS_Y = (n, T, p) 
DIMENSIONS_X = (n, T, k)
DIMENSIONS_Z = (n, T, q)
DIMENSIONS_U = (n, 1, p)

# %%
response_types = {
    'binary': [0,1,2,3,4,5,6,7],
    'ordinal': [9, 10],
    'counts': [8, 11, 12]
}

response_types = {
    'binary': [0,1,2,3,4,5,6,7, 9, 10],
    'counts': [8, 11, 12]
}

link = {
    'binary' : lambda x: torch.logit(x),
    'ordinal': lambda x: torch.logit(x),
    'counts': lambda x: torch.log(x)
}


linkinv = {
    'binary': lambda x: 1/(1+torch.exp(-x)),
    'ordinal': lambda x: 1/(1+torch.exp(-x)),
    'counts': lambda x: torch.exp(x)
}

response_transform = {
    'binary' : lambda x: 2*x - 1,
    'ordinal': lambda x: 2*x - 1,
    'counts': lambda x: torch.log(x+1)
}

# %% [markdown]
# They can be of many response types. Here for the sake of illutration we will consider 3 response types: gaussian, binary, and poisson.
#
# We allow for transformation of the data, which we account for in the estimation. In particular, Poisson data may be numerically problematic because their conditional expectation is the exponential of the linear predictor. Small differences in the latter can result in dramatic differences in the gradient. For instance, we can transform poisson with the following function $x \rightarrow \log(x+1)$. This transforms is needed in 2 places: for encoding, and at the loss function for computing the gradient.
#
# ## Computing the scale parameter
#
# The scale parameter is computed in a second step (on the fit residual). They are updated at every iteration. This is not yet implemented.
#
#
# ### Modules
#
# We need LongitudinalGLLVM as the overarching module, Sample which samples the data and takes additional arguments (such as nuisance parameters), Decoder which contains all the parameters of interest, and Encoder which encodes the data using a Neural Network.
#
# ### Design of the Encoder
# Since the estimation problem for Z is the same at each time step, we model the encoder using a RNN. At each time step, the same encoder is used to compute the Z. At the same time, the hidden state of the RNN is used to predict the U variable, which is constant over time for each observation.

# %%
class LongitudinalGLLVM(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
        self.sample = Sample(self.decoder)
    
    def plot_cov(self, what="linpar", x=None):
        data_sample = self.sample(x=x)
        data =  data_sample[what].detach().view(n, -1).numpy()
        cov_matrix = np.cov(data, rowvar=False)

        plt.figure(figsize=(10,10))
        sns.heatmap(cov_matrix, annot=False, fmt='g')
        plt.show()
    
    def impute(self, x, y, mask, nsteps=10):
        """ Impute the missing values provided by the mask (True is missing) and return x imputed"""
        for _ in range(nsteps):
            z, u = self.encoder(x,y, transform_response = True)
            _, mean = self.decoder(x,z,u)
            y[mask] = mean[mask]
        return y

class Sample(nn.Module):
    def __init__(self, decoder):
        super().__init__()
        self.decoder = decoder
        self.phi = torch.ones(1) * .8
        self.var_u = torch.ones(1) * 1.0

    # sampling comes here
    
    def forward(self, x):
        with torch.no_grad():
            if x is None:
                Warning("x was set to None for sampling. X is usually fixed. Are you sure you want to sample x?")
                x = torch.randn((n, T, k))

            u = torch.randn((n, 1, p)) * torch.sqrt(self.var_u)
            d = torch.randn((n, T, q))
            z = self.AR(d)

            linpar, mean = self.decoder(x, z, u) # decoder gives the expectation

            y = self.sample_response(mean)

            return {"x":x, "y":y, "z":z, "u":u, "linpar":linpar, "mean":mean}

    def sample_response(self, mean):
            y = torch.zeros_like(mean)
            for response_type, response_id in response_types.items():
                if response_type == "binary":
                    y[:,:,response_id] = torch.bernoulli(mean[:,:,response_id])
                elif response_type == "ordinal":
                    cum_probs = mean[:,:,response_id]
                    # draw one uniform for the whole vector
                    random = torch.rand((*cum_probs.shape[0:2], 1)) 
                    # compare with the cumulative probabilities
                    ordinal = torch.sum(random > cum_probs, dim=2)
                    ordinal = torch.nn.functional.one_hot(ordinal).squeeze().float()
                    ordinal = ordinal[:,:,1:] # discard the first column of the one_hot encoding, as it is superfluous (as a 0)
                    y[:,:,response_id] = ordinal
                elif response_type == "counts":
                    y[:,:,response_id] = torch.poisson(mean[:,:,response_id])
            return y

    def AR(self, d):
        z = d.clone()

        for t in range(1, z.shape[1]):
            z[:,t] = z[:,t] + z[:, t-1].clone() * self.phi  # we need to clone else the gradient wants to pass through it
        return z
                
    
class Decoder(nn.Module):
    # Yields the expectation
    def __init__(self):
        super().__init__()

        # decoder part (our parameters of interest)
        self.wz = nn.Parameter(torch.randn((q, p)))
        self.wx = nn.Parameter(torch.randn((1, k, p))) # Measurement invariance!
        self.bias = nn.Parameter(torch.zeros((1, 1, p))) # Measurement invariance!

    # decoding (computing the conditional mean)
    def forward(self, x, z, u):

        xwx = (x.unsqueeze(2) @ self.wx).squeeze() # see section "details of tensorproducts"
        zwz = (z.unsqueeze(2) @ self.wz).squeeze()
        # for the ordinal variables:
        linpar = self.bias + xwx + zwz + u 

        # Apply the inverse link to get the conditional expectation
        mean  = torch.zeros_like(linpar)
        for response_type, response_id in response_types.items():
            mean[:,:,response_id] = linkinv[response_type](linpar[:,:,response_id])
        # Transform the 
        return linpar, mean



class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        # encoder part
        # input dimension is (p+k) (responses + covariates)
        # output dimension is q+p (one latent )
        input_size = p + k
        hidden_size = (p + q) * 5
        self.rnn = nn.RNN(input_size = input_size, hidden_size = hidden_size, batch_first=True)
        
        self.fc = nn.Sequential(
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
        )
        # fully connected layers for Z and U
        self.fc_Z = nn.Sequential(
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = q),
        )

        self.fc_U = nn.Sequential(
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features=hidden_size, out_features = p)
        )

        self.optimizer =  torch.optim.Adam(self.parameters(), lr=.01)
        self.scheduler = StepLR(self.optimizer, step_size=100, gamma=.95)
        self.loss = nn.MSELoss()

    
    def forward(self, x, y, transform_response = False):
        # Initialize hidden state

        # pass the input through the RNN
        if transform_response:
            y_transformed = torch.zeros_like(y)
            with torch.no_grad():
                for response_type, response_id in response_types.items():
                    y_transformed[:,:,response_id] = response_transform[response_type](y[:,:,response_id])
        else:
            y_transformed = y

        xy = torch.cat([x, y_transformed], dim=2)
        rnn_out, _ = self.rnn(xy)
        out = self.fc(rnn_out)
        z_pred = self.fc_Z(out)
        u_pred = self.fc_U(out[:, -1, :]).unsqueeze(1)
        return z_pred, u_pred
    
    def fit(self, x, y, z, u, epochs = 100, verbose = False):
        y = y.clone()
        with torch.no_grad():
            for response_type, response_id in response_types.items():
                y[:,:,response_id] = response_transform[response_type](y[:,:,response_id])
        # Fit the encoder
        for epoch in range(epochs):
            self.optimizer.zero_grad()

            z_pred, u_pred = self(x, y, transform_response = False)

            loss = self.loss(z_pred, z) + self.loss(u_pred, u)

            if verbose:
                print(f"\nEpoch {epoch}/{epochs}, loss={loss}")
            loss.backward()
            self.optimizer.step()
            self.scheduler.step()

        return loss
    
    def plot(self, x, y, z, u):
        with torch.no_grad():
            z_pred, u_pred = self(x, y, transform_response = True)

        fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,4))

        ax1.scatter(z, z_pred)
        ax1.set_xlabel('Z True')
        ax1.set_ylabel('Z Pred')
        ax1.set_title('Encoded values of Z')
        ax1.plot(ax1.get_xlim(), ax1.get_ylim(), ls="--", color="red")

        ax2.scatter(u, u_pred)
        ax2.set_xlabel('U True')
        ax2.set_ylabel('U Pred')
        ax2.set_title('Encoded values of U')
        ax2.plot(ax2.get_xlim(), ax2.get_ylim(), ls="--", color="red")


        plt.show()
        


class MELoss(nn.Module):
    def __init__(self):
        super().__init__()
    
    def forward(self, y, linpar, ys, linpars):
        """Computes the loss. hat is recontructed y, ys is simulated"""
        y_transformed = torch.zeros_like(y)
        ys_transformed = torch.zeros_like(ys)
        with torch.no_grad():
            for response_type, response_id in response_types.items():
                y_transformed[:,:,response_id] = response_transform[response_type](y[:,:,response_id])
                ys_transformed[:,:,response_id] = response_transform[response_type](ys[:,:,response_id])


        return -torch.mean(y_transformed* linpar - ys_transformed * linpars) * y.shape[1] * y.shape[2]
        # return torch.mean(torch.pow(y-linpar, 2) - torch.pow(ys - linpars, 2))
        # loss = torch.mean(y.T @ linpar - ys.T @linpars)/y.shape[0]
        # return loss

# %%
model_sample = LongitudinalGLLVM()

# %%
model_sample.plot_cov("linpar", x=None)

# %%
data_sample = model_sample.sample(x = None)

# %%
model_sample.encoder.fit(data_sample['x'], data_sample['y'], data_sample['z'], data_sample['u'], epochs = 1, verbose=True)
# Out:
# Epoch 0/1, loss=3.2176079750061035
# tensor(3.2176, grad_fn=<AddBackward0>)

# %%
data_example = model_sample.sample(x=data_sample['x'])
model_sample.encoder.plot(data_sample['x'], data_sample['y'], data_sample['z'], data_sample['u'])
model_sample.encoder.plot(data_example['x'], data_example['y'], data_example['z'], data_example['u'])

# %%
model = LongitudinalGLLVM()
criterion = MELoss()
optimizer = torch.optim.Adam(model.decoder.parameters(), lr=.1)
scheduler = StepLR(optimizer, step_size=10, gamma=.95)
mseLoss = nn.MSELoss()
epochs = 500

 # TODO: FIGURE OUT THE PROBLEM WITH IMPUTATION
 # VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
mask = torch.rand_like(data_sample['y']) < 0
data_sample['y'][mask] = 0.5
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# --------------------------------------------------------

def compute_autocorr(z):
    # Compute the sample autocovariance and autocorrelation
    autocovariance = torch.mean((z[:, 1:] - torch.mean(z[:, 1:])) * (z[:, :-1] - torch.mean(z[:, :-1])), dim=1)
    autocorrelation = autocovariance / torch.var(z[:, :-1])

    # Estimate phi using the autocorrelation formula for AR(1)
    phi = torch.mean(autocorrelation)

    return phi

# %%
losses = []
learning_rates = []
learning_rates_encoder = []
param_values = []

for epoch in range(1, epochs +1):
    optimizer.zero_grad()

    # impute and sample
    with torch.no_grad():
        # data_true["y"] = model.impute(data_true["x"], data_true["y"], mask=mask["y"], nsteps=5)
        # simulate data from the current parameter values, Unconditionally (!)
        data_sim = model.sample(x=data_sample["x"])
        data_sim['y'][mask] = 0.5
        
        assert torch.eq(data_sim["x"], data_sample["x"]).all().item()

        # compute the imputing values without the gradients
        zhat_sample, uhat_sample = model.encoder(data_sample["x"], data_sample["y"], transform_response=True)
        zhat_sim, uhat_sim = model.encoder(data_sim["x"], data_sim["y"], transform_response=True)


    # train the encoder on the simulated data
    encoder_loss = model.encoder.fit(data_sim["x"], data_sim["y"], data_sim["z"], data_sim["u"],  epochs= 5) 
    
    # compute the decoded value
    linpar_sample, mean_sample = model.decoder(data_sample["x"], zhat_sample, uhat_sample)
    linpar_sim, mean_sim = model.decoder(data_sim["x"], zhat_sim, uhat_sim)

    # # impute values
    # data_sample["y"] = model.impute(data_sample["x"], data_sample["y"], mask, nsteps=2)
    # data_sim["y"] = model.impute(data_sim["x"], data_sim["y"], mask, nsteps=2)

    # model.decoder.wz.grad = mygrad
    loss = criterion(data_sample["y"], linpar_sample,  data_sim["y"], linpar_sim)
    loss.backward()

    # Update nuisance parameters
    with torch.no_grad():
        model.sample.var_u = .8* model.sample.var_u + .2 * torch.var(uhat_sample) * (model.sample.var_u / torch.var(uhat_sim))
        model.sample.phi = .8 * model.sample.phi + .2 * compute_autocorr(zhat_sample) * model.sample.phi / compute_autocorr(zhat_sim)
        if model.sample.phi > .9:
            model.sample.phi = torch.ones(1) * .9 
        # model.sample.phi = zhat_sample[:,1:,:] - zhat_sample[:,:-1,:]
        print(f'var_u: {model.sample.var_u}, phi: {model.sample.phi}')

    # Comparison with the theoretical gradient 
    # ----------------------------------------

    #     # compute the gradient
    # y = torch.zeros_like(data_sim["y"])
    # ys = torch.zeros_like(data_sim["y"])
    # with torch.no_grad():
    #     for response_type, response_id in response_types.items():
    #         y[:,response_id] = response_transform[response_type](data_sample["y"][:,response_id])
    #         ys[:,response_id] = response_transform[response_type](data_sim["y"][:,response_id])



    # mygrad =  -(y.T @ zhat_sample - ys.T @ zhat_sim)/data_sample["y"].shape[0]
    # grad_loss = model.decoder.wz.grad.clone().detach()

    # plt.scatter(mygrad, grad_loss)
    # plt.plot([-.05, .05], [-.05,.05], color="red")
    # plt.show()

    with torch.no_grad():   
        fit = mseLoss(mean_sample, data_sample["y"])
    
    
    # for param in model.decoder.parameters():
    #     if param.grad is not None:
    #         param.grad.clamp_(-100, 100)


    optimizer.step()
    scheduler.step()

    losses.append(fit.item())
    learning_rates.append(optimizer.param_groups[0]['lr'])
    learning_rates_encoder.append(model.encoder.optimizer.param_groups[0]['lr'])
    param_values.append(model.decoder.wz.clone().detach())

    print(f"\nEpoch {epoch}/{epochs}, loss_fit = {fit.item():.2f}, encoder_loss = {encoder_loss.item():.2f}.")
# Out:
# var_u: tensor([1.0002]), phi: tensor([0.6783])
#
# Epoch 1/500, loss_fit = 790045.62, encoder_loss = 2.27.
# var_u: tensor([0.9724]), phi: tensor([0.6594])
#
# Epoch 2/500, loss_fit = 789921.38, encoder_loss = 1.65.
# var_u: tensor([0.9159]), phi: tensor([0.6221])
#
# Epoch 3/500, loss_fit = 789875.19, encoder_loss = 1.35.
# var_u: tensor([0.8687]), phi: tensor([0.5972])
#
# Epoch 4/500, loss_fit = 789847.12, encoder_loss = 1.28.
# var_u: tensor([0.8300]), phi: tensor([0.5764])
#
# Epoch 5/500, loss_fit = 789672.69, encoder_loss = 1.19.
# var_u: tensor([0.8154]), phi: tensor([0.5463])
#
# Epoch 6/500, loss_fit = 789542.62, encoder_loss = 1.16.
# var_u: tensor([0.8327]), phi: tensor([0.5285])
#
# Epoch 7/500, loss_fit = 788961.50, encoder_loss = 1.14.
# var_u: tensor([0.9146]), phi: tensor([0.5225])
#
# Epoch 8/500, loss_fit = 788558.06, encoder_loss = 1.15.
# var_u: tensor([1.0415]), phi: tensor([0.5236])
#
# Epoch 9/500, loss_fit = 787073.50, encoder_loss = 1.22.
# var_u: tensor([1.1053]), phi: tensor([0.5249])
#
# Epoch 10/500, loss_fit = 784271.56, encoder_loss = 1.32.
# var_u: tensor([1.1281]), phi: tensor([0.5406])
#
# Epoch 11/500, loss_fit = 772109.44, encoder_loss = 1.37.
# var_u: tensor([1.1243]), phi: tensor([0.5505])
#
# Epoch 12/500, loss_fit = 755824.75, encoder_loss = 1.36.
# var_u: tensor([1.1316]), phi: tensor([0.5653])
#
# Epoch 13/500, loss_fit = 735762.88, encoder_loss = 1.34.
# var_u: tensor([1.1350]), phi: tensor([0.5831])
#
# Epoch 14/500, loss_fit = 743018.94, encoder_loss = 1.31.
# var_u: tensor([1.1241]), phi: tensor([0.5966])
#
# Epoch 15/500, loss_fit = 756225.88, encoder_loss = 1.30.
# var_u: tensor([1.1073]), phi: tensor([0.6189])
#
# Epoch 16/500, loss_fit = 746466.25, encoder_loss = 1.28.
# var_u: tensor([1.1003]), phi: tensor([0.6368])
#
# Epoch 17/500, loss_fit = 715930.12, encoder_loss = 1.25.
# var_u: tensor([1.0898]), phi: tensor([0.6525])
#
# Epoch 18/500, loss_fit = 691629.06, encoder_loss = 1.24.
# var_u: tensor([1.0747]), phi: tensor([0.6653])
#
# Epoch 19/500, loss_fit = 668467.75, encoder_loss = 1.26.
# var_u: tensor([1.0624]), phi: tensor([0.6798])
#
# Epoch 20/500, loss_fit = 666408.56, encoder_loss = 1.23.
# var_u: tensor([1.0478]), phi: tensor([0.6943])
#
# Epoch 21/500, loss_fit = 622305.44, encoder_loss = 1.19.
# var_u: tensor([1.0297]), phi: tensor([0.7095])
#
# Epoch 22/500, loss_fit = 590595.12, encoder_loss = 1.18.
# var_u: tensor([1.0242]), phi: tensor([0.7161])
#
# Epoch 23/500, loss_fit = 609065.25, encoder_loss = 1.16.
# var_u: tensor([0.9978]), phi: tensor([0.7222])
#
# Epoch 24/500, loss_fit = 553880.50, encoder_loss = 1.15.
# var_u: tensor([0.9889]), phi: tensor([0.7322])
#
# Epoch 25/500, loss_fit = 499988.44, encoder_loss = 1.13.
# var_u: tensor([0.9885]), phi: tensor([0.7377])
#
# Epoch 26/500, loss_fit = 471734.25, encoder_loss = 1.11.
# var_u: tensor([0.9994]), phi: tensor([0.7458])
#
# Epoch 27/500, loss_fit = 461977.62, encoder_loss = 1.11.
# var_u: tensor([1.0035]), phi: tensor([0.7526])
#
# Epoch 28/500, loss_fit = 500348.28, encoder_loss = 1.15.
# var_u: tensor([1.0125]), phi: tensor([0.7597])
#
# Epoch 29/500, loss_fit = 497697.41, encoder_loss = 1.15.
# var_u: tensor([1.0195]), phi: tensor([0.7634])
#
# Epoch 30/500, loss_fit = 407264.38, encoder_loss = 1.16.
# var_u: tensor([1.0199]), phi: tensor([0.7650])
#
# Epoch 31/500, loss_fit = 415893.97, encoder_loss = 1.16.
# var_u: tensor([1.0261]), phi: tensor([0.7693])
#
# Epoch 32/500, loss_fit = 425796.97, encoder_loss = 1.21.
# var_u: tensor([1.0330]), phi: tensor([0.7710])
#
# Epoch 33/500, loss_fit = 428406.00, encoder_loss = 1.23.
# var_u: tensor([1.0527]), phi: tensor([0.7736])
#
# Epoch 34/500, loss_fit = 248121.38, encoder_loss = 1.22.
# var_u: tensor([1.0610]), phi: tensor([0.7741])
#
# Epoch 35/500, loss_fit = 282400.12, encoder_loss = 1.23.
# var_u: tensor([1.0702]), phi: tensor([0.7753])
#
# Epoch 36/500, loss_fit = 232936.47, encoder_loss = 1.21.
# var_u: tensor([1.0822]), phi: tensor([0.7748])
#
# Epoch 37/500, loss_fit = 259697.70, encoder_loss = 1.19.
# var_u: tensor([1.0966]), phi: tensor([0.7773])
#
# Epoch 38/500, loss_fit = 267468.19, encoder_loss = 1.26.
# var_u: tensor([1.1050]), phi: tensor([0.7777])
#
# Epoch 39/500, loss_fit = 207908.84, encoder_loss = 1.22.
# var_u: tensor([1.1016]), phi: tensor([0.7790])
#
# Epoch 40/500, loss_fit = 242431.97, encoder_loss = 1.23.
# var_u: tensor([1.1016]), phi: tensor([0.7814])
#
# Epoch 41/500, loss_fit = 196493.42, encoder_loss = 1.21.
# var_u: tensor([1.0971]), phi: tensor([0.7827])
#
# Epoch 42/500, loss_fit = 330168.06, encoder_loss = 1.21.
# var_u: tensor([1.1022]), phi: tensor([0.7838])
#
# Epoch 43/500, loss_fit = 233434.83, encoder_loss = 1.19.
# var_u: tensor([1.1062]), phi: tensor([0.7830])
#
# Epoch 44/500, loss_fit = 206723.11, encoder_loss = 1.19.
# var_u: tensor([1.0925]), phi: tensor([0.7820])
#
# Epoch 45/500, loss_fit = 217609.59, encoder_loss = 1.19.
# var_u: tensor([1.0875]), phi: tensor([0.7842])
#
# Epoch 46/500, loss_fit = 253596.94, encoder_loss = 1.18.
# var_u: tensor([1.0855]), phi: tensor([0.7859])
#
# Epoch 47/500, loss_fit = 268735.12, encoder_loss = 1.20.
# var_u: tensor([1.0874]), phi: tensor([0.7860])
#
# Epoch 48/500, loss_fit = 269270.50, encoder_loss = 1.21.
# var_u: tensor([1.0883]), phi: tensor([0.7872])
#
# Epoch 49/500, loss_fit = 210657.64, encoder_loss = 1.19.
# var_u: tensor([1.0819]), phi: tensor([0.7894])
#
# Epoch 50/500, loss_fit = 270316.12, encoder_loss = 1.18.
# var_u: tensor([1.0744]), phi: tensor([0.7905])
#
# Epoch 51/500, loss_fit = 288989.72, encoder_loss = 1.19.
# var_u: tensor([1.0668]), phi: tensor([0.7911])
#
# Epoch 52/500, loss_fit = 164835.80, encoder_loss = 1.17.
# var_u: tensor([1.0657]), phi: tensor([0.7936])
#
# Epoch 53/500, loss_fit = 162391.81, encoder_loss = 1.14.
# var_u: tensor([1.0604]), phi: tensor([0.7949])
#
# Epoch 54/500, loss_fit = 220730.73, encoder_loss = 1.16.
# var_u: tensor([1.0514]), phi: tensor([0.7942])
#
# Epoch 55/500, loss_fit = 308084.53, encoder_loss = 1.17.
# var_u: tensor([1.0439]), phi: tensor([0.7951])
#
# Epoch 56/500, loss_fit = 195334.72, encoder_loss = 1.17.
# var_u: tensor([1.0388]), phi: tensor([0.7972])
#
# Epoch 57/500, loss_fit = 84399.41, encoder_loss = 1.16.
# var_u: tensor([1.0348]), phi: tensor([0.7968])
#
# Epoch 58/500, loss_fit = 265153.72, encoder_loss = 1.13.
# var_u: tensor([1.0343]), phi: tensor([0.7936])
#
# Epoch 59/500, loss_fit = 164874.30, encoder_loss = 1.16.
# var_u: tensor([1.0339]), phi: tensor([0.7934])
#
# Epoch 60/500, loss_fit = 85542.30, encoder_loss = 1.16.
# var_u: tensor([1.0217]), phi: tensor([0.7944])
#
# Epoch 61/500, loss_fit = 202537.28, encoder_loss = 1.14.
# var_u: tensor([1.0237]), phi: tensor([0.7944])
#
# Epoch 62/500, loss_fit = 272299.75, encoder_loss = 1.15.
# var_u: tensor([1.0249]), phi: tensor([0.7959])
#
# Epoch 63/500, loss_fit = 100406.48, encoder_loss = 1.12.
# var_u: tensor([1.0282]), phi: tensor([0.7948])
#
# Epoch 64/500, loss_fit = 149541.28, encoder_loss = 1.12.
# var_u: tensor([1.0270]), phi: tensor([0.7942])
#
# Epoch 65/500, loss_fit = 309126.59, encoder_loss = 1.13.
# var_u: tensor([1.0237]), phi: tensor([0.7947])
#
# Epoch 66/500, loss_fit = 146554.22, encoder_loss = 1.12.
# var_u: tensor([1.0211]), phi: tensor([0.7952])
#
# Epoch 67/500, loss_fit = 494132.81, encoder_loss = 1.12.
# var_u: tensor([1.0255]), phi: tensor([0.7935])
#
# Epoch 68/500, loss_fit = 150318.81, encoder_loss = 1.14.
# var_u: tensor([1.0231]), phi: tensor([0.7920])
#
# Epoch 69/500, loss_fit = 111235.30, encoder_loss = 1.12.
# var_u: tensor([1.0197]), phi: tensor([0.7913])
#
# Epoch 70/500, loss_fit = 132557.02, encoder_loss = 1.09.
# var_u: tensor([1.0162]), phi: tensor([0.7926])
#
# Epoch 71/500, loss_fit = 189944.44, encoder_loss = 1.12.
# var_u: tensor([1.0118]), phi: tensor([0.7916])
#
# Epoch 72/500, loss_fit = 108349.73, encoder_loss = 1.12.
# var_u: tensor([1.0138]), phi: tensor([0.7921])
#
# Epoch 73/500, loss_fit = 109165.47, encoder_loss = 1.10.
# var_u: tensor([1.0089]), phi: tensor([0.7919])
#
# Epoch 74/500, loss_fit = 213201.48, encoder_loss = 1.08.
# var_u: tensor([1.0022]), phi: tensor([0.7931])
#
# Epoch 75/500, loss_fit = 275815.97, encoder_loss = 1.07.
# var_u: tensor([0.9958]), phi: tensor([0.7928])
#
# Epoch 76/500, loss_fit = 157636.56, encoder_loss = 1.10.
# var_u: tensor([0.9989]), phi: tensor([0.7923])
#
# Epoch 77/500, loss_fit = 148444.19, encoder_loss = 1.09.
# var_u: tensor([0.9983]), phi: tensor([0.7916])
#
# Epoch 78/500, loss_fit = 205073.41, encoder_loss = 1.13.
# var_u: tensor([0.9968]), phi: tensor([0.7923])
#
# Epoch 79/500, loss_fit = 173327.77, encoder_loss = 1.11.
# var_u: tensor([0.9965]), phi: tensor([0.7935])
#
# Epoch 80/500, loss_fit = 132420.81, encoder_loss = 1.08.
# var_u: tensor([1.0073]), phi: tensor([0.7944])
#
# Epoch 81/500, loss_fit = 166068.34, encoder_loss = 1.08.
# var_u: tensor([0.9992]), phi: tensor([0.7965])
#
# Epoch 82/500, loss_fit = 183042.95, encoder_loss = 1.07.
# var_u: tensor([1.0018]), phi: tensor([0.7974])
#
# Epoch 83/500, loss_fit = 244732.02, encoder_loss = 1.10.
# var_u: tensor([1.0034]), phi: tensor([0.7978])
#
# Epoch 84/500, loss_fit = 93337.77, encoder_loss = 1.09.
# var_u: tensor([1.0024]), phi: tensor([0.7998])
#
# Epoch 85/500, loss_fit = 119913.57, encoder_loss = 1.12.
# var_u: tensor([1.0045]), phi: tensor([0.7997])
#
# Epoch 86/500, loss_fit = 163863.34, encoder_loss = 1.12.
# var_u: tensor([1.0074]), phi: tensor([0.7989])
#
# Epoch 87/500, loss_fit = 101782.41, encoder_loss = 1.09.
# var_u: tensor([1.0059]), phi: tensor([0.7972])
#
# Epoch 88/500, loss_fit = 106058.92, encoder_loss = 1.10.
# var_u: tensor([1.0035]), phi: tensor([0.7988])
#
# Epoch 89/500, loss_fit = 55976.10, encoder_loss = 1.11.
# var_u: tensor([1.0068]), phi: tensor([0.7965])
#
# Epoch 90/500, loss_fit = 75183.45, encoder_loss = 1.09.
# var_u: tensor([1.0084]), phi: tensor([0.7955])
#
# Epoch 91/500, loss_fit = 213827.34, encoder_loss = 1.08.
# var_u: tensor([1.0082]), phi: tensor([0.7952])
#
# Epoch 92/500, loss_fit = 169987.14, encoder_loss = 1.11.
# var_u: tensor([1.0061]), phi: tensor([0.7936])
#
# Epoch 93/500, loss_fit = 172188.52, encoder_loss = 1.09.
# var_u: tensor([0.9989]), phi: tensor([0.7931])
#
# Epoch 94/500, loss_fit = 92715.23, encoder_loss = 1.10.
# var_u: tensor([1.0001]), phi: tensor([0.7929])
#
# Epoch 95/500, loss_fit = 213409.00, encoder_loss = 1.10.
# var_u: tensor([0.9969]), phi: tensor([0.7936])
#
# Epoch 96/500, loss_fit = 142874.02, encoder_loss = 1.12.
# var_u: tensor([0.9923]), phi: tensor([0.7939])
#
# Epoch 97/500, loss_fit = 150880.31, encoder_loss = 1.11.
# var_u: tensor([0.9966]), phi: tensor([0.7907])
#
# Epoch 98/500, loss_fit = 319313.41, encoder_loss = 1.12.
# var_u: tensor([0.9951]), phi: tensor([0.7896])
#
# Epoch 99/500, loss_fit = 158795.34, encoder_loss = 1.11.
# var_u: tensor([0.9925]), phi: tensor([0.7919])
#
# Epoch 100/500, loss_fit = 77786.09, encoder_loss = 1.14.
# var_u: tensor([0.9929]), phi: tensor([0.7948])
#
# Epoch 101/500, loss_fit = 125860.82, encoder_loss = 1.11.
# var_u: tensor([0.9974]), phi: tensor([0.7954])
#
# Epoch 102/500, loss_fit = 154129.86, encoder_loss = 1.08.
# var_u: tensor([1.0018]), phi: tensor([0.7963])
#
# Epoch 103/500, loss_fit = 617989.44, encoder_loss = 1.10.
# var_u: tensor([1.0059]), phi: tensor([0.7932])
#
# Epoch 104/500, loss_fit = 225764.17, encoder_loss = 1.07.
# var_u: tensor([1.0084]), phi: tensor([0.7959])
#
# Epoch 105/500, loss_fit = 206586.44, encoder_loss = 1.07.
# var_u: tensor([1.0119]), phi: tensor([0.7962])
#
# Epoch 106/500, loss_fit = 58707.23, encoder_loss = 1.09.
# var_u: tensor([1.0118]), phi: tensor([0.7967])
#
# Epoch 107/500, loss_fit = 178055.39, encoder_loss = 1.08.
# var_u: tensor([1.0136]), phi: tensor([0.7964])
#
# Epoch 108/500, loss_fit = 104878.66, encoder_loss = 1.13.
# var_u: tensor([1.0182]), phi: tensor([0.7947])
#
# Epoch 109/500, loss_fit = 101462.31, encoder_loss = 1.10.
# var_u: tensor([1.0209]), phi: tensor([0.7946])
#
# Epoch 110/500, loss_fit = 160575.39, encoder_loss = 1.07.
# var_u: tensor([1.0250]), phi: tensor([0.7943])
#
# Epoch 111/500, loss_fit = 95131.63, encoder_loss = 1.05.
# var_u: tensor([1.0250]), phi: tensor([0.7920])
#
# Epoch 112/500, loss_fit = 125944.12, encoder_loss = 1.08.
# var_u: tensor([1.0213]), phi: tensor([0.7935])
#
# Epoch 113/500, loss_fit = 107168.00, encoder_loss = 1.07.
# var_u: tensor([1.0158]), phi: tensor([0.7973])
#
# Epoch 114/500, loss_fit = 118926.31, encoder_loss = 1.08.
# var_u: tensor([1.0053]), phi: tensor([0.7968])
#
# Epoch 115/500, loss_fit = 79095.86, encoder_loss = 1.04.
# var_u: tensor([1.0042]), phi: tensor([0.7959])
#
# Epoch 116/500, loss_fit = 197850.84, encoder_loss = 1.07.
# var_u: tensor([0.9969]), phi: tensor([0.7946])
#
# Epoch 117/500, loss_fit = 95402.91, encoder_loss = 1.05.
# var_u: tensor([0.9984]), phi: tensor([0.7936])
#
# Epoch 118/500, loss_fit = 156926.61, encoder_loss = 1.07.
# var_u: tensor([1.0023]), phi: tensor([0.7956])
#
# Epoch 119/500, loss_fit = 104641.09, encoder_loss = 1.06.
# var_u: tensor([1.0031]), phi: tensor([0.7950])
#
# Epoch 120/500, loss_fit = 98432.30, encoder_loss = 1.07.
# var_u: tensor([1.0081]), phi: tensor([0.7955])
#
# Epoch 121/500, loss_fit = 184141.02, encoder_loss = 1.11.
# var_u: tensor([1.0040]), phi: tensor([0.7949])
#
# Epoch 122/500, loss_fit = 138954.20, encoder_loss = 1.07.
# var_u: tensor([0.9989]), phi: tensor([0.7904])
#
# Epoch 123/500, loss_fit = 230629.72, encoder_loss = 1.06.
# var_u: tensor([0.9936]), phi: tensor([0.7902])
#
# Epoch 124/500, loss_fit = 88488.11, encoder_loss = 1.06.
# var_u: tensor([0.9976]), phi: tensor([0.7930])
#
# Epoch 125/500, loss_fit = 128759.41, encoder_loss = 1.03.
# var_u: tensor([0.9960]), phi: tensor([0.7949])
#
# Epoch 126/500, loss_fit = 108696.66, encoder_loss = 1.05.
# var_u: tensor([1.0029]), phi: tensor([0.7972])
#
# Epoch 127/500, loss_fit = 116323.92, encoder_loss = 1.06.
# var_u: tensor([0.9987]), phi: tensor([0.7975])
#
# Epoch 128/500, loss_fit = 157242.94, encoder_loss = 1.09.
# var_u: tensor([1.0012]), phi: tensor([0.7953])
#
# Epoch 129/500, loss_fit = 113366.37, encoder_loss = 1.06.
# var_u: tensor([0.9951]), phi: tensor([0.7953])
#
# Epoch 130/500, loss_fit = 232134.38, encoder_loss = 1.06.
# var_u: tensor([0.9971]), phi: tensor([0.7946])
#
# Epoch 131/500, loss_fit = 71005.95, encoder_loss = 1.06.
# var_u: tensor([0.9946]), phi: tensor([0.7937])
#
# Epoch 132/500, loss_fit = 118898.22, encoder_loss = 1.05.
# var_u: tensor([0.9927]), phi: tensor([0.7959])
#
# Epoch 133/500, loss_fit = 108396.59, encoder_loss = 1.07.
# var_u: tensor([0.9932]), phi: tensor([0.7959])
#
# Epoch 134/500, loss_fit = 82971.10, encoder_loss = 1.04.
# var_u: tensor([0.9955]), phi: tensor([0.7976])
#
# Epoch 135/500, loss_fit = 77709.40, encoder_loss = 1.06.
# var_u: tensor([0.9957]), phi: tensor([0.8014])
#
# Epoch 136/500, loss_fit = 81930.79, encoder_loss = 1.05.
# var_u: tensor([0.9904]), phi: tensor([0.8016])
#
# Epoch 137/500, loss_fit = 70683.21, encoder_loss = 1.03.
# var_u: tensor([0.9954]), phi: tensor([0.8011])
#
# Epoch 138/500, loss_fit = 217095.08, encoder_loss = 1.04.
# var_u: tensor([0.9969]), phi: tensor([0.8033])
#
# Epoch 139/500, loss_fit = 95985.02, encoder_loss = 1.03.
# var_u: tensor([1.0031]), phi: tensor([0.8005])
#
# Epoch 140/500, loss_fit = 94137.40, encoder_loss = 1.08.
# var_u: tensor([1.0056]), phi: tensor([0.7992])
#
# Epoch 141/500, loss_fit = 167139.97, encoder_loss = 1.05.
# var_u: tensor([1.0063]), phi: tensor([0.7985])
#
# Epoch 142/500, loss_fit = 117223.70, encoder_loss = 1.08.
# var_u: tensor([1.0042]), phi: tensor([0.7950])
#
# Epoch 143/500, loss_fit = 103953.27, encoder_loss = 1.03.
# var_u: tensor([0.9994]), phi: tensor([0.7945])
#
# Epoch 144/500, loss_fit = 150990.67, encoder_loss = 1.05.
# var_u: tensor([0.9986]), phi: tensor([0.7939])
#
# Epoch 145/500, loss_fit = 166406.41, encoder_loss = 1.04.
# var_u: tensor([1.0071]), phi: tensor([0.7959])
#
# Epoch 146/500, loss_fit = 83738.79, encoder_loss = 1.06.
# var_u: tensor([1.0072]), phi: tensor([0.7967])
#
# Epoch 147/500, loss_fit = 135015.91, encoder_loss = 1.06.
# var_u: tensor([1.0032]), phi: tensor([0.7961])
#
# Epoch 148/500, loss_fit = 169160.39, encoder_loss = 1.07.
# var_u: tensor([1.0023]), phi: tensor([0.7966])
#
# Epoch 149/500, loss_fit = 112763.59, encoder_loss = 1.06.
# var_u: tensor([1.0096]), phi: tensor([0.7988])
#
# Epoch 150/500, loss_fit = 58831.10, encoder_loss = 1.03.
# var_u: tensor([1.0156]), phi: tensor([0.8007])
#
# Epoch 151/500, loss_fit = 90175.76, encoder_loss = 1.09.
# var_u: tensor([1.0141]), phi: tensor([0.7994])
#
# Epoch 152/500, loss_fit = 135226.55, encoder_loss = 1.07.
# var_u: tensor([1.0096]), phi: tensor([0.7999])
#
# Epoch 153/500, loss_fit = 192348.16, encoder_loss = 1.04.
# var_u: tensor([1.0115]), phi: tensor([0.7985])
#
# Epoch 154/500, loss_fit = 52557.76, encoder_loss = 1.06.
# var_u: tensor([1.0120]), phi: tensor([0.7948])
#
# Epoch 155/500, loss_fit = 139928.50, encoder_loss = 1.07.
# var_u: tensor([1.0193]), phi: tensor([0.7966])
#
# Epoch 156/500, loss_fit = 139963.89, encoder_loss = 1.06.
# var_u: tensor([1.0257]), phi: tensor([0.7952])
#
# Epoch 157/500, loss_fit = 174128.73, encoder_loss = 1.07.
# var_u: tensor([1.0194]), phi: tensor([0.7929])
#
# Epoch 158/500, loss_fit = 441728.88, encoder_loss = 1.08.
# var_u: tensor([1.0203]), phi: tensor([0.7924])
#
# Epoch 159/500, loss_fit = 84147.60, encoder_loss = 1.06.
# var_u: tensor([1.0286]), phi: tensor([0.7932])
#
# Epoch 160/500, loss_fit = 94497.52, encoder_loss = 1.07.
# var_u: tensor([1.0176]), phi: tensor([0.7977])
#
# Epoch 161/500, loss_fit = 137782.59, encoder_loss = 1.09.
# var_u: tensor([1.0180]), phi: tensor([0.8000])
#
# Epoch 162/500, loss_fit = 91747.34, encoder_loss = 1.08.
# var_u: tensor([1.0144]), phi: tensor([0.7974])
#
# Epoch 163/500, loss_fit = 109657.52, encoder_loss = 1.08.
# var_u: tensor([1.0147]), phi: tensor([0.7942])
#
# Epoch 164/500, loss_fit = 104683.66, encoder_loss = 1.06.
# var_u: tensor([1.0179]), phi: tensor([0.7919])
#
# Epoch 165/500, loss_fit = 252781.50, encoder_loss = 1.06.
# var_u: tensor([1.0113]), phi: tensor([0.7953])
#
# Epoch 166/500, loss_fit = 271140.50, encoder_loss = 1.09.
# var_u: tensor([1.0115]), phi: tensor([0.7972])
#
# Epoch 167/500, loss_fit = 68829.81, encoder_loss = 1.04.
# var_u: tensor([1.0102]), phi: tensor([0.7987])
#
# Epoch 168/500, loss_fit = 125906.79, encoder_loss = 1.06.
# var_u: tensor([1.0128]), phi: tensor([0.7989])
#
# Epoch 169/500, loss_fit = 227011.34, encoder_loss = 1.05.
# var_u: tensor([1.0086]), phi: tensor([0.7967])
#
# Epoch 170/500, loss_fit = 133433.17, encoder_loss = 1.05.
# var_u: tensor([1.0113]), phi: tensor([0.7989])
#
# Epoch 171/500, loss_fit = 93987.96, encoder_loss = 1.03.
# var_u: tensor([1.0110]), phi: tensor([0.8000])
#
# Epoch 172/500, loss_fit = 87123.63, encoder_loss = 1.06.
# var_u: tensor([1.0109]), phi: tensor([0.8018])
#
# Epoch 173/500, loss_fit = 124167.16, encoder_loss = 1.06.
# var_u: tensor([1.0072]), phi: tensor([0.8038])
#
# Epoch 174/500, loss_fit = 68424.27, encoder_loss = 1.07.
# var_u: tensor([1.0090]), phi: tensor([0.8021])
#
# Epoch 175/500, loss_fit = 104484.00, encoder_loss = 1.05.
# var_u: tensor([1.0123]), phi: tensor([0.8030])
#
# Epoch 176/500, loss_fit = 109459.07, encoder_loss = 1.06.
# var_u: tensor([1.0120]), phi: tensor([0.8016])
#
# Epoch 177/500, loss_fit = 101355.97, encoder_loss = 1.04.
# var_u: tensor([1.0112]), phi: tensor([0.8012])
#
# Epoch 178/500, loss_fit = 177781.75, encoder_loss = 1.08.
# var_u: tensor([1.0162]), phi: tensor([0.8008])
#
# Epoch 179/500, loss_fit = 141500.81, encoder_loss = 1.06.
# var_u: tensor([1.0183]), phi: tensor([0.7990])
#
# Epoch 180/500, loss_fit = 199634.00, encoder_loss = 1.04.
# var_u: tensor([1.0165]), phi: tensor([0.7999])
#
# Epoch 181/500, loss_fit = 187495.31, encoder_loss = 1.07.
# var_u: tensor([1.0167]), phi: tensor([0.8008])
#
# Epoch 182/500, loss_fit = 203542.86, encoder_loss = 1.05.
# var_u: tensor([1.0245]), phi: tensor([0.7998])
#
# Epoch 183/500, loss_fit = 99685.45, encoder_loss = 1.06.
# var_u: tensor([1.0285]), phi: tensor([0.8020])
#
# Epoch 184/500, loss_fit = 123421.46, encoder_loss = 1.05.
# var_u: tensor([1.0274]), phi: tensor([0.8024])
#
# Epoch 185/500, loss_fit = 113821.70, encoder_loss = 1.08.
# var_u: tensor([1.0214]), phi: tensor([0.8040])
#
# Epoch 186/500, loss_fit = 187909.27, encoder_loss = 1.05.
# var_u: tensor([1.0246]), phi: tensor([0.8016])
#
# Epoch 187/500, loss_fit = 54080.84, encoder_loss = 1.05.
# var_u: tensor([1.0297]), phi: tensor([0.7996])
#
# Epoch 188/500, loss_fit = 94133.63, encoder_loss = 1.05.
# var_u: tensor([1.0285]), phi: tensor([0.8016])
#
# Epoch 189/500, loss_fit = 250728.83, encoder_loss = 1.05.
# var_u: tensor([1.0265]), phi: tensor([0.7993])
#
# Epoch 190/500, loss_fit = 118437.61, encoder_loss = 1.07.
# var_u: tensor([1.0194]), phi: tensor([0.8001])
#
# Epoch 191/500, loss_fit = 121306.49, encoder_loss = 1.07.
# var_u: tensor([1.0277]), phi: tensor([0.8003])
#
# Epoch 192/500, loss_fit = 167659.61, encoder_loss = 1.09.
# var_u: tensor([1.0257]), phi: tensor([0.8014])
#
# Epoch 193/500, loss_fit = 122807.84, encoder_loss = 1.07.
# var_u: tensor([1.0333]), phi: tensor([0.7967])
#
# Epoch 194/500, loss_fit = 147478.22, encoder_loss = 1.06.
# var_u: tensor([1.0277]), phi: tensor([0.7951])
#
# Epoch 195/500, loss_fit = 135465.23, encoder_loss = 1.06.
# var_u: tensor([1.0324]), phi: tensor([0.7946])
#
# Epoch 196/500, loss_fit = 130179.48, encoder_loss = 1.05.
# var_u: tensor([1.0374]), phi: tensor([0.7964])
#
# Epoch 197/500, loss_fit = 163600.42, encoder_loss = 1.03.
# var_u: tensor([1.0449]), phi: tensor([0.7956])
#
# Epoch 198/500, loss_fit = 154862.58, encoder_loss = 1.06.
# var_u: tensor([1.0408]), phi: tensor([0.7955])
#
# Epoch 199/500, loss_fit = 101418.81, encoder_loss = 1.04.
# var_u: tensor([1.0410]), phi: tensor([0.7971])
#
# Epoch 200/500, loss_fit = 74536.91, encoder_loss = 1.05.
# var_u: tensor([1.0387]), phi: tensor([0.7983])
#
# Epoch 201/500, loss_fit = 89445.38, encoder_loss = 1.06.
# var_u: tensor([1.0360]), phi: tensor([0.7979])
#
# Epoch 202/500, loss_fit = 126697.66, encoder_loss = 1.04.
# var_u: tensor([1.0412]), phi: tensor([0.7938])
#
# Epoch 203/500, loss_fit = 84972.04, encoder_loss = 1.02.
# var_u: tensor([1.0404]), phi: tensor([0.7953])
#
# Epoch 204/500, loss_fit = 96501.51, encoder_loss = 1.04.
# var_u: tensor([1.0407]), phi: tensor([0.7950])
#
# Epoch 205/500, loss_fit = 60242.44, encoder_loss = 1.02.
# var_u: tensor([1.0345]), phi: tensor([0.7947])
#
# Epoch 206/500, loss_fit = 197912.33, encoder_loss = 1.03.
# var_u: tensor([1.0300]), phi: tensor([0.7934])
#
# Epoch 207/500, loss_fit = 97440.30, encoder_loss = 1.03.
# var_u: tensor([1.0265]), phi: tensor([0.7960])
#
# Epoch 208/500, loss_fit = 68886.61, encoder_loss = 1.01.
# var_u: tensor([1.0245]), phi: tensor([0.7969])
#
# Epoch 209/500, loss_fit = 51952.24, encoder_loss = 1.02.
# var_u: tensor([1.0240]), phi: tensor([0.7950])
#
# Epoch 210/500, loss_fit = 90709.89, encoder_loss = 1.00.
# var_u: tensor([1.0243]), phi: tensor([0.7937])
#
# Epoch 211/500, loss_fit = 85581.49, encoder_loss = 1.03.
# var_u: tensor([1.0250]), phi: tensor([0.7948])
#
# Epoch 212/500, loss_fit = 73305.12, encoder_loss = 1.03.
# var_u: tensor([1.0179]), phi: tensor([0.7941])
#
# Epoch 213/500, loss_fit = 96746.41, encoder_loss = 1.03.
# var_u: tensor([1.0141]), phi: tensor([0.7937])
#
# Epoch 214/500, loss_fit = 105021.85, encoder_loss = 1.04.
# var_u: tensor([1.0142]), phi: tensor([0.7936])
#
# Epoch 215/500, loss_fit = 92975.01, encoder_loss = 1.04.
# var_u: tensor([1.0127]), phi: tensor([0.7937])
#
# Epoch 216/500, loss_fit = 51982.05, encoder_loss = 1.02.
# var_u: tensor([1.0135]), phi: tensor([0.7920])
#
# Epoch 217/500, loss_fit = 123747.59, encoder_loss = 1.00.
# var_u: tensor([1.0180]), phi: tensor([0.7906])
#
# Epoch 218/500, loss_fit = 171539.31, encoder_loss = 1.00.
# var_u: tensor([1.0180]), phi: tensor([0.7907])
#
# Epoch 219/500, loss_fit = 100267.51, encoder_loss = 1.02.
# var_u: tensor([1.0125]), phi: tensor([0.7930])
#
# Epoch 220/500, loss_fit = 61600.95, encoder_loss = 1.00.
# var_u: tensor([1.0104]), phi: tensor([0.7956])
#
# Epoch 221/500, loss_fit = 90740.06, encoder_loss = 1.02.
# var_u: tensor([1.0118]), phi: tensor([0.7918])
#
# Epoch 222/500, loss_fit = 61136.80, encoder_loss = 0.98.
# var_u: tensor([1.0128]), phi: tensor([0.7927])
#
# Epoch 223/500, loss_fit = 60698.25, encoder_loss = 1.02.
# var_u: tensor([1.0117]), phi: tensor([0.7935])
#
# Epoch 224/500, loss_fit = 66999.62, encoder_loss = 1.03.
# var_u: tensor([1.0113]), phi: tensor([0.7935])
#
# Epoch 225/500, loss_fit = 119115.05, encoder_loss = 1.01.
# var_u: tensor([1.0129]), phi: tensor([0.7975])
#
# Epoch 226/500, loss_fit = 116835.88, encoder_loss = 1.03.
# var_u: tensor([1.0119]), phi: tensor([0.7974])
#
# Epoch 227/500, loss_fit = 64409.94, encoder_loss = 1.00.
# var_u: tensor([1.0175]), phi: tensor([0.7969])
#
# Epoch 228/500, loss_fit = 149855.20, encoder_loss = 0.98.
# var_u: tensor([1.0181]), phi: tensor([0.7960])
#
# Epoch 229/500, loss_fit = 134806.30, encoder_loss = 1.01.
# var_u: tensor([1.0188]), phi: tensor([0.7947])
#
# Epoch 230/500, loss_fit = 119206.12, encoder_loss = 1.02.
# var_u: tensor([1.0168]), phi: tensor([0.7962])
#
# Epoch 231/500, loss_fit = 88615.24, encoder_loss = 1.01.
# var_u: tensor([1.0152]), phi: tensor([0.7979])
#
# Epoch 232/500, loss_fit = 204980.64, encoder_loss = 1.00.
# var_u: tensor([1.0190]), phi: tensor([0.7997])
#
# Epoch 233/500, loss_fit = 83398.59, encoder_loss = 1.01.
# var_u: tensor([1.0221]), phi: tensor([0.7974])
#
# Epoch 234/500, loss_fit = 79696.41, encoder_loss = 1.05.
# var_u: tensor([1.0248]), phi: tensor([0.7964])
#
# Epoch 235/500, loss_fit = 74843.86, encoder_loss = 1.01.
# var_u: tensor([1.0187]), phi: tensor([0.7968])
#
# Epoch 236/500, loss_fit = 79908.94, encoder_loss = 1.01.
# var_u: tensor([1.0166]), phi: tensor([0.7980])
#
# Epoch 237/500, loss_fit = 149112.05, encoder_loss = 1.01.
# var_u: tensor([1.0120]), phi: tensor([0.7964])
#
# Epoch 238/500, loss_fit = 92107.02, encoder_loss = 1.01.
# var_u: tensor([1.0130]), phi: tensor([0.7954])
#
# Epoch 239/500, loss_fit = 79187.01, encoder_loss = 1.01.
# var_u: tensor([1.0107]), phi: tensor([0.7950])
#
# Epoch 240/500, loss_fit = 109668.01, encoder_loss = 1.05.
# var_u: tensor([1.0128]), phi: tensor([0.7953])
#
# Epoch 241/500, loss_fit = 62654.55, encoder_loss = 1.00.
# var_u: tensor([1.0074]), phi: tensor([0.7947])
#
# Epoch 242/500, loss_fit = 70716.38, encoder_loss = 1.01.
# var_u: tensor([1.0087]), phi: tensor([0.7973])
#
# Epoch 243/500, loss_fit = 112567.51, encoder_loss = 0.99.
# var_u: tensor([1.0086]), phi: tensor([0.7965])
#
# Epoch 244/500, loss_fit = 77558.93, encoder_loss = 1.03.
# var_u: tensor([1.0110]), phi: tensor([0.7966])
#
# Epoch 245/500, loss_fit = 109621.60, encoder_loss = 1.00.
# var_u: tensor([1.0074]), phi: tensor([0.7971])
#
# Epoch 246/500, loss_fit = 72658.26, encoder_loss = 1.00.
# var_u: tensor([1.0117]), phi: tensor([0.7945])
#
# Epoch 247/500, loss_fit = 91139.39, encoder_loss = 1.01.
# var_u: tensor([1.0107]), phi: tensor([0.7969])
#
# Epoch 248/500, loss_fit = 81673.43, encoder_loss = 1.00.
# var_u: tensor([1.0129]), phi: tensor([0.7938])
#
# Epoch 249/500, loss_fit = 101407.78, encoder_loss = 1.03.
# var_u: tensor([1.0185]), phi: tensor([0.7965])
#
# Epoch 250/500, loss_fit = 137273.84, encoder_loss = 1.03.
# var_u: tensor([1.0214]), phi: tensor([0.7958])
#
# Epoch 251/500, loss_fit = 102906.35, encoder_loss = 1.02.
# var_u: tensor([1.0253]), phi: tensor([0.7967])
#
# Epoch 252/500, loss_fit = 93392.51, encoder_loss = 1.01.
# var_u: tensor([1.0246]), phi: tensor([0.7982])
#
# Epoch 253/500, loss_fit = 70173.59, encoder_loss = 1.03.
# var_u: tensor([1.0237]), phi: tensor([0.7985])
#
# Epoch 254/500, loss_fit = 86542.63, encoder_loss = 1.05.
# var_u: tensor([1.0274]), phi: tensor([0.7964])
#
# Epoch 255/500, loss_fit = 94724.10, encoder_loss = 1.01.
# var_u: tensor([1.0260]), phi: tensor([0.7943])
#
# Epoch 256/500, loss_fit = 82101.92, encoder_loss = 1.03.
# var_u: tensor([1.0254]), phi: tensor([0.7947])
#
# Epoch 257/500, loss_fit = 97878.02, encoder_loss = 1.00.
# var_u: tensor([1.0300]), phi: tensor([0.7953])
#
# Epoch 258/500, loss_fit = 96071.90, encoder_loss = 1.03.
# var_u: tensor([1.0314]), phi: tensor([0.7958])
#
# Epoch 259/500, loss_fit = 84154.91, encoder_loss = 1.02.
# var_u: tensor([1.0244]), phi: tensor([0.7967])
#
# Epoch 260/500, loss_fit = 66307.68, encoder_loss = 1.04.
# var_u: tensor([1.0204]), phi: tensor([0.7945])
#
# Epoch 261/500, loss_fit = 105417.65, encoder_loss = 1.02.
# var_u: tensor([1.0221]), phi: tensor([0.7950])
#
# Epoch 262/500, loss_fit = 109499.67, encoder_loss = 1.01.
# var_u: tensor([1.0192]), phi: tensor([0.7962])
#
# Epoch 263/500, loss_fit = 84067.09, encoder_loss = 1.02.
# var_u: tensor([1.0192]), phi: tensor([0.7948])
#
# Epoch 264/500, loss_fit = 125408.70, encoder_loss = 1.04.
# var_u: tensor([1.0167]), phi: tensor([0.7961])
#
# Epoch 265/500, loss_fit = 134068.41, encoder_loss = 1.02.
# var_u: tensor([1.0182]), phi: tensor([0.7933])
#
# Epoch 266/500, loss_fit = 157319.47, encoder_loss = 1.01.
# var_u: tensor([1.0167]), phi: tensor([0.7923])
#
# Epoch 267/500, loss_fit = 134199.28, encoder_loss = 0.97.
# var_u: tensor([1.0135]), phi: tensor([0.7927])
#
# Epoch 268/500, loss_fit = 164639.64, encoder_loss = 0.97.
# var_u: tensor([1.0196]), phi: tensor([0.7921])
#
# Epoch 269/500, loss_fit = 111041.29, encoder_loss = 0.98.
# var_u: tensor([1.0127]), phi: tensor([0.7899])
#
# Epoch 270/500, loss_fit = 162466.08, encoder_loss = 0.98.
# var_u: tensor([1.0139]), phi: tensor([0.7906])
#
# Epoch 271/500, loss_fit = 64821.76, encoder_loss = 0.98.
# var_u: tensor([1.0108]), phi: tensor([0.7898])
#
# Epoch 272/500, loss_fit = 147580.05, encoder_loss = 0.97.
# var_u: tensor([1.0145]), phi: tensor([0.7910])
#
# Epoch 273/500, loss_fit = 77258.35, encoder_loss = 0.98.
# var_u: tensor([1.0116]), phi: tensor([0.7928])
#
# Epoch 274/500, loss_fit = 77412.32, encoder_loss = 1.00.
# var_u: tensor([1.0142]), phi: tensor([0.7910])
#
# Epoch 275/500, loss_fit = 99496.27, encoder_loss = 0.98.
# var_u: tensor([1.0161]), phi: tensor([0.7924])
#
# Epoch 276/500, loss_fit = 74868.99, encoder_loss = 0.98.
# var_u: tensor([1.0114]), phi: tensor([0.7910])
#
# Epoch 277/500, loss_fit = 110053.10, encoder_loss = 0.99.
# var_u: tensor([1.0105]), phi: tensor([0.7919])
#
# Epoch 278/500, loss_fit = 75822.45, encoder_loss = 1.00.
# var_u: tensor([1.0033]), phi: tensor([0.7922])
#
# Epoch 279/500, loss_fit = 109289.30, encoder_loss = 0.97.
# var_u: tensor([1.0050]), phi: tensor([0.7916])
#
# Epoch 280/500, loss_fit = 78924.90, encoder_loss = 0.99.
# var_u: tensor([1.0071]), phi: tensor([0.7922])
#
# Epoch 281/500, loss_fit = 435617.12, encoder_loss = 0.97.
# var_u: tensor([1.0117]), phi: tensor([0.7941])
#
# Epoch 282/500, loss_fit = 118558.75, encoder_loss = 0.94.
# var_u: tensor([1.0109]), phi: tensor([0.7952])
#
# Epoch 283/500, loss_fit = 119903.62, encoder_loss = 0.97.
# var_u: tensor([1.0145]), phi: tensor([0.7956])
#
# Epoch 284/500, loss_fit = 175931.08, encoder_loss = 0.96.
# var_u: tensor([1.0124]), phi: tensor([0.7964])
#
# Epoch 285/500, loss_fit = 135774.84, encoder_loss = 0.95.
# var_u: tensor([1.0175]), phi: tensor([0.7948])
#
# Epoch 286/500, loss_fit = 61996.16, encoder_loss = 0.97.
# var_u: tensor([1.0206]), phi: tensor([0.7951])
#
# Epoch 287/500, loss_fit = 85488.05, encoder_loss = 0.97.
# var_u: tensor([1.0253]), phi: tensor([0.7958])
#
# Epoch 288/500, loss_fit = 115796.55, encoder_loss = 1.01.
# var_u: tensor([1.0314]), phi: tensor([0.7977])
#
# Epoch 289/500, loss_fit = 89850.98, encoder_loss = 0.98.
# var_u: tensor([1.0293]), phi: tensor([0.7961])
#
# Epoch 290/500, loss_fit = 78869.62, encoder_loss = 1.02.
# var_u: tensor([1.0320]), phi: tensor([0.7972])
#
# Epoch 291/500, loss_fit = 114740.34, encoder_loss = 0.99.
# var_u: tensor([1.0313]), phi: tensor([0.7970])
#
# Epoch 292/500, loss_fit = 126286.42, encoder_loss = 0.97.
# var_u: tensor([1.0344]), phi: tensor([0.7962])
#
# Epoch 293/500, loss_fit = 111302.16, encoder_loss = 0.98.
# var_u: tensor([1.0344]), phi: tensor([0.7969])
#
# Epoch 294/500, loss_fit = 173556.81, encoder_loss = 0.98.
# var_u: tensor([1.0360]), phi: tensor([0.7957])
#
# Epoch 295/500, loss_fit = 80842.93, encoder_loss = 0.99.
# var_u: tensor([1.0338]), phi: tensor([0.7938])
#
# Epoch 296/500, loss_fit = 126618.93, encoder_loss = 0.96.
# var_u: tensor([1.0317]), phi: tensor([0.7953])
#
# Epoch 297/500, loss_fit = 108040.61, encoder_loss = 0.98.
# var_u: tensor([1.0325]), phi: tensor([0.7945])
#
# Epoch 298/500, loss_fit = 81412.17, encoder_loss = 0.97.
# var_u: tensor([1.0264]), phi: tensor([0.7900])
#
# Epoch 299/500, loss_fit = 73924.99, encoder_loss = 0.98.
# var_u: tensor([1.0269]), phi: tensor([0.7938])
#
# Epoch 300/500, loss_fit = 153845.47, encoder_loss = 0.97.
# var_u: tensor([1.0298]), phi: tensor([0.7956])
#
# Epoch 301/500, loss_fit = 162796.94, encoder_loss = 1.01.
# var_u: tensor([1.0233]), phi: tensor([0.7970])
#
# Epoch 302/500, loss_fit = 116264.75, encoder_loss = 0.99.
# var_u: tensor([1.0190]), phi: tensor([0.7981])
#
# Epoch 303/500, loss_fit = 90063.77, encoder_loss = 0.97.
# var_u: tensor([1.0150]), phi: tensor([0.8000])
#
# Epoch 304/500, loss_fit = 112241.24, encoder_loss = 0.99.
# var_u: tensor([1.0127]), phi: tensor([0.8036])
#
# Epoch 305/500, loss_fit = 93312.59, encoder_loss = 0.97.
# var_u: tensor([1.0167]), phi: tensor([0.8029])
#
# Epoch 306/500, loss_fit = 182221.97, encoder_loss = 0.96.
# var_u: tensor([1.0163]), phi: tensor([0.8024])
#
# Epoch 307/500, loss_fit = 107288.46, encoder_loss = 0.98.
# var_u: tensor([1.0168]), phi: tensor([0.8021])
#
# Epoch 308/500, loss_fit = 72866.98, encoder_loss = 0.96.
# var_u: tensor([1.0169]), phi: tensor([0.7987])
#
# Epoch 309/500, loss_fit = 52851.34, encoder_loss = 0.98.
# var_u: tensor([1.0205]), phi: tensor([0.8003])
#
# Epoch 310/500, loss_fit = 93004.16, encoder_loss = 0.98.
# var_u: tensor([1.0274]), phi: tensor([0.7986])
#
# Epoch 311/500, loss_fit = 57611.00, encoder_loss = 0.96.
# var_u: tensor([1.0252]), phi: tensor([0.7977])
#
# Epoch 312/500, loss_fit = 62378.16, encoder_loss = 0.97.
# var_u: tensor([1.0188]), phi: tensor([0.7985])
#
# Epoch 313/500, loss_fit = 116663.95, encoder_loss = 1.00.
# var_u: tensor([1.0191]), phi: tensor([0.7983])
#
# Epoch 314/500, loss_fit = 70635.70, encoder_loss = 0.98.
# var_u: tensor([1.0158]), phi: tensor([0.8001])
#
# Epoch 315/500, loss_fit = 191762.73, encoder_loss = 1.00.
# var_u: tensor([1.0175]), phi: tensor([0.7989])
#
# Epoch 316/500, loss_fit = 79355.59, encoder_loss = 0.97.
# var_u: tensor([1.0172]), phi: tensor([0.7963])
#
# Epoch 317/500, loss_fit = 73576.70, encoder_loss = 0.96.
# var_u: tensor([1.0141]), phi: tensor([0.7926])
#
# Epoch 318/500, loss_fit = 67411.49, encoder_loss = 0.94.
# var_u: tensor([1.0180]), phi: tensor([0.7908])
#
# Epoch 319/500, loss_fit = 74833.91, encoder_loss = 0.98.
# var_u: tensor([1.0216]), phi: tensor([0.7892])
#
# Epoch 320/500, loss_fit = 120214.27, encoder_loss = 0.96.
# var_u: tensor([1.0202]), phi: tensor([0.7867])
#
# Epoch 321/500, loss_fit = 74652.99, encoder_loss = 0.99.
# var_u: tensor([1.0170]), phi: tensor([0.7889])
#
# Epoch 322/500, loss_fit = 87701.79, encoder_loss = 0.98.
# var_u: tensor([1.0193]), phi: tensor([0.7920])
#
# Epoch 323/500, loss_fit = 69137.05, encoder_loss = 0.98.
# var_u: tensor([1.0176]), phi: tensor([0.7950])
#
# Epoch 324/500, loss_fit = 81224.76, encoder_loss = 0.97.
# var_u: tensor([1.0251]), phi: tensor([0.7942])
#
# Epoch 325/500, loss_fit = 84925.99, encoder_loss = 0.95.
# var_u: tensor([1.0226]), phi: tensor([0.7953])
#
# Epoch 326/500, loss_fit = 66033.14, encoder_loss = 0.96.
# var_u: tensor([1.0190]), phi: tensor([0.7957])
#
# Epoch 327/500, loss_fit = 92140.30, encoder_loss = 0.96.
# var_u: tensor([1.0191]), phi: tensor([0.7962])
#
# Epoch 328/500, loss_fit = 115990.00, encoder_loss = 0.95.
# var_u: tensor([1.0206]), phi: tensor([0.7985])
#
# Epoch 329/500, loss_fit = 76760.41, encoder_loss = 0.96.
# var_u: tensor([1.0214]), phi: tensor([0.7970])
#
# Epoch 330/500, loss_fit = 63219.78, encoder_loss = 0.97.
# var_u: tensor([1.0215]), phi: tensor([0.7951])
#
# Epoch 331/500, loss_fit = 140860.52, encoder_loss = 0.94.
# var_u: tensor([1.0211]), phi: tensor([0.7957])
#
# Epoch 332/500, loss_fit = 153610.91, encoder_loss = 0.99.
# var_u: tensor([1.0202]), phi: tensor([0.7961])
#
# Epoch 333/500, loss_fit = 66652.66, encoder_loss = 0.96.
# var_u: tensor([1.0212]), phi: tensor([0.7956])
#
# Epoch 334/500, loss_fit = 122922.27, encoder_loss = 0.99.
# var_u: tensor([1.0200]), phi: tensor([0.7958])
#
# Epoch 335/500, loss_fit = 180669.83, encoder_loss = 0.97.
# var_u: tensor([1.0175]), phi: tensor([0.7944])
#
# Epoch 336/500, loss_fit = 106527.52, encoder_loss = 0.96.
# var_u: tensor([1.0162]), phi: tensor([0.7996])
#
# Epoch 337/500, loss_fit = 115268.55, encoder_loss = 0.99.
# var_u: tensor([1.0166]), phi: tensor([0.7990])
#
# Epoch 338/500, loss_fit = 62379.74, encoder_loss = 0.94.
# var_u: tensor([1.0172]), phi: tensor([0.7976])
#
# Epoch 339/500, loss_fit = 89908.71, encoder_loss = 0.96.
# var_u: tensor([1.0183]), phi: tensor([0.7939])
#
# Epoch 340/500, loss_fit = 123935.80, encoder_loss = 0.96.
# var_u: tensor([1.0203]), phi: tensor([0.7917])
#
# Epoch 341/500, loss_fit = 88616.18, encoder_loss = 0.97.
# var_u: tensor([1.0164]), phi: tensor([0.7911])
#
# Epoch 342/500, loss_fit = 133273.59, encoder_loss = 0.98.
# var_u: tensor([1.0189]), phi: tensor([0.7953])
#
# Epoch 343/500, loss_fit = 66805.63, encoder_loss = 0.96.
# var_u: tensor([1.0221]), phi: tensor([0.7951])
#
# Epoch 344/500, loss_fit = 169873.72, encoder_loss = 0.97.
# var_u: tensor([1.0214]), phi: tensor([0.7964])
#
# Epoch 345/500, loss_fit = 80885.21, encoder_loss = 0.97.
# var_u: tensor([1.0213]), phi: tensor([0.7965])
#
# Epoch 346/500, loss_fit = 88919.06, encoder_loss = 0.96.
# var_u: tensor([1.0184]), phi: tensor([0.7952])
#
# Epoch 347/500, loss_fit = 57994.99, encoder_loss = 0.96.
# var_u: tensor([1.0222]), phi: tensor([0.7928])
#
# Epoch 348/500, loss_fit = 172641.41, encoder_loss = 0.95.
# var_u: tensor([1.0177]), phi: tensor([0.7931])
#
# Epoch 349/500, loss_fit = 101704.94, encoder_loss = 0.96.
# var_u: tensor([1.0209]), phi: tensor([0.7931])
#
# Epoch 350/500, loss_fit = 76237.05, encoder_loss = 1.01.
# var_u: tensor([1.0208]), phi: tensor([0.7953])
#
# Epoch 351/500, loss_fit = 58720.26, encoder_loss = 0.96.
# var_u: tensor([1.0224]), phi: tensor([0.7943])
#
# Epoch 352/500, loss_fit = 65695.75, encoder_loss = 0.98.
# var_u: tensor([1.0270]), phi: tensor([0.7952])
#
# Epoch 353/500, loss_fit = 81220.91, encoder_loss = 0.97.
# var_u: tensor([1.0268]), phi: tensor([0.7957])
#
# Epoch 354/500, loss_fit = 79251.85, encoder_loss = 0.96.
# var_u: tensor([1.0288]), phi: tensor([0.7949])
#
# Epoch 355/500, loss_fit = 81644.33, encoder_loss = 0.96.
# var_u: tensor([1.0324]), phi: tensor([0.7957])
#
# Epoch 356/500, loss_fit = 121071.06, encoder_loss = 0.95.
# var_u: tensor([1.0390]), phi: tensor([0.7953])
#
# Epoch 357/500, loss_fit = 118870.45, encoder_loss = 0.98.
# var_u: tensor([1.0364]), phi: tensor([0.7957])
#
# Epoch 358/500, loss_fit = 131547.14, encoder_loss = 0.99.
# var_u: tensor([1.0386]), phi: tensor([0.7966])
#
# Epoch 359/500, loss_fit = 152559.44, encoder_loss = 0.99.
# var_u: tensor([1.0401]), phi: tensor([0.7968])
#
# Epoch 360/500, loss_fit = 102200.08, encoder_loss = 0.97.
# var_u: tensor([1.0361]), phi: tensor([0.7948])
#
# Epoch 361/500, loss_fit = 56321.48, encoder_loss = 0.99.
# var_u: tensor([1.0371]), phi: tensor([0.7958])
#
# Epoch 362/500, loss_fit = 112623.44, encoder_loss = 0.96.
# var_u: tensor([1.0330]), phi: tensor([0.7927])
#
# Epoch 363/500, loss_fit = 91280.88, encoder_loss = 0.95.
# var_u: tensor([1.0383]), phi: tensor([0.7918])
#
# Epoch 364/500, loss_fit = 89482.04, encoder_loss = 1.00.
# var_u: tensor([1.0353]), phi: tensor([0.7939])
#
# Epoch 365/500, loss_fit = 118096.72, encoder_loss = 1.00.
# var_u: tensor([1.0303]), phi: tensor([0.7943])
#
# Epoch 366/500, loss_fit = 98722.72, encoder_loss = 0.97.
# var_u: tensor([1.0276]), phi: tensor([0.7915])
#
# Epoch 367/500, loss_fit = 89560.35, encoder_loss = 0.98.
# var_u: tensor([1.0239]), phi: tensor([0.7907])
#
# Epoch 368/500, loss_fit = 84565.66, encoder_loss = 0.97.
# var_u: tensor([1.0217]), phi: tensor([0.7879])
#
# Epoch 369/500, loss_fit = 86007.70, encoder_loss = 0.98.
# var_u: tensor([1.0218]), phi: tensor([0.7894])
#
# Epoch 370/500, loss_fit = 116391.87, encoder_loss = 0.94.
# var_u: tensor([1.0216]), phi: tensor([0.7926])
#
# Epoch 371/500, loss_fit = 72538.20, encoder_loss = 0.98.
# var_u: tensor([1.0218]), phi: tensor([0.7914])
#
# Epoch 372/500, loss_fit = 93122.50, encoder_loss = 0.95.
# var_u: tensor([1.0258]), phi: tensor([0.7906])
#
# Epoch 373/500, loss_fit = 100937.56, encoder_loss = 0.96.
# var_u: tensor([1.0256]), phi: tensor([0.7920])
#
# Epoch 374/500, loss_fit = 91650.70, encoder_loss = 0.97.
# var_u: tensor([1.0283]), phi: tensor([0.7944])
#
# Epoch 375/500, loss_fit = 75211.99, encoder_loss = 0.98.
# var_u: tensor([1.0322]), phi: tensor([0.7972])
#
# Epoch 376/500, loss_fit = 78214.64, encoder_loss = 0.99.
# var_u: tensor([1.0299]), phi: tensor([0.7983])
#
# Epoch 377/500, loss_fit = 113905.30, encoder_loss = 0.97.
# var_u: tensor([1.0257]), phi: tensor([0.7994])
#
# Epoch 378/500, loss_fit = 62513.48, encoder_loss = 0.98.
# var_u: tensor([1.0222]), phi: tensor([0.7991])
#
# Epoch 379/500, loss_fit = 63902.60, encoder_loss = 0.97.
# var_u: tensor([1.0262]), phi: tensor([0.7976])
#
# Epoch 380/500, loss_fit = 142534.12, encoder_loss = 0.97.
# var_u: tensor([1.0308]), phi: tensor([0.7948])
#
# Epoch 381/500, loss_fit = 74012.80, encoder_loss = 0.96.
# var_u: tensor([1.0327]), phi: tensor([0.7972])
#
# Epoch 382/500, loss_fit = 85084.13, encoder_loss = 0.97.
# var_u: tensor([1.0285]), phi: tensor([0.7975])
#
# Epoch 383/500, loss_fit = 131563.59, encoder_loss = 0.97.
# var_u: tensor([1.0325]), phi: tensor([0.7974])
#
# Epoch 384/500, loss_fit = 67551.02, encoder_loss = 0.94.
# var_u: tensor([1.0321]), phi: tensor([0.7985])
#
# Epoch 385/500, loss_fit = 74652.23, encoder_loss = 0.92.
# var_u: tensor([1.0346]), phi: tensor([0.7950])
#
# Epoch 386/500, loss_fit = 135981.23, encoder_loss = 0.96.
# var_u: tensor([1.0363]), phi: tensor([0.7954])
#
# Epoch 387/500, loss_fit = 111437.62, encoder_loss = 0.98.
# var_u: tensor([1.0341]), phi: tensor([0.7956])
#
# Epoch 388/500, loss_fit = 139594.23, encoder_loss = 0.98.
# var_u: tensor([1.0351]), phi: tensor([0.7960])
#
# Epoch 389/500, loss_fit = 81132.20, encoder_loss = 0.98.
# var_u: tensor([1.0354]), phi: tensor([0.7949])
#
# Epoch 390/500, loss_fit = 81682.26, encoder_loss = 0.95.
# var_u: tensor([1.0300]), phi: tensor([0.7931])
#
# Epoch 391/500, loss_fit = 151700.69, encoder_loss = 0.94.
# var_u: tensor([1.0271]), phi: tensor([0.7938])
#
# Epoch 392/500, loss_fit = 116845.33, encoder_loss = 0.96.
# var_u: tensor([1.0288]), phi: tensor([0.7962])
#
# Epoch 393/500, loss_fit = 109211.24, encoder_loss = 0.96.
# var_u: tensor([1.0277]), phi: tensor([0.7952])
#
# Epoch 394/500, loss_fit = 116819.30, encoder_loss = 0.96.
# var_u: tensor([1.0311]), phi: tensor([0.7946])
#
# Epoch 395/500, loss_fit = 197838.94, encoder_loss = 0.94.
# var_u: tensor([1.0273]), phi: tensor([0.7950])
#
# Epoch 396/500, loss_fit = 115976.45, encoder_loss = 0.95.
# var_u: tensor([1.0306]), phi: tensor([0.7934])
#
# Epoch 397/500, loss_fit = 82421.30, encoder_loss = 0.94.
# var_u: tensor([1.0318]), phi: tensor([0.7925])
#
# Epoch 398/500, loss_fit = 113491.93, encoder_loss = 0.94.
# var_u: tensor([1.0333]), phi: tensor([0.7940])
#
# Epoch 399/500, loss_fit = 138432.45, encoder_loss = 0.93.
# var_u: tensor([1.0306]), phi: tensor([0.7903])
#
# Epoch 400/500, loss_fit = 96602.20, encoder_loss = 0.93.
# var_u: tensor([1.0306]), phi: tensor([0.7909])
#
# Epoch 401/500, loss_fit = 78267.61, encoder_loss = 0.95.
# var_u: tensor([1.0320]), phi: tensor([0.7914])
#
# Epoch 402/500, loss_fit = 83615.59, encoder_loss = 0.92.
# var_u: tensor([1.0305]), phi: tensor([0.7921])
#
# Epoch 403/500, loss_fit = 66972.48, encoder_loss = 0.92.
# var_u: tensor([1.0318]), phi: tensor([0.7916])
#
# Epoch 404/500, loss_fit = 70633.85, encoder_loss = 0.95.
# var_u: tensor([1.0340]), phi: tensor([0.7924])
#
# Epoch 405/500, loss_fit = 94599.30, encoder_loss = 0.93.
# var_u: tensor([1.0334]), phi: tensor([0.7919])
#
# Epoch 406/500, loss_fit = 85939.02, encoder_loss = 0.94.
# var_u: tensor([1.0330]), phi: tensor([0.7896])
#
# Epoch 407/500, loss_fit = 113294.32, encoder_loss = 0.92.
# var_u: tensor([1.0320]), phi: tensor([0.7906])
#
# Epoch 408/500, loss_fit = 70797.91, encoder_loss = 0.94.
# var_u: tensor([1.0288]), phi: tensor([0.7904])
#
# Epoch 409/500, loss_fit = 65334.68, encoder_loss = 0.94.
# var_u: tensor([1.0307]), phi: tensor([0.7901])
#
# Epoch 410/500, loss_fit = 108377.95, encoder_loss = 0.95.
# var_u: tensor([1.0258]), phi: tensor([0.7920])
#
# Epoch 411/500, loss_fit = 68455.80, encoder_loss = 0.92.
# var_u: tensor([1.0323]), phi: tensor([0.7901])
#
# Epoch 412/500, loss_fit = 97218.16, encoder_loss = 0.94.
# var_u: tensor([1.0250]), phi: tensor([0.7888])
#
# Epoch 413/500, loss_fit = 83685.80, encoder_loss = 0.93.
# var_u: tensor([1.0279]), phi: tensor([0.7898])
#
# Epoch 414/500, loss_fit = 113866.92, encoder_loss = 0.91.
# var_u: tensor([1.0261]), phi: tensor([0.7896])
#
# Epoch 415/500, loss_fit = 69259.15, encoder_loss = 0.93.
# var_u: tensor([1.0252]), phi: tensor([0.7888])
#
# Epoch 416/500, loss_fit = 51229.51, encoder_loss = 0.94.
# var_u: tensor([1.0270]), phi: tensor([0.7892])
#
# Epoch 417/500, loss_fit = 51787.43, encoder_loss = 0.92.
# var_u: tensor([1.0257]), phi: tensor([0.7895])
#
# Epoch 418/500, loss_fit = 74670.95, encoder_loss = 0.93.
# var_u: tensor([1.0268]), phi: tensor([0.7896])
#
# Epoch 419/500, loss_fit = 118756.18, encoder_loss = 0.92.
# var_u: tensor([1.0272]), phi: tensor([0.7918])
#
# Epoch 420/500, loss_fit = 67807.34, encoder_loss = 0.90.
# var_u: tensor([1.0293]), phi: tensor([0.7897])
#
# Epoch 421/500, loss_fit = 77066.91, encoder_loss = 0.94.
# var_u: tensor([1.0303]), phi: tensor([0.7878])
#
# Epoch 422/500, loss_fit = 93448.24, encoder_loss = 0.93.
# var_u: tensor([1.0303]), phi: tensor([0.7870])
#
# Epoch 423/500, loss_fit = 129787.00, encoder_loss = 0.93.
# var_u: tensor([1.0337]), phi: tensor([0.7876])
#
# Epoch 424/500, loss_fit = 111534.34, encoder_loss = 0.91.
# var_u: tensor([1.0337]), phi: tensor([0.7892])
#
# Epoch 425/500, loss_fit = 71109.56, encoder_loss = 0.93.
# var_u: tensor([1.0345]), phi: tensor([0.7879])
#
# Epoch 426/500, loss_fit = 315956.72, encoder_loss = 0.91.
# var_u: tensor([1.0307]), phi: tensor([0.7879])
#
# Epoch 427/500, loss_fit = 110476.17, encoder_loss = 0.93.
# var_u: tensor([1.0288]), phi: tensor([0.7906])
#
# Epoch 428/500, loss_fit = 103286.73, encoder_loss = 0.93.
# var_u: tensor([1.0314]), phi: tensor([0.7889])
#
# Epoch 429/500, loss_fit = 90134.31, encoder_loss = 0.95.
# var_u: tensor([1.0237]), phi: tensor([0.7928])
#
# Epoch 430/500, loss_fit = 78084.63, encoder_loss = 0.94.
# var_u: tensor([1.0243]), phi: tensor([0.7922])
#
# Epoch 431/500, loss_fit = 273127.22, encoder_loss = 0.91.
# var_u: tensor([1.0221]), phi: tensor([0.7945])
#
# Epoch 432/500, loss_fit = 70588.28, encoder_loss = 0.92.
# var_u: tensor([1.0254]), phi: tensor([0.7937])
#
# Epoch 433/500, loss_fit = 92209.45, encoder_loss = 0.92.
# var_u: tensor([1.0235]), phi: tensor([0.7928])
#
# Epoch 434/500, loss_fit = 58705.59, encoder_loss = 0.94.
# var_u: tensor([1.0213]), phi: tensor([0.7937])
#
# Epoch 435/500, loss_fit = 98601.98, encoder_loss = 0.89.
# var_u: tensor([1.0188]), phi: tensor([0.7945])
#
# Epoch 436/500, loss_fit = 126646.41, encoder_loss = 0.95.
# var_u: tensor([1.0168]), phi: tensor([0.7931])
#
# Epoch 437/500, loss_fit = 102995.23, encoder_loss = 0.93.
# var_u: tensor([1.0163]), phi: tensor([0.7940])
#
# Epoch 438/500, loss_fit = 80659.02, encoder_loss = 0.92.
# var_u: tensor([1.0162]), phi: tensor([0.7944])
#
# Epoch 439/500, loss_fit = 112090.31, encoder_loss = 0.95.
# var_u: tensor([1.0178]), phi: tensor([0.7974])
#
# Epoch 440/500, loss_fit = 103307.69, encoder_loss = 0.91.
# var_u: tensor([1.0178]), phi: tensor([0.7982])
#
# Epoch 441/500, loss_fit = 91611.38, encoder_loss = 0.91.
# var_u: tensor([1.0152]), phi: tensor([0.7971])
#
# Epoch 442/500, loss_fit = 101781.77, encoder_loss = 0.90.
# var_u: tensor([1.0126]), phi: tensor([0.7936])
#
# Epoch 443/500, loss_fit = 77533.76, encoder_loss = 0.90.
# var_u: tensor([1.0083]), phi: tensor([0.7924])
#
# Epoch 444/500, loss_fit = 76900.06, encoder_loss = 0.89.
# var_u: tensor([1.0076]), phi: tensor([0.7945])
#
# Epoch 445/500, loss_fit = 102588.06, encoder_loss = 0.90.
# var_u: tensor([1.0163]), phi: tensor([0.7936])
#
# Epoch 446/500, loss_fit = 104591.12, encoder_loss = 0.90.
# var_u: tensor([1.0165]), phi: tensor([0.7937])
#
# Epoch 447/500, loss_fit = 74657.10, encoder_loss = 0.92.
# var_u: tensor([1.0181]), phi: tensor([0.7915])
#
# Epoch 448/500, loss_fit = 58703.73, encoder_loss = 0.92.
# var_u: tensor([1.0184]), phi: tensor([0.7930])
#
# Epoch 449/500, loss_fit = 90756.61, encoder_loss = 0.92.
# var_u: tensor([1.0215]), phi: tensor([0.7941])
#
# Epoch 450/500, loss_fit = 78870.09, encoder_loss = 0.90.
# var_u: tensor([1.0210]), phi: tensor([0.7946])
#
# Epoch 451/500, loss_fit = 93218.84, encoder_loss = 0.94.
# var_u: tensor([1.0142]), phi: tensor([0.7933])
#
# Epoch 452/500, loss_fit = 83491.68, encoder_loss = 0.90.
# var_u: tensor([1.0157]), phi: tensor([0.7917])
#
# Epoch 453/500, loss_fit = 103181.55, encoder_loss = 0.91.
# var_u: tensor([1.0181]), phi: tensor([0.7925])
#
# Epoch 454/500, loss_fit = 155859.45, encoder_loss = 0.92.
# var_u: tensor([1.0172]), phi: tensor([0.7932])
#
# Epoch 455/500, loss_fit = 147770.75, encoder_loss = 0.91.
# var_u: tensor([1.0156]), phi: tensor([0.7946])
#
# Epoch 456/500, loss_fit = 100612.75, encoder_loss = 0.91.
# var_u: tensor([1.0164]), phi: tensor([0.7921])
#
# Epoch 457/500, loss_fit = 94687.28, encoder_loss = 0.92.
# var_u: tensor([1.0141]), phi: tensor([0.7931])
#
# Epoch 458/500, loss_fit = 137423.42, encoder_loss = 0.90.
# var_u: tensor([1.0144]), phi: tensor([0.7897])
#
# Epoch 459/500, loss_fit = 330581.47, encoder_loss = 0.91.
# var_u: tensor([1.0167]), phi: tensor([0.7911])
#
# Epoch 460/500, loss_fit = 77651.54, encoder_loss = 0.92.
# var_u: tensor([1.0232]), phi: tensor([0.7914])
#
# Epoch 461/500, loss_fit = 75095.68, encoder_loss = 0.90.
# var_u: tensor([1.0254]), phi: tensor([0.7909])
#
# Epoch 462/500, loss_fit = 63132.11, encoder_loss = 0.93.
# var_u: tensor([1.0306]), phi: tensor([0.7890])
#
# Epoch 463/500, loss_fit = 59439.67, encoder_loss = 0.91.
# var_u: tensor([1.0295]), phi: tensor([0.7881])
#
# Epoch 464/500, loss_fit = 86172.67, encoder_loss = 0.91.
# var_u: tensor([1.0312]), phi: tensor([0.7914])
#
# Epoch 465/500, loss_fit = 48487.03, encoder_loss = 0.94.
# var_u: tensor([1.0265]), phi: tensor([0.7883])
#
# Epoch 466/500, loss_fit = 73199.58, encoder_loss = 0.92.
# var_u: tensor([1.0206]), phi: tensor([0.7885])
#
# Epoch 467/500, loss_fit = 96668.95, encoder_loss = 0.91.
# var_u: tensor([1.0200]), phi: tensor([0.7880])
#
# Epoch 468/500, loss_fit = 61455.95, encoder_loss = 0.94.
# var_u: tensor([1.0198]), phi: tensor([0.7883])
#
# Epoch 469/500, loss_fit = 92397.28, encoder_loss = 0.93.
# var_u: tensor([1.0215]), phi: tensor([0.7882])
#
# Epoch 470/500, loss_fit = 138427.78, encoder_loss = 0.92.
# var_u: tensor([1.0228]), phi: tensor([0.7914])
#
# Epoch 471/500, loss_fit = 51465.92, encoder_loss = 0.90.
# var_u: tensor([1.0241]), phi: tensor([0.7903])
#
# Epoch 472/500, loss_fit = 60185.34, encoder_loss = 0.92.
# var_u: tensor([1.0225]), phi: tensor([0.7899])
#
# Epoch 473/500, loss_fit = 110561.09, encoder_loss = 0.91.
# var_u: tensor([1.0182]), phi: tensor([0.7921])
#
# Epoch 474/500, loss_fit = 51359.11, encoder_loss = 0.93.
# var_u: tensor([1.0168]), phi: tensor([0.7927])
#
# Epoch 475/500, loss_fit = 66698.12, encoder_loss = 0.93.
# var_u: tensor([1.0168]), phi: tensor([0.7945])
#
# Epoch 476/500, loss_fit = 159286.78, encoder_loss = 0.92.
# var_u: tensor([1.0160]), phi: tensor([0.7930])
#
# Epoch 477/500, loss_fit = 116045.58, encoder_loss = 0.93.
# var_u: tensor([1.0161]), phi: tensor([0.7929])
#
# Epoch 478/500, loss_fit = 68312.76, encoder_loss = 0.92.
# var_u: tensor([1.0185]), phi: tensor([0.7934])
#
# Epoch 479/500, loss_fit = 78216.01, encoder_loss = 0.92.
# var_u: tensor([1.0178]), phi: tensor([0.7935])
#
# Epoch 480/500, loss_fit = 73740.87, encoder_loss = 0.91.
# var_u: tensor([1.0232]), phi: tensor([0.7929])
#
# Epoch 481/500, loss_fit = 54484.91, encoder_loss = 0.92.
# var_u: tensor([1.0227]), phi: tensor([0.7938])
#
# Epoch 482/500, loss_fit = 143323.61, encoder_loss = 0.93.
# var_u: tensor([1.0199]), phi: tensor([0.7940])
#
# Epoch 483/500, loss_fit = 122891.16, encoder_loss = 0.92.
# var_u: tensor([1.0204]), phi: tensor([0.7975])
#
# Epoch 484/500, loss_fit = 103143.93, encoder_loss = 0.92.
# var_u: tensor([1.0233]), phi: tensor([0.7956])
#
# Epoch 485/500, loss_fit = 111545.16, encoder_loss = 0.93.
# var_u: tensor([1.0248]), phi: tensor([0.7942])
#
# Epoch 486/500, loss_fit = 94456.52, encoder_loss = 0.90.
# var_u: tensor([1.0261]), phi: tensor([0.7937])
#
# Epoch 487/500, loss_fit = 161869.25, encoder_loss = 0.90.
# var_u: tensor([1.0229]), phi: tensor([0.7931])
#
# Epoch 488/500, loss_fit = 115231.32, encoder_loss = 0.91.
# var_u: tensor([1.0290]), phi: tensor([0.7928])
#
# Epoch 489/500, loss_fit = 73065.80, encoder_loss = 0.93.
# var_u: tensor([1.0327]), phi: tensor([0.7919])
#
# Epoch 490/500, loss_fit = 66248.63, encoder_loss = 0.93.
# var_u: tensor([1.0307]), phi: tensor([0.7932])
#
# Epoch 491/500, loss_fit = 83788.64, encoder_loss = 0.93.
# var_u: tensor([1.0256]), phi: tensor([0.7904])
#
# Epoch 492/500, loss_fit = 190917.70, encoder_loss = 0.92.
# var_u: tensor([1.0249]), phi: tensor([0.7891])
#
# Epoch 493/500, loss_fit = 122424.42, encoder_loss = 0.90.
# var_u: tensor([1.0211]), phi: tensor([0.7899])
#
# Epoch 494/500, loss_fit = 54393.93, encoder_loss = 0.93.
# var_u: tensor([1.0182]), phi: tensor([0.7910])
#
# Epoch 495/500, loss_fit = 71380.84, encoder_loss = 0.91.
# var_u: tensor([1.0184]), phi: tensor([0.7929])
#
# Epoch 496/500, loss_fit = 64715.03, encoder_loss = 0.93.
# var_u: tensor([1.0176]), phi: tensor([0.7942])
#
# Epoch 497/500, loss_fit = 54545.49, encoder_loss = 0.92.
# var_u: tensor([1.0173]), phi: tensor([0.7941])
#
# Epoch 498/500, loss_fit = 59212.64, encoder_loss = 0.91.
# var_u: tensor([1.0210]), phi: tensor([0.7939])
#
# Epoch 499/500, loss_fit = 71404.91, encoder_loss = 0.91.
# var_u: tensor([1.0159]), phi: tensor([0.7940])
#
# Epoch 500/500, loss_fit = 34314.20, encoder_loss = 0.88.

# %%
plt.plot(learning_rates)
plt.plot(learning_rates_encoder)

# %%
data = np.stack([tensor.flatten().numpy() for tensor in param_values], axis=0)


# Create figure and axes
fig, ax = plt.subplots()

# Loop through each feature
for i in range(data.shape[1]):
    ax.plot(data[:, i])

# Add legend and labels
ax.legend()
plt.xlabel('Time period')
plt.ylabel('Feature value')
plt.title('Evolution of features over time')

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(model_sample.decoder.wz.detach().numpy(), model.decoder.wz.detach().numpy())
plt.plot([-3,3], [-3,3], color="red")
plt.plot([-3,3], [3,-3], color="red")
plt.show()

plt.scatter(model_sample.decoder.wx.detach().numpy(), model.decoder.wx.detach().numpy())
plt.plot([-3,3], [-3,3], color="red")
plt.plot([-3,3], [3,-3], color="red")
plt.show()

# %%
model.encoder.plot(data_sample['x'], data_sample['y'], data_sample['z'], data_sample['u'])

# %%
dat1 = torch.reshape(model_sample.sample(x=data_sample['x'])['y'].detach(), (data_sample['y'].shape[0], -1))
cor1 = np.corrcoef(dat1, rowvar=False)
dat2 = torch.reshape(model.sample(x=data_sample['x'])['y'].detach(), (data_sample['y'].shape[0], -1))
cor2 = np.corrcoef(dat2, rowvar=False)

plt.scatter(cor1, cor2)
plt.show()

# %%
model.sample()['y']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 model.sample()['y']
#
# File c:\Users\Willwhite\AppData\Local\miniconda\envs\pytorch\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# TypeError: Sample.forward() missing 1 required positional argument: 'x'

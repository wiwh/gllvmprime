# %% [markdown]
# # GLLVM Longitudinal

# %%
import torch
from torch import nn
from torch.optim.lr_scheduler import StepLR # scheduler
import numpy as np
import seaborn as sns
import math
import matplotlib.pyplot as plt
import copy

# %% [markdown]
# A Longitudinal GLLVM is a model with 1 variable per period for T periods, n observations, and p responses, and k covariates. We also have a random effect for each observation x response.

# %%
n = 1000
p = 13
q = 1
k = 3
T = 9

DIMENSIONS_Y = (n, T, p) 
DIMENSIONS_X = (n, T, k)
DIMENSIONS_Z = (n, T, q)
DIMENSIONS_U = (n, 1, p)

# %%
response_types = {
    'binary': [0,1,2,3,4,5,6,7],
    'ordinal': [9, 10],
    'counts': [8, 11, 12]
}

response_types = {
    'binary': [0,1,2,3,4,5,6,7, 9, 10],
    'counts': [8, 11, 12]
}

link = {
    'binary' : lambda x: torch.logit(x),
    'ordinal': lambda x: torch.logit(x),
    'counts': lambda x: torch.log(x)
}


linkinv = {
    'binary': lambda x: 1/(1+torch.exp(-x)),
    'ordinal': lambda x: 1/(1+torch.exp(-x)),
    'counts': lambda x: torch.exp(x)
}

response_transform = {
    'binary' : lambda x: 2*x - 1,
    'ordinal': lambda x: 2*x - 1,
    'counts': lambda x: torch.log(x+1)
}

# %% [markdown]
# They can be of many response types. Here for the sake of illutration we will consider 3 response types: gaussian, binary, and poisson.
#
# We allow for transformation of the data, which we account for in the estimation. In particular, Poisson data may be numerically problematic because their conditional expectation is the exponential of the linear predictor. Small differences in the latter can result in dramatic differences in the gradient. For instance, we can transform poisson with the following function $x \rightarrow \log(x+1)$. This transforms is needed in 2 places: for encoding, and at the loss function for computing the gradient.
#
# ## Computing the scale parameter
#
# The scale parameter is computed in a second step (on the fit residual). They are updated at every iteration. This is not yet implemented.
#
#
# ### Modules
#
# We need LongitudinalGLLVM as the overarching module, Sample which samples the data and takes additional arguments (such as nuisance parameters), Decoder which contains all the parameters of interest, and Encoder which encodes the data using a Neural Network.
#
# ### Design of the Encoder
# Since the estimation problem for Z is the same at each time step, we model the encoder using a RNN. At each time step, the same encoder is used to compute the Z. At the same time, the hidden state of the RNN is used to predict the U variable, which is constant over time for each observation.

# %%
class LongitudinalGLLVM(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
        self.sample = Sample(self.decoder)
    
    def plot_cov(self, what="linpar", x=None):
        data_sample = self.sample(x=x)
        data =  data_sample[what].detach().view(n, -1).numpy()
        cov_matrix = np.cov(data, rowvar=False)

        plt.figure(figsize=(10,10))
        sns.heatmap(cov_matrix, annot=False, fmt='g')
        plt.show()

class Sample(nn.Module):
    def __init__(self, decoder):
        super().__init__()
        self.decoder = decoder
        self.phi = torch.ones(1) * 0.5
        self.var_u = torch.ones(1) * 1.5

    # sampling comes here
    
    def forward(self, x):
        with torch.no_grad():
            if x is None:
                Warning("x was set to None for sampling. X is usually fixed. Are you sure you want to sample x?")
                x = torch.randn((n, T, k))

            u = torch.randn((n, 1, p)) * torch.sqrt(self.var_u)
            d = torch.randn((n, T, q))
            z = self.AR(d)

            linpar, mean = self.decoder(x, z, u) # decoder gives the expectation

            y = self.sample_response(mean)

            return {"x":x, "y":y, "z":z, "u":u, "linpar":linpar, "mean":mean}

    def sample_response(self, mean):
            y = torch.zeros_like(mean)
            for response_type, response_id in response_types.items():
                if response_type == "binary":
                    y[:,:,response_id] = torch.bernoulli(mean[:,:,response_id])
                elif response_type == "ordinal":
                    cum_probs = mean[:,:,response_id]
                    # draw one uniform for the whole vector
                    random = torch.rand((*cum_probs.shape[0:2], 1)) 
                    # compare with the cumulative probabilities
                    ordinal = torch.sum(random > cum_probs, dim=2)
                    ordinal = torch.nn.functional.one_hot(ordinal).squeeze().float()
                    ordinal = ordinal[:,:,1:] # discard the first column of the one_hot encoding, as it is superfluous (as a 0)
                    y[:,:,response_id] = ordinal
                elif response_type == "counts":
                    y[:,:,response_id] = torch.poisson(mean[:,:,response_id])
            return y

    def AR(self, d):
        z = d.clone()

        for t in range(1, z.shape[1]):
            z[:,t] = z[:,t] + z[:, t-1].clone() * self.phi  # we need to clone else the gradient wants to pass through it
        return z
                
    
class Decoder(nn.Module):
    # Yields the expectation
    def __init__(self):
        super().__init__()

        # decoder part (our parameters of interest)
        self.wz = nn.Parameter(torch.randn((q, p)))
        self.wx = nn.Parameter(torch.randn((T, k, p)))
        self.bias = nn.Parameter(torch.zeros((1, T, p)))

    # decoding (computing the conditional mean)
    def forward(self, x, z, u):

        xwx = (x.unsqueeze(2) @ self.wx).squeeze() # see section "details of tensorproducts"
        zwz = (z.unsqueeze(2) @ self.wz).squeeze()
        # for the ordinal variables:
        linpar = self.bias + xwx + zwz + u 

        # Apply the inverse link to get the conditional expectation
        mean  = torch.zeros_like(linpar)
        for response_type, response_id in response_types.items():
            mean[:,:,response_id] = linkinv[response_type](linpar[:,:,response_id])
        # Transform the 
        return linpar, mean



class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        # encoder part
        # input dimension is (p+k) (responses + covariates)
        # output dimension is q+p (one latent )
        input_size = p + k
        hidden_size = (p + q) * 5
        self.rnn = nn.RNN(input_size = input_size, hidden_size = hidden_size, batch_first=True)
        
        self.fc = nn.Sequential(
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
        )
        # fully connected layers for Z and U
        self.fc_Z = nn.Sequential(
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = q),
        )

        self.fc_U = nn.Sequential(
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features=hidden_size, out_features = p)
        )

        self.optimizer =  torch.optim.Adam(self.parameters(), lr=.01)
        self.scheduler = StepLR(self.optimizer, step_size=100, gamma=.95)
        self.loss = nn.MSELoss()

    
    def forward(self, x, y, transform_response = False):
        # Initialize hidden state

        # pass the input through the RNN
        if transform_response:
            y_transformed = torch.zeros_like(y)
            with torch.no_grad():
                for response_type, response_id in response_types.items():
                    y_transformed[:,:,response_id] = response_transform[response_type](y[:,:,response_id])
        else:
            y_transformed = y

        xy = torch.cat([x, y_transformed], dim=2)
        rnn_out, _ = self.rnn(xy)
        out = self.fc(rnn_out)
        z_pred = self.fc_Z(out)
        u_pred = self.fc_U(out[:, -1, :]).unsqueeze(1)
        return z_pred, u_pred
    
    def fit(self, x, y, z, u, epochs = 100, verbose = False):
        y = y.clone()
        with torch.no_grad():
            for response_type, response_id in response_types.items():
                y[:,:,response_id] = response_transform[response_type](y[:,:,response_id])
        # Fit the encoder
        for epoch in range(epochs):
            self.optimizer.zero_grad()

            z_pred, u_pred = self(x, y, transform_response = False)

            loss = self.loss(z_pred, z) + self.loss(u_pred, u)

            if verbose:
                print(f"\nEpoch {epoch}/{epochs}, loss={loss}")
            loss.backward()
            self.optimizer.step()
            self.scheduler.step()

        return loss
    
    def plot(self, x, y, z, u):
        with torch.no_grad():
            z_pred, u_pred = self(x, y, transform_response = True)

        fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,4))

        ax1.scatter(z, z_pred)
        ax1.set_xlabel('Z True')
        ax1.set_ylabel('Z Pred')
        ax1.set_title('Encoded values of Z')
        ax1.plot(ax1.get_xlim(), ax1.get_ylim(), ls="--", color="red")

        ax2.scatter(u, u_pred)
        ax2.set_xlabel('U True')
        ax2.set_ylabel('U Pred')
        ax2.set_title('Encoded values of U')
        ax2.plot(ax2.get_xlim(), ax2.get_ylim(), ls="--", color="red")


        plt.show()
        


class MELoss(nn.Module):
    def __init__(self):
        super().__init__()
    
    def forward(self, y, linpar, ys, linpars):
        """Computes the loss. hat is recontructed y, ys is simulated"""
        y_transformed = torch.zeros_like(y)
        ys_transformed = torch.zeros_like(ys)
        with torch.no_grad():
            for response_type, response_id in response_types.items():
                y_transformed[:,:,response_id] = response_transform[response_type](y[:,:,response_id])
                ys_transformed[:,:,response_id] = response_transform[response_type](ys[:,:,response_id])


        return -torch.mean(y_transformed* linpar - ys_transformed * linpars) * y.shape[1] * y.shape[2]
        # return torch.mean(torch.pow(y-linpar, 2) - torch.pow(ys - linpars, 2))
        # loss = torch.mean(y.T @ linpar - ys.T @linpars)/y.shape[0]
        # return loss

# %%
model_sample = LongitudinalGLLVM()

# %%
model_sample.plot_cov("linpar", x=None)

# %%
data_sample = model_sample.sample(x = None)

# %%
model_sample.encoder.fit(data_sample['x'], data_sample['y'], data_sample['z'], data_sample['u'], epochs = 10, verbose=True)
# Out:
# Epoch 0/10, loss=2.7973365783691406
#
# Epoch 1/10, loss=2.7501511573791504
#
# Epoch 2/10, loss=2.5735905170440674
#
# Epoch 3/10, loss=2.2970666885375977
#
# Epoch 4/10, loss=2.295571804046631
#
# Epoch 5/10, loss=3.4736483097076416
#
# Epoch 6/10, loss=2.1796388626098633
#
# Epoch 7/10, loss=2.495009422302246
#
# Epoch 8/10, loss=2.2899115085601807
#
# Epoch 9/10, loss=2.2975850105285645
# tensor(2.2976, grad_fn=<AddBackward0>)

# %%
data_example = model_sample.sample(x=data_sample['x'])
model_sample.encoder.plot(data_sample['x'], data_sample['y'], data_sample['z'], data_sample['u'])
model_sample.encoder.plot(data_example['x'], data_example['y'], data_example['z'], data_example['u'])

# %%
model = LongitudinalGLLVM()
criterion = MELoss()
optimizer = torch.optim.Adam(model.decoder.parameters(), lr=.1)
scheduler = StepLR(optimizer, step_size=10, gamma=.95)
mseLoss = nn.MSELoss()
epochs = 500

def compute_autocorr(z):
    lagged_data = z[:,:-1, 0]
    shifted_data = z[:,1:, 0]
    autocorr = torch.mean(torch.sum(lagged_data * shifted_data, dim=1) / torch.sum(shifted_data ** 2, dim=1))
    return autocorr

# %%
losses = []
learning_rates = []
learning_rates_encoder = []
param_values = []

for epoch in range(1, epochs +1):
    optimizer.zero_grad()

    # impute and sample
    with torch.no_grad():
        # data_true["y"] = model.impute(data_true["x"], data_true["y"], mask=mask["y"], nsteps=5)
        # simulate data from the current parameter values, Unconditionally (!)
        data_sim = model.sample(x=data_sample["x"])
        
        assert torch.eq(data_sim["x"], data_sample["x"]).all().item()

        # compute the imputing values without the gradients
        zhat_sample, uhat_sample = model.encoder(data_sample["x"], data_sample["y"], transform_response=True)
        zhat_sim, uhat_sim = model.encoder(data_sim["x"], data_sim["y"], transform_response=True)


    # train the encoder on the simulated data
    encoder_loss = model.encoder.fit(data_sim["x"], data_sim["y"], data_sim["z"], data_sim["u"],  epochs= 5) 
    
    # compute the decoded value
    linpar_sample, mean_sample = model.decoder(data_sample["x"], zhat_sample, uhat_sample)
    linpar_sim, mean_sim = model.decoder(data_sim["x"], zhat_sim, uhat_sim)


    # model.decoder.wz.grad = mygrad
    loss = criterion(data_sample["y"], linpar_sample,  data_sim["y"], linpar_sim)
    loss.backward()

    # Update nuisance parameters
    with torch.no_grad():
        model.sample.var_u = .95* model.sample.var_u + .05 * torch.var(uhat_sample) * (model.sample.var_u / torch.var(uhat_sim))
        model.sample.phi = .95 * model.sample.phi + .05 * compute_autocorr(zhat_sample) * model.sample.phi / compute_autocorr(zhat_sim)
        if model.sample.phi > .9:
            model.sample.phi = torch.ones(1) * .9 
        # model.sample.phi = zhat_sample[:,1:,:] - zhat_sample[:,:-1,:]
        print(f'var_u: {model.sample.var_u}, phi: {model.sample.phi}')

    # Comparison with the theoretical gradient 
    # ----------------------------------------

    #     # compute the gradient
    # y = torch.zeros_like(data_sim["y"])
    # ys = torch.zeros_like(data_sim["y"])
    # with torch.no_grad():
    #     for response_type, response_id in response_types.items():
    #         y[:,response_id] = response_transform[response_type](data_sample["y"][:,response_id])
    #         ys[:,response_id] = response_transform[response_type](data_sim["y"][:,response_id])



    # mygrad =  -(y.T @ zhat_sample - ys.T @ zhat_sim)/data_sample["y"].shape[0]
    # grad_loss = model.decoder.wz.grad.clone().detach()

    # plt.scatter(mygrad, grad_loss)
    # plt.plot([-.05, .05], [-.05,.05], color="red")
    # plt.show()

    with torch.no_grad():   
        fit = mseLoss(mean_sample, data_sample["y"])
    
    
    # for param in model.decoder.parameters():
    #     if param.grad is not None:
    #         param.grad.clamp_(-100, 100)


    optimizer.step()
    scheduler.step()

    losses.append(fit.item())
    learning_rates.append(optimizer.param_groups[0]['lr'])
    learning_rates_encoder.append(model.encoder.optimizer.param_groups[0]['lr'])
    param_values.append(model.decoder.wz.clone().detach())

    print(f"\nEpoch {epoch}/{epochs}, loss_fit = {fit.item():.2f}, encoder_loss = {encoder_loss.item():.2f}.")
# Out:
# var_u: tensor([1.5000]), phi: tensor([0.5000])
#
# Epoch 1/500, loss_fit = 42514.18, encoder_loss = 2.14.
# var_u: tensor([1.4806]), phi: tensor([0.4948])
#
# Epoch 2/500, loss_fit = 49564.84, encoder_loss = 2.00.
# var_u: tensor([1.4604]), phi: tensor([0.4889])
#
# Epoch 3/500, loss_fit = 37149.12, encoder_loss = 1.91.
# var_u: tensor([1.4576]), phi: tensor([0.4835])
#
# Epoch 4/500, loss_fit = 35573.17, encoder_loss = 1.86.
# var_u: tensor([1.4572]), phi: tensor([0.4793])
#
# Epoch 5/500, loss_fit = 34805.72, encoder_loss = 1.84.
# var_u: tensor([1.4545]), phi: tensor([0.4737])
#
# Epoch 6/500, loss_fit = 34810.02, encoder_loss = 1.81.
# var_u: tensor([1.4520]), phi: tensor([0.4701])
#
# Epoch 7/500, loss_fit = 35034.95, encoder_loss = 1.75.
# var_u: tensor([1.4525]), phi: tensor([0.4682])
#
# Epoch 8/500, loss_fit = 42430.55, encoder_loss = 1.74.
# var_u: tensor([1.4514]), phi: tensor([0.4658])
#
# Epoch 9/500, loss_fit = 57282.40, encoder_loss = 1.72.
# var_u: tensor([1.4513]), phi: tensor([0.4646])
#
# Epoch 10/500, loss_fit = 41660.89, encoder_loss = 1.71.
# var_u: tensor([1.4482]), phi: tensor([0.4640])
#
# Epoch 11/500, loss_fit = 46646.19, encoder_loss = 1.71.
# var_u: tensor([1.4463]), phi: tensor([0.4642])
#
# Epoch 12/500, loss_fit = 48370.38, encoder_loss = 1.65.
# var_u: tensor([1.4449]), phi: tensor([0.4643])
#
# Epoch 13/500, loss_fit = 57840.77, encoder_loss = 1.64.
# var_u: tensor([1.4415]), phi: tensor([0.4650])
#
# Epoch 14/500, loss_fit = 42318.25, encoder_loss = 1.60.
# var_u: tensor([1.4378]), phi: tensor([0.4655])
#
# Epoch 15/500, loss_fit = 44668.18, encoder_loss = 1.55.
# var_u: tensor([1.4356]), phi: tensor([0.4662])
#
# Epoch 16/500, loss_fit = 46716.82, encoder_loss = 1.55.
# var_u: tensor([1.4347]), phi: tensor([0.4662])
#
# Epoch 17/500, loss_fit = 46039.41, encoder_loss = 1.52.
# var_u: tensor([1.4341]), phi: tensor([0.4662])
#
# Epoch 18/500, loss_fit = 52637.74, encoder_loss = 1.49.
# var_u: tensor([1.4335]), phi: tensor([0.4667])
#
# Epoch 19/500, loss_fit = 31789.79, encoder_loss = 1.44.
# var_u: tensor([1.4310]), phi: tensor([0.4666])
#
# Epoch 20/500, loss_fit = 35307.38, encoder_loss = 1.42.
# var_u: tensor([1.4292]), phi: tensor([0.4672])
#
# Epoch 21/500, loss_fit = 29947.68, encoder_loss = 1.38.
# var_u: tensor([1.4283]), phi: tensor([0.4674])
#
# Epoch 22/500, loss_fit = 29393.21, encoder_loss = 1.39.
# var_u: tensor([1.4259]), phi: tensor([0.4678])
#
# Epoch 23/500, loss_fit = 24165.56, encoder_loss = 1.38.
# var_u: tensor([1.4252]), phi: tensor([0.4683])
#
# Epoch 24/500, loss_fit = 25913.33, encoder_loss = 1.41.
# var_u: tensor([1.4247]), phi: tensor([0.4688])
#
# Epoch 25/500, loss_fit = 22931.77, encoder_loss = 1.39.
# var_u: tensor([1.4248]), phi: tensor([0.4689])
#
# Epoch 26/500, loss_fit = 26398.01, encoder_loss = 1.36.
# var_u: tensor([1.4243]), phi: tensor([0.4696])
#
# Epoch 27/500, loss_fit = 21734.40, encoder_loss = 1.34.
# var_u: tensor([1.4242]), phi: tensor([0.4694])
#
# Epoch 28/500, loss_fit = 26421.48, encoder_loss = 1.33.
# var_u: tensor([1.4232]), phi: tensor([0.4700])
#
# Epoch 29/500, loss_fit = 20678.30, encoder_loss = 1.32.
# var_u: tensor([1.4221]), phi: tensor([0.4705])
#
# Epoch 30/500, loss_fit = 21496.84, encoder_loss = 1.31.
# var_u: tensor([1.4229]), phi: tensor([0.4713])
#
# Epoch 31/500, loss_fit = 20697.06, encoder_loss = 1.33.
# var_u: tensor([1.4248]), phi: tensor([0.4718])
#
# Epoch 32/500, loss_fit = 23214.78, encoder_loss = 1.40.
# var_u: tensor([1.4241]), phi: tensor([0.4721])
#
# Epoch 33/500, loss_fit = 24784.30, encoder_loss = 1.37.
# var_u: tensor([1.4257]), phi: tensor([0.4726])
#
# Epoch 34/500, loss_fit = 23966.82, encoder_loss = 1.33.
# var_u: tensor([1.4265]), phi: tensor([0.4724])
#
# Epoch 35/500, loss_fit = 24353.37, encoder_loss = 1.30.
# var_u: tensor([1.4279]), phi: tensor([0.4733])
#
# Epoch 36/500, loss_fit = 20583.00, encoder_loss = 1.29.
# var_u: tensor([1.4284]), phi: tensor([0.4738])
#
# Epoch 37/500, loss_fit = 22091.13, encoder_loss = 1.29.
# var_u: tensor([1.4289]), phi: tensor([0.4742])
#
# Epoch 38/500, loss_fit = 24307.89, encoder_loss = 1.25.
# var_u: tensor([1.4309]), phi: tensor([0.4749])
#
# Epoch 39/500, loss_fit = 20677.36, encoder_loss = 1.28.
# var_u: tensor([1.4332]), phi: tensor([0.4751])
#
# Epoch 40/500, loss_fit = 19370.56, encoder_loss = 1.28.
# var_u: tensor([1.4338]), phi: tensor([0.4754])
#
# Epoch 41/500, loss_fit = 20282.92, encoder_loss = 1.28.
# var_u: tensor([1.4344]), phi: tensor([0.4757])
#
# Epoch 42/500, loss_fit = 20802.70, encoder_loss = 1.26.
# var_u: tensor([1.4355]), phi: tensor([0.4757])
#
# Epoch 43/500, loss_fit = 25884.94, encoder_loss = 1.31.
# var_u: tensor([1.4378]), phi: tensor([0.4760])
#
# Epoch 44/500, loss_fit = 21244.31, encoder_loss = 1.29.
# var_u: tensor([1.4391]), phi: tensor([0.4770])
#
# Epoch 45/500, loss_fit = 23364.81, encoder_loss = 1.28.
# var_u: tensor([1.4403]), phi: tensor([0.4773])
#
# Epoch 46/500, loss_fit = 23287.43, encoder_loss = 1.23.
# var_u: tensor([1.4416]), phi: tensor([0.4779])
#
# Epoch 47/500, loss_fit = 19730.43, encoder_loss = 1.23.
# var_u: tensor([1.4410]), phi: tensor([0.4783])
#
# Epoch 48/500, loss_fit = 20803.70, encoder_loss = 1.23.
# var_u: tensor([1.4408]), phi: tensor([0.4787])
#
# Epoch 49/500, loss_fit = 21799.69, encoder_loss = 1.22.
# var_u: tensor([1.4426]), phi: tensor([0.4792])
#
# Epoch 50/500, loss_fit = 16439.85, encoder_loss = 1.21.
# var_u: tensor([1.4433]), phi: tensor([0.4798])
#
# Epoch 51/500, loss_fit = 15675.06, encoder_loss = 1.26.
# var_u: tensor([1.4452]), phi: tensor([0.4798])
#
# Epoch 52/500, loss_fit = 18967.94, encoder_loss = 1.24.
# var_u: tensor([1.4452]), phi: tensor([0.4800])
#
# Epoch 53/500, loss_fit = 24732.77, encoder_loss = 1.31.
# var_u: tensor([1.4461]), phi: tensor([0.4798])
#
# Epoch 54/500, loss_fit = 22906.27, encoder_loss = 1.30.
# var_u: tensor([1.4462]), phi: tensor([0.4805])
#
# Epoch 55/500, loss_fit = 22464.40, encoder_loss = 1.28.
# var_u: tensor([1.4460]), phi: tensor([0.4809])
#
# Epoch 56/500, loss_fit = 19927.55, encoder_loss = 1.25.
# var_u: tensor([1.4469]), phi: tensor([0.4814])
#
# Epoch 57/500, loss_fit = 17548.93, encoder_loss = 1.24.
# var_u: tensor([1.4472]), phi: tensor([0.4817])
#
# Epoch 58/500, loss_fit = 18012.96, encoder_loss = 1.20.
# var_u: tensor([1.4480]), phi: tensor([0.4820])
#
# Epoch 59/500, loss_fit = 18614.57, encoder_loss = 1.19.
# var_u: tensor([1.4490]), phi: tensor([0.4822])
#
# Epoch 60/500, loss_fit = 17698.09, encoder_loss = 1.18.
# var_u: tensor([1.4496]), phi: tensor([0.4823])
#
# Epoch 61/500, loss_fit = 16038.16, encoder_loss = 1.20.
# var_u: tensor([1.4499]), phi: tensor([0.4827])
#
# Epoch 62/500, loss_fit = 14910.55, encoder_loss = 1.21.
# var_u: tensor([1.4520]), phi: tensor([0.4833])
#
# Epoch 63/500, loss_fit = 18764.75, encoder_loss = 1.24.
# var_u: tensor([1.4533]), phi: tensor([0.4836])
#
# Epoch 64/500, loss_fit = 17869.34, encoder_loss = 1.22.
# var_u: tensor([1.4534]), phi: tensor([0.4840])
#
# Epoch 65/500, loss_fit = 15452.43, encoder_loss = 1.24.
# var_u: tensor([1.4543]), phi: tensor([0.4840])
#
# Epoch 66/500, loss_fit = 17875.95, encoder_loss = 1.21.
# var_u: tensor([1.4549]), phi: tensor([0.4842])
#
# Epoch 67/500, loss_fit = 18413.51, encoder_loss = 1.20.
# var_u: tensor([1.4544]), phi: tensor([0.4848])
#
# Epoch 68/500, loss_fit = 18116.98, encoder_loss = 1.19.
# var_u: tensor([1.4560]), phi: tensor([0.4851])
#
# Epoch 69/500, loss_fit = 18043.16, encoder_loss = 1.18.
# var_u: tensor([1.4549]), phi: tensor([0.4850])
#
# Epoch 70/500, loss_fit = 17616.40, encoder_loss = 1.24.
# var_u: tensor([1.4554]), phi: tensor([0.4852])
#
# Epoch 71/500, loss_fit = 19992.60, encoder_loss = 1.22.
# var_u: tensor([1.4563]), phi: tensor([0.4853])
#
# Epoch 72/500, loss_fit = 21101.63, encoder_loss = 1.22.
# var_u: tensor([1.4564]), phi: tensor([0.4855])
#
# Epoch 73/500, loss_fit = 19031.13, encoder_loss = 1.19.
# var_u: tensor([1.4564]), phi: tensor([0.4856])
#
# Epoch 74/500, loss_fit = 16622.33, encoder_loss = 1.28.
# var_u: tensor([1.4560]), phi: tensor([0.4861])
#
# Epoch 75/500, loss_fit = 15540.47, encoder_loss = 1.26.
# var_u: tensor([1.4555]), phi: tensor([0.4868])
#
# Epoch 76/500, loss_fit = 19841.67, encoder_loss = 1.24.
# var_u: tensor([1.4546]), phi: tensor([0.4864])
#
# Epoch 77/500, loss_fit = 17995.93, encoder_loss = 1.25.
# var_u: tensor([1.4546]), phi: tensor([0.4869])
#
# Epoch 78/500, loss_fit = 20701.65, encoder_loss = 1.20.
# var_u: tensor([1.4548]), phi: tensor([0.4872])
#
# Epoch 79/500, loss_fit = 16723.84, encoder_loss = 1.20.
# var_u: tensor([1.4553]), phi: tensor([0.4874])
#
# Epoch 80/500, loss_fit = 18550.78, encoder_loss = 1.16.
# var_u: tensor([1.4551]), phi: tensor([0.4875])
#
# Epoch 81/500, loss_fit = 16485.51, encoder_loss = 1.20.
# var_u: tensor([1.4551]), phi: tensor([0.4873])
#
# Epoch 82/500, loss_fit = 16014.71, encoder_loss = 1.18.
# var_u: tensor([1.4551]), phi: tensor([0.4874])
#
# Epoch 83/500, loss_fit = 17370.49, encoder_loss = 1.17.
# var_u: tensor([1.4550]), phi: tensor([0.4876])
#
# Epoch 84/500, loss_fit = 16520.97, encoder_loss = 1.21.
# var_u: tensor([1.4556]), phi: tensor([0.4880])
#
# Epoch 85/500, loss_fit = 16901.88, encoder_loss = 1.20.
# var_u: tensor([1.4558]), phi: tensor([0.4880])
#
# Epoch 86/500, loss_fit = 16144.82, encoder_loss = 1.20.
# var_u: tensor([1.4564]), phi: tensor([0.4881])
#
# Epoch 87/500, loss_fit = 20356.98, encoder_loss = 1.21.
# var_u: tensor([1.4559]), phi: tensor([0.4883])
#
# Epoch 88/500, loss_fit = 15945.89, encoder_loss = 1.19.
# var_u: tensor([1.4562]), phi: tensor([0.4882])
#
# Epoch 89/500, loss_fit = 15632.64, encoder_loss = 1.19.
# var_u: tensor([1.4567]), phi: tensor([0.4886])
#
# Epoch 90/500, loss_fit = 17146.59, encoder_loss = 1.20.
# var_u: tensor([1.4579]), phi: tensor([0.4889])
#
# Epoch 91/500, loss_fit = 14434.02, encoder_loss = 1.17.
# var_u: tensor([1.4591]), phi: tensor([0.4893])
#
# Epoch 92/500, loss_fit = 15574.04, encoder_loss = 1.21.
# var_u: tensor([1.4597]), phi: tensor([0.4893])
#
# Epoch 93/500, loss_fit = 14150.03, encoder_loss = 1.19.
# var_u: tensor([1.4603]), phi: tensor([0.4895])
#
# Epoch 94/500, loss_fit = 20956.08, encoder_loss = 1.17.
# var_u: tensor([1.4603]), phi: tensor([0.4894])
#
# Epoch 95/500, loss_fit = 16178.90, encoder_loss = 1.15.
# var_u: tensor([1.4605]), phi: tensor([0.4893])
#
# Epoch 96/500, loss_fit = 14590.63, encoder_loss = 1.19.
# var_u: tensor([1.4603]), phi: tensor([0.4894])
#
# Epoch 97/500, loss_fit = 17605.44, encoder_loss = 1.15.
# var_u: tensor([1.4611]), phi: tensor([0.4897])
#
# Epoch 98/500, loss_fit = 16051.99, encoder_loss = 1.15.
# var_u: tensor([1.4617]), phi: tensor([0.4897])
#
# Epoch 99/500, loss_fit = 18170.20, encoder_loss = 1.17.
# var_u: tensor([1.4619]), phi: tensor([0.4903])
#
# Epoch 100/500, loss_fit = 15621.54, encoder_loss = 1.18.
# var_u: tensor([1.4617]), phi: tensor([0.4903])
#
# Epoch 101/500, loss_fit = 15026.66, encoder_loss = 1.19.
# var_u: tensor([1.4616]), phi: tensor([0.4899])
#
# Epoch 102/500, loss_fit = 13547.86, encoder_loss = 1.14.
# var_u: tensor([1.4616]), phi: tensor([0.4899])
#
# Epoch 103/500, loss_fit = 14697.09, encoder_loss = 1.11.
# var_u: tensor([1.4617]), phi: tensor([0.4905])
#
# Epoch 104/500, loss_fit = 16313.14, encoder_loss = 1.13.
# var_u: tensor([1.4616]), phi: tensor([0.4907])
#
# Epoch 105/500, loss_fit = 13945.83, encoder_loss = 1.16.
# var_u: tensor([1.4604]), phi: tensor([0.4910])
#
# Epoch 106/500, loss_fit = 15421.34, encoder_loss = 1.19.
# var_u: tensor([1.4603]), phi: tensor([0.4907])
#
# Epoch 107/500, loss_fit = 16800.36, encoder_loss = 1.17.
# var_u: tensor([1.4603]), phi: tensor([0.4910])
#
# Epoch 108/500, loss_fit = 16489.54, encoder_loss = 1.16.
# var_u: tensor([1.4590]), phi: tensor([0.4920])
#
# Epoch 109/500, loss_fit = 15509.69, encoder_loss = 1.11.
# var_u: tensor([1.4592]), phi: tensor([0.4922])
#
# Epoch 110/500, loss_fit = 20813.69, encoder_loss = 1.12.
# var_u: tensor([1.4586]), phi: tensor([0.4918])
#
# Epoch 111/500, loss_fit = 15597.76, encoder_loss = 1.09.
# var_u: tensor([1.4582]), phi: tensor([0.4918])
#
# Epoch 112/500, loss_fit = 17922.49, encoder_loss = 1.08.
# var_u: tensor([1.4579]), phi: tensor([0.4914])
#
# Epoch 113/500, loss_fit = 14415.47, encoder_loss = 1.13.
# var_u: tensor([1.4567]), phi: tensor([0.4916])
#
# Epoch 114/500, loss_fit = 16066.83, encoder_loss = 1.21.
# var_u: tensor([1.4570]), phi: tensor([0.4913])
#
# Epoch 115/500, loss_fit = 18830.51, encoder_loss = 1.19.
# var_u: tensor([1.4578]), phi: tensor([0.4917])
#
# Epoch 116/500, loss_fit = 17559.79, encoder_loss = 1.16.
# var_u: tensor([1.4592]), phi: tensor([0.4920])
#
# Epoch 117/500, loss_fit = 19781.67, encoder_loss = 1.14.
# var_u: tensor([1.4593]), phi: tensor([0.4922])
#
# Epoch 118/500, loss_fit = 20040.12, encoder_loss = 1.14.
# var_u: tensor([1.4593]), phi: tensor([0.4919])
#
# Epoch 119/500, loss_fit = 22649.14, encoder_loss = 1.10.
# var_u: tensor([1.4591]), phi: tensor([0.4919])
#
# Epoch 120/500, loss_fit = 18372.05, encoder_loss = 1.11.
# var_u: tensor([1.4587]), phi: tensor([0.4923])
#
# Epoch 121/500, loss_fit = 16625.58, encoder_loss = 1.08.
# var_u: tensor([1.4584]), phi: tensor([0.4928])
#
# Epoch 122/500, loss_fit = 15334.10, encoder_loss = 1.08.
# var_u: tensor([1.4585]), phi: tensor([0.4927])
#
# Epoch 123/500, loss_fit = 16616.46, encoder_loss = 1.17.
# var_u: tensor([1.4591]), phi: tensor([0.4925])
#
# Epoch 124/500, loss_fit = 15890.70, encoder_loss = 1.20.
# var_u: tensor([1.4599]), phi: tensor([0.4925])
#
# Epoch 125/500, loss_fit = 15926.79, encoder_loss = 1.16.
# var_u: tensor([1.4594]), phi: tensor([0.4925])
#
# Epoch 126/500, loss_fit = 16834.41, encoder_loss = 1.13.
# var_u: tensor([1.4587]), phi: tensor([0.4928])
#
# Epoch 127/500, loss_fit = 15254.04, encoder_loss = 1.11.
# var_u: tensor([1.4578]), phi: tensor([0.4931])
#
# Epoch 128/500, loss_fit = 18036.21, encoder_loss = 1.12.
# var_u: tensor([1.4585]), phi: tensor([0.4935])
#
# Epoch 129/500, loss_fit = 20036.48, encoder_loss = 1.07.
# var_u: tensor([1.4594]), phi: tensor([0.4939])
#
# Epoch 130/500, loss_fit = 18670.08, encoder_loss = 1.09.
# var_u: tensor([1.4604]), phi: tensor([0.4941])
#
# Epoch 131/500, loss_fit = 19685.66, encoder_loss = 1.11.
# var_u: tensor([1.4605]), phi: tensor([0.4945])
#
# Epoch 132/500, loss_fit = 20889.08, encoder_loss = 1.17.
# var_u: tensor([1.4603]), phi: tensor([0.4943])
#
# Epoch 133/500, loss_fit = 19307.28, encoder_loss = 1.17.
# var_u: tensor([1.4602]), phi: tensor([0.4943])
#
# Epoch 134/500, loss_fit = 18138.14, encoder_loss = 1.14.
# var_u: tensor([1.4613]), phi: tensor([0.4943])
#
# Epoch 135/500, loss_fit = 17229.79, encoder_loss = 1.09.
# var_u: tensor([1.4624]), phi: tensor([0.4943])
#
# Epoch 136/500, loss_fit = 18585.73, encoder_loss = 1.08.
# var_u: tensor([1.4639]), phi: tensor([0.4946])
#
# Epoch 137/500, loss_fit = 17916.43, encoder_loss = 1.13.
# var_u: tensor([1.4638]), phi: tensor([0.4945])
#
# Epoch 138/500, loss_fit = 21714.01, encoder_loss = 1.15.
# var_u: tensor([1.4634]), phi: tensor([0.4942])
#
# Epoch 139/500, loss_fit = 20601.30, encoder_loss = 1.14.
# var_u: tensor([1.4640]), phi: tensor([0.4944])
#
# Epoch 140/500, loss_fit = 20805.21, encoder_loss = 1.10.
# var_u: tensor([1.4633]), phi: tensor([0.4941])
#
# Epoch 141/500, loss_fit = 17672.42, encoder_loss = 1.10.
# var_u: tensor([1.4636]), phi: tensor([0.4940])
#
# Epoch 142/500, loss_fit = 18830.10, encoder_loss = 1.06.
# var_u: tensor([1.4636]), phi: tensor([0.4949])
#
# Epoch 143/500, loss_fit = 18100.98, encoder_loss = 1.11.
# var_u: tensor([1.4631]), phi: tensor([0.4951])
#
# Epoch 144/500, loss_fit = 19841.69, encoder_loss = 1.09.
# var_u: tensor([1.4621]), phi: tensor([0.4956])
#
# Epoch 145/500, loss_fit = 21783.16, encoder_loss = 1.11.
# var_u: tensor([1.4629]), phi: tensor([0.4955])
#
# Epoch 146/500, loss_fit = 17719.42, encoder_loss = 1.10.
# var_u: tensor([1.4633]), phi: tensor([0.4955])
#
# Epoch 147/500, loss_fit = 17055.25, encoder_loss = 1.13.
# var_u: tensor([1.4624]), phi: tensor([0.4958])
#
# Epoch 148/500, loss_fit = 21995.55, encoder_loss = 1.15.
# var_u: tensor([1.4631]), phi: tensor([0.4964])
#
# Epoch 149/500, loss_fit = 19844.82, encoder_loss = 1.12.
# var_u: tensor([1.4625]), phi: tensor([0.4970])
#
# Epoch 150/500, loss_fit = 17395.98, encoder_loss = 1.10.
# var_u: tensor([1.4633]), phi: tensor([0.4968])
#
# Epoch 151/500, loss_fit = 16911.55, encoder_loss = 1.08.
# var_u: tensor([1.4635]), phi: tensor([0.4968])
#
# Epoch 152/500, loss_fit = 18465.75, encoder_loss = 1.08.
# var_u: tensor([1.4630]), phi: tensor([0.4976])
#
# Epoch 153/500, loss_fit = 17004.07, encoder_loss = 1.06.
# var_u: tensor([1.4637]), phi: tensor([0.4980])
#
# Epoch 154/500, loss_fit = 15445.39, encoder_loss = 1.09.
# var_u: tensor([1.4649]), phi: tensor([0.4977])
#
# Epoch 155/500, loss_fit = 18037.19, encoder_loss = 1.17.
# var_u: tensor([1.4664]), phi: tensor([0.4976])
#
# Epoch 156/500, loss_fit = 18930.10, encoder_loss = 1.14.
# var_u: tensor([1.4670]), phi: tensor([0.4973])
#
# Epoch 157/500, loss_fit = 17603.73, encoder_loss = 1.13.
# var_u: tensor([1.4672]), phi: tensor([0.4970])
#
# Epoch 158/500, loss_fit = 21817.14, encoder_loss = 1.13.
# var_u: tensor([1.4670]), phi: tensor([0.4971])
#
# Epoch 159/500, loss_fit = 21328.69, encoder_loss = 1.09.
# var_u: tensor([1.4665]), phi: tensor([0.4970])
#
# Epoch 160/500, loss_fit = 18617.73, encoder_loss = 1.09.
# var_u: tensor([1.4666]), phi: tensor([0.4971])
#
# Epoch 161/500, loss_fit = 14929.11, encoder_loss = 1.06.
# var_u: tensor([1.4657]), phi: tensor([0.4969])
#
# Epoch 162/500, loss_fit = 15825.48, encoder_loss = 1.06.
# var_u: tensor([1.4662]), phi: tensor([0.4969])
#
# Epoch 163/500, loss_fit = 17522.79, encoder_loss = 1.06.
# var_u: tensor([1.4668]), phi: tensor([0.4972])
#
# Epoch 164/500, loss_fit = 15534.53, encoder_loss = 1.10.
# var_u: tensor([1.4672]), phi: tensor([0.4972])
#
# Epoch 165/500, loss_fit = 14886.47, encoder_loss = 1.15.
# var_u: tensor([1.4675]), phi: tensor([0.4976])
#
# Epoch 166/500, loss_fit = 13121.32, encoder_loss = 1.14.
# var_u: tensor([1.4678]), phi: tensor([0.4976])
#
# Epoch 167/500, loss_fit = 15996.12, encoder_loss = 1.13.
# var_u: tensor([1.4682]), phi: tensor([0.4978])
#
# Epoch 168/500, loss_fit = 17543.44, encoder_loss = 1.11.
# var_u: tensor([1.4686]), phi: tensor([0.4974])
#
# Epoch 169/500, loss_fit = 16477.21, encoder_loss = 1.12.
# var_u: tensor([1.4683]), phi: tensor([0.4973])
#
# Epoch 170/500, loss_fit = 16389.94, encoder_loss = 1.08.
# var_u: tensor([1.4695]), phi: tensor([0.4973])
#
# Epoch 171/500, loss_fit = 17505.66, encoder_loss = 1.07.
# var_u: tensor([1.4698]), phi: tensor([0.4973])
#
# Epoch 172/500, loss_fit = 15589.40, encoder_loss = 1.07.
# var_u: tensor([1.4706]), phi: tensor([0.4974])
#
# Epoch 173/500, loss_fit = 17110.93, encoder_loss = 1.05.
# var_u: tensor([1.4703]), phi: tensor([0.4971])
#
# Epoch 174/500, loss_fit = 15691.84, encoder_loss = 1.09.
# var_u: tensor([1.4703]), phi: tensor([0.4969])
#
# Epoch 175/500, loss_fit = 13841.43, encoder_loss = 1.07.
# var_u: tensor([1.4693]), phi: tensor([0.4968])
#
# Epoch 176/500, loss_fit = 11871.19, encoder_loss = 1.10.
# var_u: tensor([1.4685]), phi: tensor([0.4964])
#
# Epoch 177/500, loss_fit = 15413.34, encoder_loss = 1.13.
# var_u: tensor([1.4687]), phi: tensor([0.4958])
#
# Epoch 178/500, loss_fit = 14372.48, encoder_loss = 1.10.
# var_u: tensor([1.4690]), phi: tensor([0.4956])
#
# Epoch 179/500, loss_fit = 14393.09, encoder_loss = 1.10.
# var_u: tensor([1.4693]), phi: tensor([0.4959])
#
# Epoch 180/500, loss_fit = 16696.21, encoder_loss = 1.07.
# var_u: tensor([1.4693]), phi: tensor([0.4958])
#
# Epoch 181/500, loss_fit = 19632.98, encoder_loss = 1.05.
# var_u: tensor([1.4707]), phi: tensor([0.4955])
#
# Epoch 182/500, loss_fit = 14594.84, encoder_loss = 1.03.
# var_u: tensor([1.4698]), phi: tensor([0.4950])
#
# Epoch 183/500, loss_fit = 14273.66, encoder_loss = 1.03.
# var_u: tensor([1.4710]), phi: tensor([0.4949])
#
# Epoch 184/500, loss_fit = 16960.36, encoder_loss = 1.05.
# var_u: tensor([1.4714]), phi: tensor([0.4949])
#
# Epoch 185/500, loss_fit = 14232.81, encoder_loss = 1.10.
# var_u: tensor([1.4698]), phi: tensor([0.4950])
#
# Epoch 186/500, loss_fit = 13463.22, encoder_loss = 1.14.
# var_u: tensor([1.4710]), phi: tensor([0.4950])
#
# Epoch 187/500, loss_fit = 14583.24, encoder_loss = 1.11.
# var_u: tensor([1.4709]), phi: tensor([0.4951])
#
# Epoch 188/500, loss_fit = 17389.06, encoder_loss = 1.08.
# var_u: tensor([1.4716]), phi: tensor([0.4953])
#
# Epoch 189/500, loss_fit = 16724.22, encoder_loss = 1.07.
# var_u: tensor([1.4711]), phi: tensor([0.4951])
#
# Epoch 190/500, loss_fit = 15306.65, encoder_loss = 1.03.
# var_u: tensor([1.4723]), phi: tensor([0.4950])
#
# Epoch 191/500, loss_fit = 15608.10, encoder_loss = 1.03.
# var_u: tensor([1.4733]), phi: tensor([0.4947])
#
# Epoch 192/500, loss_fit = 15212.09, encoder_loss = 1.04.
# var_u: tensor([1.4733]), phi: tensor([0.4945])
#
# Epoch 193/500, loss_fit = 15152.33, encoder_loss = 1.09.
# var_u: tensor([1.4746]), phi: tensor([0.4944])
#
# Epoch 194/500, loss_fit = 16067.11, encoder_loss = 1.18.
# var_u: tensor([1.4740]), phi: tensor([0.4938])
#
# Epoch 195/500, loss_fit = 17364.45, encoder_loss = 1.13.
# var_u: tensor([1.4753]), phi: tensor([0.4937])
#
# Epoch 196/500, loss_fit = 16968.04, encoder_loss = 1.07.
# var_u: tensor([1.4765]), phi: tensor([0.4932])
#
# Epoch 197/500, loss_fit = 16829.00, encoder_loss = 1.09.
# var_u: tensor([1.4774]), phi: tensor([0.4934])
#
# Epoch 198/500, loss_fit = 16254.50, encoder_loss = 1.06.
# var_u: tensor([1.4778]), phi: tensor([0.4931])
#
# Epoch 199/500, loss_fit = 15722.49, encoder_loss = 1.02.
# var_u: tensor([1.4785]), phi: tensor([0.4936])
#
# Epoch 200/500, loss_fit = 16176.69, encoder_loss = 1.01.
# var_u: tensor([1.4791]), phi: tensor([0.4933])
#
# Epoch 201/500, loss_fit = 14511.00, encoder_loss = 0.99.
# var_u: tensor([1.4794]), phi: tensor([0.4934])
#
# Epoch 202/500, loss_fit = 14566.70, encoder_loss = 1.01.
# var_u: tensor([1.4794]), phi: tensor([0.4931])
#
# Epoch 203/500, loss_fit = 15101.94, encoder_loss = 1.02.
# var_u: tensor([1.4800]), phi: tensor([0.4931])
#
# Epoch 204/500, loss_fit = 15236.55, encoder_loss = 1.08.
# var_u: tensor([1.4792]), phi: tensor([0.4935])
#
# Epoch 205/500, loss_fit = 15976.38, encoder_loss = 1.00.
# var_u: tensor([1.4791]), phi: tensor([0.4936])
#
# Epoch 206/500, loss_fit = 13794.92, encoder_loss = 1.05.
# var_u: tensor([1.4788]), phi: tensor([0.4942])
#
# Epoch 207/500, loss_fit = 13458.83, encoder_loss = 1.03.
# var_u: tensor([1.4775]), phi: tensor([0.4942])
#
# Epoch 208/500, loss_fit = 15318.27, encoder_loss = 1.00.
# var_u: tensor([1.4776]), phi: tensor([0.4940])
#
# Epoch 209/500, loss_fit = 16241.31, encoder_loss = 1.00.
# var_u: tensor([1.4773]), phi: tensor([0.4940])
#
# Epoch 210/500, loss_fit = 14729.29, encoder_loss = 0.98.
# var_u: tensor([1.4780]), phi: tensor([0.4940])
#
# Epoch 211/500, loss_fit = 13557.04, encoder_loss = 1.01.
# var_u: tensor([1.4784]), phi: tensor([0.4942])
#
# Epoch 212/500, loss_fit = 15737.82, encoder_loss = 1.06.
# var_u: tensor([1.4791]), phi: tensor([0.4942])
#
# Epoch 213/500, loss_fit = 15414.07, encoder_loss = 1.02.
# var_u: tensor([1.4796]), phi: tensor([0.4941])
#
# Epoch 214/500, loss_fit = 19046.39, encoder_loss = 1.06.
# var_u: tensor([1.4790]), phi: tensor([0.4944])
#
# Epoch 215/500, loss_fit = 17585.40, encoder_loss = 1.04.
# var_u: tensor([1.4793]), phi: tensor([0.4948])
#
# Epoch 216/500, loss_fit = 15072.41, encoder_loss = 1.02.
# var_u: tensor([1.4791]), phi: tensor([0.4951])
#
# Epoch 217/500, loss_fit = 14878.40, encoder_loss = 1.02.
# var_u: tensor([1.4782]), phi: tensor([0.4953])
#
# Epoch 218/500, loss_fit = 15742.41, encoder_loss = 0.98.
# var_u: tensor([1.4781]), phi: tensor([0.4949])
#
# Epoch 219/500, loss_fit = 14962.86, encoder_loss = 1.05.
# var_u: tensor([1.4784]), phi: tensor([0.4951])
#
# Epoch 220/500, loss_fit = 17011.62, encoder_loss = 0.99.
# var_u: tensor([1.4798]), phi: tensor([0.4951])
#
# Epoch 221/500, loss_fit = 15908.08, encoder_loss = 0.99.
# var_u: tensor([1.4791]), phi: tensor([0.4951])
#
# Epoch 222/500, loss_fit = 15241.29, encoder_loss = 0.99.
# var_u: tensor([1.4789]), phi: tensor([0.4948])
#
# Epoch 223/500, loss_fit = 16843.32, encoder_loss = 0.99.
# var_u: tensor([1.4793]), phi: tensor([0.4947])
#
# Epoch 224/500, loss_fit = 18266.03, encoder_loss = 1.00.
# var_u: tensor([1.4786]), phi: tensor([0.4949])
#
# Epoch 225/500, loss_fit = 15527.31, encoder_loss = 0.98.
# var_u: tensor([1.4779]), phi: tensor([0.4952])
#
# Epoch 226/500, loss_fit = 16813.50, encoder_loss = 1.00.
# var_u: tensor([1.4777]), phi: tensor([0.4953])
#
# Epoch 227/500, loss_fit = 14950.56, encoder_loss = 0.98.
# var_u: tensor([1.4789]), phi: tensor([0.4955])
#
# Epoch 228/500, loss_fit = 19101.77, encoder_loss = 0.98.
# var_u: tensor([1.4784]), phi: tensor([0.4950])
#
# Epoch 229/500, loss_fit = 14357.14, encoder_loss = 0.99.
# var_u: tensor([1.4788]), phi: tensor([0.4954])
#
# Epoch 230/500, loss_fit = 15195.71, encoder_loss = 0.96.
# var_u: tensor([1.4802]), phi: tensor([0.4955])
#
# Epoch 231/500, loss_fit = 13900.76, encoder_loss = 1.06.
# var_u: tensor([1.4808]), phi: tensor([0.4955])
#
# Epoch 232/500, loss_fit = 17234.26, encoder_loss = 1.06.
# var_u: tensor([1.4804]), phi: tensor([0.4954])
#
# Epoch 233/500, loss_fit = 16407.79, encoder_loss = 1.03.
# var_u: tensor([1.4796]), phi: tensor([0.4959])
#
# Epoch 234/500, loss_fit = 17563.88, encoder_loss = 1.04.
# var_u: tensor([1.4793]), phi: tensor([0.4960])
#
# Epoch 235/500, loss_fit = 17103.16, encoder_loss = 1.01.
# var_u: tensor([1.4788]), phi: tensor([0.4957])
#
# Epoch 236/500, loss_fit = 15581.37, encoder_loss = 1.00.
# var_u: tensor([1.4782]), phi: tensor([0.4960])
#
# Epoch 237/500, loss_fit = 16368.54, encoder_loss = 1.02.
# var_u: tensor([1.4780]), phi: tensor([0.4960])
#
# Epoch 238/500, loss_fit = 15043.72, encoder_loss = 1.00.
# var_u: tensor([1.4784]), phi: tensor([0.4963])
#
# Epoch 239/500, loss_fit = 13127.36, encoder_loss = 1.00.
# var_u: tensor([1.4783]), phi: tensor([0.4965])
#
# Epoch 240/500, loss_fit = 16196.83, encoder_loss = 1.00.
# var_u: tensor([1.4773]), phi: tensor([0.4962])
#
# Epoch 241/500, loss_fit = 13761.61, encoder_loss = 0.97.
# var_u: tensor([1.4762]), phi: tensor([0.4965])
#
# Epoch 242/500, loss_fit = 13759.35, encoder_loss = 1.04.
# var_u: tensor([1.4766]), phi: tensor([0.4962])
#
# Epoch 243/500, loss_fit = 14783.49, encoder_loss = 1.07.
# var_u: tensor([1.4760]), phi: tensor([0.4962])
#
# Epoch 244/500, loss_fit = 14831.95, encoder_loss = 1.07.
# var_u: tensor([1.4755]), phi: tensor([0.4960])
#
# Epoch 245/500, loss_fit = 15805.13, encoder_loss = 1.01.
# var_u: tensor([1.4751]), phi: tensor([0.4960])
#
# Epoch 246/500, loss_fit = 16259.05, encoder_loss = 1.00.
# var_u: tensor([1.4755]), phi: tensor([0.4960])
#
# Epoch 247/500, loss_fit = 13964.67, encoder_loss = 1.00.
# var_u: tensor([1.4757]), phi: tensor([0.4958])
#
# Epoch 248/500, loss_fit = 15283.59, encoder_loss = 0.98.
# var_u: tensor([1.4768]), phi: tensor([0.4955])
#
# Epoch 249/500, loss_fit = 13798.51, encoder_loss = 0.97.
# var_u: tensor([1.4761]), phi: tensor([0.4953])
#
# Epoch 250/500, loss_fit = 12844.70, encoder_loss = 0.94.
# var_u: tensor([1.4760]), phi: tensor([0.4954])
#
# Epoch 251/500, loss_fit = 13687.34, encoder_loss = 0.96.
# var_u: tensor([1.4756]), phi: tensor([0.4952])
#
# Epoch 252/500, loss_fit = 12453.68, encoder_loss = 0.95.
# var_u: tensor([1.4752]), phi: tensor([0.4951])
#
# Epoch 253/500, loss_fit = 13105.05, encoder_loss = 0.95.
# var_u: tensor([1.4762]), phi: tensor([0.4951])
#
# Epoch 254/500, loss_fit = 12801.43, encoder_loss = 0.94.
# var_u: tensor([1.4765]), phi: tensor([0.4950])
#
# Epoch 255/500, loss_fit = 13491.06, encoder_loss = 1.16.
# var_u: tensor([1.4753]), phi: tensor([0.4948])
#
# Epoch 256/500, loss_fit = 14050.91, encoder_loss = 1.21.
# var_u: tensor([1.4770]), phi: tensor([0.4948])
#
# Epoch 257/500, loss_fit = 17086.69, encoder_loss = 1.16.
# var_u: tensor([1.4769]), phi: tensor([0.4954])
#
# Epoch 258/500, loss_fit = 16562.34, encoder_loss = 1.15.
# var_u: tensor([1.4759]), phi: tensor([0.4955])
#
# Epoch 259/500, loss_fit = 18857.26, encoder_loss = 1.14.
# var_u: tensor([1.4770]), phi: tensor([0.4953])
#
# Epoch 260/500, loss_fit = 13955.30, encoder_loss = 1.09.
# var_u: tensor([1.4791]), phi: tensor([0.4954])
#
# Epoch 261/500, loss_fit = 14347.16, encoder_loss = 1.09.
# var_u: tensor([1.4798]), phi: tensor([0.4954])
#
# Epoch 262/500, loss_fit = 14609.69, encoder_loss = 1.06.
# var_u: tensor([1.4807]), phi: tensor([0.4953])
#
# Epoch 263/500, loss_fit = 16670.57, encoder_loss = 1.05.
# var_u: tensor([1.4821]), phi: tensor([0.4955])
#
# Epoch 264/500, loss_fit = 15375.14, encoder_loss = 1.03.
# var_u: tensor([1.4842]), phi: tensor([0.4952])
#
# Epoch 265/500, loss_fit = 16071.60, encoder_loss = 1.02.
# var_u: tensor([1.4842]), phi: tensor([0.4954])
#
# Epoch 266/500, loss_fit = 16513.07, encoder_loss = 1.01.
# var_u: tensor([1.4853]), phi: tensor([0.4956])
#
# Epoch 267/500, loss_fit = 13301.71, encoder_loss = 0.98.
# var_u: tensor([1.4862]), phi: tensor([0.4958])
#
# Epoch 268/500, loss_fit = 15558.89, encoder_loss = 0.96.
# var_u: tensor([1.4861]), phi: tensor([0.4955])
#
# Epoch 269/500, loss_fit = 12053.30, encoder_loss = 0.98.
# var_u: tensor([1.4871]), phi: tensor([0.4953])
#
# Epoch 270/500, loss_fit = 14605.06, encoder_loss = 0.96.
# var_u: tensor([1.4862]), phi: tensor([0.4954])
#
# Epoch 271/500, loss_fit = 14079.44, encoder_loss = 0.99.
# var_u: tensor([1.4856]), phi: tensor([0.4955])
#
# Epoch 272/500, loss_fit = 12458.73, encoder_loss = 0.95.
# var_u: tensor([1.4850]), phi: tensor([0.4955])
#
# Epoch 273/500, loss_fit = 12975.46, encoder_loss = 0.96.
# var_u: tensor([1.4844]), phi: tensor([0.4958])
#
# Epoch 274/500, loss_fit = 13315.02, encoder_loss = 1.08.
# var_u: tensor([1.4835]), phi: tensor([0.4955])
#
# Epoch 275/500, loss_fit = 15020.63, encoder_loss = 1.09.
# var_u: tensor([1.4835]), phi: tensor([0.4954])
#
# Epoch 276/500, loss_fit = 15954.63, encoder_loss = 1.07.
# var_u: tensor([1.4843]), phi: tensor([0.4953])
#
# Epoch 277/500, loss_fit = 13967.08, encoder_loss = 1.02.
# var_u: tensor([1.4844]), phi: tensor([0.4956])
#
# Epoch 278/500, loss_fit = 13844.59, encoder_loss = 1.00.
# var_u: tensor([1.4851]), phi: tensor([0.4953])
#
# Epoch 279/500, loss_fit = 13855.32, encoder_loss = 0.99.
# var_u: tensor([1.4853]), phi: tensor([0.4951])
#
# Epoch 280/500, loss_fit = 13904.38, encoder_loss = 0.97.
# var_u: tensor([1.4863]), phi: tensor([0.4951])
#
# Epoch 281/500, loss_fit = 14216.93, encoder_loss = 0.96.
# var_u: tensor([1.4852]), phi: tensor([0.4950])
#
# Epoch 282/500, loss_fit = 12895.73, encoder_loss = 0.94.
# var_u: tensor([1.4856]), phi: tensor([0.4950])
#
# Epoch 283/500, loss_fit = 11292.39, encoder_loss = 0.95.
# var_u: tensor([1.4850]), phi: tensor([0.4947])
#
# Epoch 284/500, loss_fit = 13511.82, encoder_loss = 0.93.
# var_u: tensor([1.4833]), phi: tensor([0.4948])
#
# Epoch 285/500, loss_fit = 11575.80, encoder_loss = 0.93.
# var_u: tensor([1.4824]), phi: tensor([0.4949])
#
# Epoch 286/500, loss_fit = 12377.38, encoder_loss = 0.95.
# var_u: tensor([1.4825]), phi: tensor([0.4950])
#
# Epoch 287/500, loss_fit = 11405.07, encoder_loss = 0.92.
# var_u: tensor([1.4823]), phi: tensor([0.4951])
#
# Epoch 288/500, loss_fit = 12186.58, encoder_loss = 0.97.
# var_u: tensor([1.4812]), phi: tensor([0.4949])
#
# Epoch 289/500, loss_fit = 9111.06, encoder_loss = 1.09.
# var_u: tensor([1.4819]), phi: tensor([0.4943])
#
# Epoch 290/500, loss_fit = 14763.56, encoder_loss = 1.07.
# var_u: tensor([1.4815]), phi: tensor([0.4941])
#
# Epoch 291/500, loss_fit = 12308.63, encoder_loss = 1.02.
# var_u: tensor([1.4817]), phi: tensor([0.4943])
#
# Epoch 292/500, loss_fit = 13946.70, encoder_loss = 1.02.
# var_u: tensor([1.4818]), phi: tensor([0.4943])
#
# Epoch 293/500, loss_fit = 12898.37, encoder_loss = 1.00.
# var_u: tensor([1.4815]), phi: tensor([0.4941])
#
# Epoch 294/500, loss_fit = 14626.11, encoder_loss = 0.99.
# var_u: tensor([1.4824]), phi: tensor([0.4944])
#
# Epoch 295/500, loss_fit = 15915.81, encoder_loss = 0.97.
# var_u: tensor([1.4831]), phi: tensor([0.4941])
#
# Epoch 296/500, loss_fit = 16738.68, encoder_loss = 0.95.
# var_u: tensor([1.4830]), phi: tensor([0.4939])
#
# Epoch 297/500, loss_fit = 14168.87, encoder_loss = 0.98.
# var_u: tensor([1.4824]), phi: tensor([0.4944])
#
# Epoch 298/500, loss_fit = 12796.63, encoder_loss = 0.95.
# var_u: tensor([1.4820]), phi: tensor([0.4943])
#
# Epoch 299/500, loss_fit = 13747.36, encoder_loss = 0.94.
# var_u: tensor([1.4814]), phi: tensor([0.4940])
#
# Epoch 300/500, loss_fit = 12534.18, encoder_loss = 0.97.
# var_u: tensor([1.4810]), phi: tensor([0.4938])
#
# Epoch 301/500, loss_fit = 13777.36, encoder_loss = 0.97.
# var_u: tensor([1.4807]), phi: tensor([0.4937])
#
# Epoch 302/500, loss_fit = 12921.88, encoder_loss = 0.94.
# var_u: tensor([1.4804]), phi: tensor([0.4941])
#
# Epoch 303/500, loss_fit = 13554.14, encoder_loss = 0.98.
# var_u: tensor([1.4811]), phi: tensor([0.4941])
#
# Epoch 304/500, loss_fit = 13738.98, encoder_loss = 0.96.
# var_u: tensor([1.4805]), phi: tensor([0.4944])
#
# Epoch 305/500, loss_fit = 13130.51, encoder_loss = 0.96.
# var_u: tensor([1.4801]), phi: tensor([0.4944])
#
# Epoch 306/500, loss_fit = 13700.30, encoder_loss = 0.93.
# var_u: tensor([1.4798]), phi: tensor([0.4946])
#
# Epoch 307/500, loss_fit = 13970.95, encoder_loss = 0.92.
# var_u: tensor([1.4803]), phi: tensor([0.4949])
#
# Epoch 308/500, loss_fit = 13974.31, encoder_loss = 0.94.
# var_u: tensor([1.4800]), phi: tensor([0.4949])
#
# Epoch 309/500, loss_fit = 12835.61, encoder_loss = 0.99.
# var_u: tensor([1.4783]), phi: tensor([0.4950])
#
# Epoch 310/500, loss_fit = 13106.02, encoder_loss = 0.98.
# var_u: tensor([1.4793]), phi: tensor([0.4948])
#
# Epoch 311/500, loss_fit = 13964.90, encoder_loss = 0.97.
# var_u: tensor([1.4806]), phi: tensor([0.4947])
#
# Epoch 312/500, loss_fit = 13791.93, encoder_loss = 0.96.
# var_u: tensor([1.4802]), phi: tensor([0.4945])
#
# Epoch 313/500, loss_fit = 14560.82, encoder_loss = 0.93.
# var_u: tensor([1.4798]), phi: tensor([0.4947])
#
# Epoch 314/500, loss_fit = 16763.93, encoder_loss = 0.96.
# var_u: tensor([1.4795]), phi: tensor([0.4947])
#
# Epoch 315/500, loss_fit = 13280.51, encoder_loss = 0.93.
# var_u: tensor([1.4795]), phi: tensor([0.4953])
#
# Epoch 316/500, loss_fit = 13810.83, encoder_loss = 0.91.
# var_u: tensor([1.4785]), phi: tensor([0.4956])
#
# Epoch 317/500, loss_fit = 14991.85, encoder_loss = 0.89.
# var_u: tensor([1.4784]), phi: tensor([0.4953])
#
# Epoch 318/500, loss_fit = 16583.26, encoder_loss = 1.00.
# var_u: tensor([1.4793]), phi: tensor([0.4957])
#
# Epoch 319/500, loss_fit = 14464.22, encoder_loss = 1.05.
# var_u: tensor([1.4800]), phi: tensor([0.4956])
#
# Epoch 320/500, loss_fit = 13807.32, encoder_loss = 1.00.
# var_u: tensor([1.4793]), phi: tensor([0.4956])
#
# Epoch 321/500, loss_fit = 11522.21, encoder_loss = 0.97.
# var_u: tensor([1.4787]), phi: tensor([0.4957])
#
# Epoch 322/500, loss_fit = 11962.85, encoder_loss = 0.94.
# var_u: tensor([1.4795]), phi: tensor([0.4958])
#
# Epoch 323/500, loss_fit = 22195.54, encoder_loss = 0.93.
# var_u: tensor([1.4796]), phi: tensor([0.4962])
#
# Epoch 324/500, loss_fit = 14396.16, encoder_loss = 0.91.
# var_u: tensor([1.4801]), phi: tensor([0.4963])
#
# Epoch 325/500, loss_fit = 12947.33, encoder_loss = 0.91.
# var_u: tensor([1.4811]), phi: tensor([0.4966])
#
# Epoch 326/500, loss_fit = 13307.12, encoder_loss = 0.88.
# var_u: tensor([1.4813]), phi: tensor([0.4966])
#
# Epoch 327/500, loss_fit = 14030.80, encoder_loss = 0.89.
# var_u: tensor([1.4808]), phi: tensor([0.4965])
#
# Epoch 328/500, loss_fit = 13150.38, encoder_loss = 0.91.
# var_u: tensor([1.4812]), phi: tensor([0.4965])
#
# Epoch 329/500, loss_fit = 14933.61, encoder_loss = 0.92.
# var_u: tensor([1.4815]), phi: tensor([0.4966])
#
# Epoch 330/500, loss_fit = 16526.63, encoder_loss = 0.95.
# var_u: tensor([1.4812]), phi: tensor([0.4964])
#
# Epoch 331/500, loss_fit = 16214.67, encoder_loss = 0.93.
# var_u: tensor([1.4813]), phi: tensor([0.4963])
#
# Epoch 332/500, loss_fit = 14207.33, encoder_loss = 0.91.
# var_u: tensor([1.4812]), phi: tensor([0.4962])
#
# Epoch 333/500, loss_fit = 16544.80, encoder_loss = 0.89.
# var_u: tensor([1.4816]), phi: tensor([0.4960])
#
# Epoch 334/500, loss_fit = 13453.43, encoder_loss = 0.90.
# var_u: tensor([1.4816]), phi: tensor([0.4959])
#
# Epoch 335/500, loss_fit = 12818.41, encoder_loss = 0.95.
# var_u: tensor([1.4825]), phi: tensor([0.4956])
#
# Epoch 336/500, loss_fit = 16404.15, encoder_loss = 0.94.
# var_u: tensor([1.4823]), phi: tensor([0.4958])
#
# Epoch 337/500, loss_fit = 15665.55, encoder_loss = 0.93.
# var_u: tensor([1.4819]), phi: tensor([0.4954])
#
# Epoch 338/500, loss_fit = 13900.79, encoder_loss = 0.90.
# var_u: tensor([1.4819]), phi: tensor([0.4954])
#
# Epoch 339/500, loss_fit = 14148.51, encoder_loss = 0.92.
# var_u: tensor([1.4819]), phi: tensor([0.4951])
#
# Epoch 340/500, loss_fit = 15242.98, encoder_loss = 0.90.
# var_u: tensor([1.4821]), phi: tensor([0.4957])
#
# Epoch 341/500, loss_fit = 16079.77, encoder_loss = 0.88.
# var_u: tensor([1.4807]), phi: tensor([0.4955])
#
# Epoch 342/500, loss_fit = 14231.27, encoder_loss = 0.89.
# var_u: tensor([1.4808]), phi: tensor([0.4954])
#
# Epoch 343/500, loss_fit = 19316.70, encoder_loss = 0.87.
# var_u: tensor([1.4804]), phi: tensor([0.4953])
#
# Epoch 344/500, loss_fit = 17253.33, encoder_loss = 0.86.
# var_u: tensor([1.4806]), phi: tensor([0.4953])
#
# Epoch 345/500, loss_fit = 14917.98, encoder_loss = 0.88.
# var_u: tensor([1.4807]), phi: tensor([0.4954])
#
# Epoch 346/500, loss_fit = 13829.82, encoder_loss = 1.07.
# var_u: tensor([1.4813]), phi: tensor([0.4955])
#
# Epoch 347/500, loss_fit = 16964.14, encoder_loss = 1.08.
# var_u: tensor([1.4816]), phi: tensor([0.4951])
#
# Epoch 348/500, loss_fit = 18923.12, encoder_loss = 1.02.
# var_u: tensor([1.4814]), phi: tensor([0.4956])
#
# Epoch 349/500, loss_fit = 18164.07, encoder_loss = 1.01.
# var_u: tensor([1.4819]), phi: tensor([0.4956])
#
# Epoch 350/500, loss_fit = 15552.91, encoder_loss = 0.98.
# var_u: tensor([1.4821]), phi: tensor([0.4954])
#
# Epoch 351/500, loss_fit = 16419.80, encoder_loss = 0.96.
# var_u: tensor([1.4829]), phi: tensor([0.4954])
#
# Epoch 352/500, loss_fit = 13509.73, encoder_loss = 0.93.
# var_u: tensor([1.4838]), phi: tensor([0.4952])
#
# Epoch 353/500, loss_fit = 15457.77, encoder_loss = 0.90.
# var_u: tensor([1.4833]), phi: tensor([0.4950])
#
# Epoch 354/500, loss_fit = 13755.04, encoder_loss = 0.91.
# var_u: tensor([1.4829]), phi: tensor([0.4950])
#
# Epoch 355/500, loss_fit = 13963.99, encoder_loss = 0.90.
# var_u: tensor([1.4825]), phi: tensor([0.4948])
#
# Epoch 356/500, loss_fit = 16899.28, encoder_loss = 0.90.
# var_u: tensor([1.4818]), phi: tensor([0.4950])
#
# Epoch 357/500, loss_fit = 15581.46, encoder_loss = 0.87.
# var_u: tensor([1.4818]), phi: tensor([0.4945])
#
# Epoch 358/500, loss_fit = 15230.94, encoder_loss = 0.87.
# var_u: tensor([1.4827]), phi: tensor([0.4946])
#
# Epoch 359/500, loss_fit = 15510.95, encoder_loss = 1.02.
# var_u: tensor([1.4825]), phi: tensor([0.4947])
#
# Epoch 360/500, loss_fit = 15905.97, encoder_loss = 1.01.
# var_u: tensor([1.4824]), phi: tensor([0.4952])
#
# Epoch 361/500, loss_fit = 15558.06, encoder_loss = 0.99.
# var_u: tensor([1.4822]), phi: tensor([0.4953])
#
# Epoch 362/500, loss_fit = 15572.09, encoder_loss = 0.97.
# var_u: tensor([1.4801]), phi: tensor([0.4953])
#
# Epoch 363/500, loss_fit = 15703.34, encoder_loss = 0.95.
# var_u: tensor([1.4789]), phi: tensor([0.4954])
#
# Epoch 364/500, loss_fit = 16161.44, encoder_loss = 0.93.
# var_u: tensor([1.4784]), phi: tensor([0.4951])
#
# Epoch 365/500, loss_fit = 15098.56, encoder_loss = 0.92.
# var_u: tensor([1.4774]), phi: tensor([0.4943])
#
# Epoch 366/500, loss_fit = 16314.33, encoder_loss = 0.90.
# var_u: tensor([1.4777]), phi: tensor([0.4942])
#
# Epoch 367/500, loss_fit = 14558.27, encoder_loss = 0.87.
# var_u: tensor([1.4781]), phi: tensor([0.4940])
#
# Epoch 368/500, loss_fit = 14059.54, encoder_loss = 0.86.
# var_u: tensor([1.4784]), phi: tensor([0.4943])
#
# Epoch 369/500, loss_fit = 16203.66, encoder_loss = 0.85.
# var_u: tensor([1.4791]), phi: tensor([0.4944])
#
# Epoch 370/500, loss_fit = 14613.19, encoder_loss = 0.85.
# var_u: tensor([1.4776]), phi: tensor([0.4946])
#
# Epoch 371/500, loss_fit = 13753.92, encoder_loss = 0.88.
# var_u: tensor([1.4786]), phi: tensor([0.4949])
#
# Epoch 372/500, loss_fit = 17410.86, encoder_loss = 0.86.
# var_u: tensor([1.4778]), phi: tensor([0.4952])
#
# Epoch 373/500, loss_fit = 16538.49, encoder_loss = 0.91.
# var_u: tensor([1.4787]), phi: tensor([0.4955])
#
# Epoch 374/500, loss_fit = 14956.71, encoder_loss = 0.91.
# var_u: tensor([1.4800]), phi: tensor([0.4958])
#
# Epoch 375/500, loss_fit = 15220.46, encoder_loss = 0.90.
# var_u: tensor([1.4793]), phi: tensor([0.4956])
#
# Epoch 376/500, loss_fit = 16934.51, encoder_loss = 0.88.
# var_u: tensor([1.4797]), phi: tensor([0.4957])
#
# Epoch 377/500, loss_fit = 15518.12, encoder_loss = 0.85.
# var_u: tensor([1.4791]), phi: tensor([0.4961])
#
# Epoch 378/500, loss_fit = 15308.55, encoder_loss = 0.86.
# var_u: tensor([1.4776]), phi: tensor([0.4964])
#
# Epoch 379/500, loss_fit = 14294.00, encoder_loss = 0.85.
# var_u: tensor([1.4775]), phi: tensor([0.4966])
#
# Epoch 380/500, loss_fit = 11627.99, encoder_loss = 0.87.
# var_u: tensor([1.4771]), phi: tensor([0.4965])
#
# Epoch 381/500, loss_fit = 14028.30, encoder_loss = 0.89.
# var_u: tensor([1.4773]), phi: tensor([0.4963])
#
# Epoch 382/500, loss_fit = 13196.54, encoder_loss = 0.90.
# var_u: tensor([1.4778]), phi: tensor([0.4965])
#
# Epoch 383/500, loss_fit = 12452.41, encoder_loss = 0.86.
# var_u: tensor([1.4773]), phi: tensor([0.4967])
#
# Epoch 384/500, loss_fit = 14676.29, encoder_loss = 0.86.
# var_u: tensor([1.4775]), phi: tensor([0.4968])
#
# Epoch 385/500, loss_fit = 13172.33, encoder_loss = 0.83.
# var_u: tensor([1.4768]), phi: tensor([0.4968])
#
# Epoch 386/500, loss_fit = 12374.40, encoder_loss = 0.90.
# var_u: tensor([1.4756]), phi: tensor([0.4969])
#
# Epoch 387/500, loss_fit = 12962.76, encoder_loss = 0.91.
# var_u: tensor([1.4761]), phi: tensor([0.4966])
#
# Epoch 388/500, loss_fit = 12694.12, encoder_loss = 0.89.
# var_u: tensor([1.4778]), phi: tensor([0.4967])
#
# Epoch 389/500, loss_fit = 12346.70, encoder_loss = 0.87.
# var_u: tensor([1.4771]), phi: tensor([0.4967])
#
# Epoch 390/500, loss_fit = 12895.92, encoder_loss = 0.87.
# var_u: tensor([1.4762]), phi: tensor([0.4968])
#
# Epoch 391/500, loss_fit = 13190.38, encoder_loss = 0.84.
# var_u: tensor([1.4753]), phi: tensor([0.4971])
#
# Epoch 392/500, loss_fit = 13095.29, encoder_loss = 0.85.
# var_u: tensor([1.4750]), phi: tensor([0.4972])
#
# Epoch 393/500, loss_fit = 14164.70, encoder_loss = 0.86.
# var_u: tensor([1.4762]), phi: tensor([0.4973])
#
# Epoch 394/500, loss_fit = 14509.12, encoder_loss = 0.86.
# var_u: tensor([1.4764]), phi: tensor([0.4971])
#
# Epoch 395/500, loss_fit = 15234.08, encoder_loss = 0.86.
# var_u: tensor([1.4756]), phi: tensor([0.4967])
#
# Epoch 396/500, loss_fit = 13320.96, encoder_loss = 0.84.
# var_u: tensor([1.4762]), phi: tensor([0.4971])
#
# Epoch 397/500, loss_fit = 11944.56, encoder_loss = 0.84.
# var_u: tensor([1.4762]), phi: tensor([0.4973])
#
# Epoch 398/500, loss_fit = 11329.20, encoder_loss = 0.84.
# var_u: tensor([1.4760]), phi: tensor([0.4973])
#
# Epoch 399/500, loss_fit = 12283.77, encoder_loss = 0.91.
# var_u: tensor([1.4768]), phi: tensor([0.4976])
#
# Epoch 400/500, loss_fit = 13228.95, encoder_loss = 0.92.
# var_u: tensor([1.4770]), phi: tensor([0.4973])
#
# Epoch 401/500, loss_fit = 14167.86, encoder_loss = 0.92.
# var_u: tensor([1.4785]), phi: tensor([0.4973])
#
# Epoch 402/500, loss_fit = 13747.42, encoder_loss = 0.91.
# var_u: tensor([1.4800]), phi: tensor([0.4974])
#
# Epoch 403/500, loss_fit = 13914.64, encoder_loss = 0.89.
# var_u: tensor([1.4813]), phi: tensor([0.4967])
#
# Epoch 404/500, loss_fit = 15134.20, encoder_loss = 0.88.
# var_u: tensor([1.4808]), phi: tensor([0.4965])
#
# Epoch 405/500, loss_fit = 16341.77, encoder_loss = 0.87.
# var_u: tensor([1.4796]), phi: tensor([0.4967])
#
# Epoch 406/500, loss_fit = 15584.47, encoder_loss = 0.86.
# var_u: tensor([1.4795]), phi: tensor([0.4966])
#
# Epoch 407/500, loss_fit = 15838.53, encoder_loss = 0.83.
# var_u: tensor([1.4788]), phi: tensor([0.4968])
#
# Epoch 408/500, loss_fit = 15518.12, encoder_loss = 0.85.
# var_u: tensor([1.4789]), phi: tensor([0.4968])
#
# Epoch 409/500, loss_fit = 16269.58, encoder_loss = 0.84.
# var_u: tensor([1.4802]), phi: tensor([0.4965])
#
# Epoch 410/500, loss_fit = 16194.94, encoder_loss = 0.82.
# var_u: tensor([1.4804]), phi: tensor([0.4968])
#
# Epoch 411/500, loss_fit = 18744.54, encoder_loss = 0.87.
# var_u: tensor([1.4795]), phi: tensor([0.4966])
#
# Epoch 412/500, loss_fit = 13656.79, encoder_loss = 0.94.
# var_u: tensor([1.4796]), phi: tensor([0.4968])
#
# Epoch 413/500, loss_fit = 13205.80, encoder_loss = 0.93.
# var_u: tensor([1.4790]), phi: tensor([0.4967])
#
# Epoch 414/500, loss_fit = 13115.25, encoder_loss = 0.90.
# var_u: tensor([1.4794]), phi: tensor([0.4968])
#
# Epoch 415/500, loss_fit = 14461.56, encoder_loss = 0.90.
# var_u: tensor([1.4794]), phi: tensor([0.4972])
#
# Epoch 416/500, loss_fit = 14436.65, encoder_loss = 0.88.
# var_u: tensor([1.4800]), phi: tensor([0.4973])
#
# Epoch 417/500, loss_fit = 13039.23, encoder_loss = 0.86.
# var_u: tensor([1.4794]), phi: tensor([0.4970])
#
# Epoch 418/500, loss_fit = 12011.33, encoder_loss = 0.84.
# var_u: tensor([1.4793]), phi: tensor([0.4973])
#
# Epoch 419/500, loss_fit = 12440.31, encoder_loss = 0.85.
# var_u: tensor([1.4797]), phi: tensor([0.4976])
#
# Epoch 420/500, loss_fit = 12965.96, encoder_loss = 0.82.
# var_u: tensor([1.4807]), phi: tensor([0.4976])
#
# Epoch 421/500, loss_fit = 12517.74, encoder_loss = 0.84.
# var_u: tensor([1.4812]), phi: tensor([0.4976])
#
# Epoch 422/500, loss_fit = 14764.12, encoder_loss = 0.82.
# var_u: tensor([1.4818]), phi: tensor([0.4975])
#
# Epoch 423/500, loss_fit = 14180.89, encoder_loss = 0.84.
# var_u: tensor([1.4816]), phi: tensor([0.4972])
#
# Epoch 424/500, loss_fit = 14536.86, encoder_loss = 0.84.
# var_u: tensor([1.4803]), phi: tensor([0.4974])
#
# Epoch 425/500, loss_fit = 13310.32, encoder_loss = 0.83.
# var_u: tensor([1.4786]), phi: tensor([0.4977])
#
# Epoch 426/500, loss_fit = 12534.06, encoder_loss = 0.85.
# var_u: tensor([1.4794]), phi: tensor([0.4974])
#
# Epoch 427/500, loss_fit = 13083.24, encoder_loss = 1.08.
# var_u: tensor([1.4798]), phi: tensor([0.4975])
#
# Epoch 428/500, loss_fit = 15482.90, encoder_loss = 1.01.
# var_u: tensor([1.4788]), phi: tensor([0.4971])
#
# Epoch 429/500, loss_fit = 17066.75, encoder_loss = 1.01.
# var_u: tensor([1.4801]), phi: tensor([0.4971])
#
# Epoch 430/500, loss_fit = 13922.97, encoder_loss = 0.97.
# var_u: tensor([1.4794]), phi: tensor([0.4971])
#
# Epoch 431/500, loss_fit = 16435.80, encoder_loss = 0.96.
# var_u: tensor([1.4795]), phi: tensor([0.4968])
#
# Epoch 432/500, loss_fit = 13776.40, encoder_loss = 0.94.
# var_u: tensor([1.4787]), phi: tensor([0.4967])
#
# Epoch 433/500, loss_fit = 15420.82, encoder_loss = 0.93.
# var_u: tensor([1.4790]), phi: tensor([0.4968])
#
# Epoch 434/500, loss_fit = 16103.74, encoder_loss = 0.91.
# var_u: tensor([1.4788]), phi: tensor([0.4968])
#
# Epoch 435/500, loss_fit = 16021.38, encoder_loss = 0.88.
# var_u: tensor([1.4783]), phi: tensor([0.4969])
#
# Epoch 436/500, loss_fit = 14707.43, encoder_loss = 0.89.
# var_u: tensor([1.4785]), phi: tensor([0.4970])
#
# Epoch 437/500, loss_fit = 15853.51, encoder_loss = 0.85.
# var_u: tensor([1.4787]), phi: tensor([0.4969])
#
# Epoch 438/500, loss_fit = 14427.65, encoder_loss = 0.84.
# var_u: tensor([1.4781]), phi: tensor([0.4971])
#
# Epoch 439/500, loss_fit = 15111.52, encoder_loss = 0.84.
# var_u: tensor([1.4777]), phi: tensor([0.4967])
#
# Epoch 440/500, loss_fit = 14209.71, encoder_loss = 0.86.
# var_u: tensor([1.4778]), phi: tensor([0.4969])
#
# Epoch 441/500, loss_fit = 14940.93, encoder_loss = 0.83.
# var_u: tensor([1.4771]), phi: tensor([0.4974])
#
# Epoch 442/500, loss_fit = 13567.80, encoder_loss = 0.82.
# var_u: tensor([1.4771]), phi: tensor([0.4974])
#
# Epoch 443/500, loss_fit = 13887.93, encoder_loss = 0.82.
# var_u: tensor([1.4771]), phi: tensor([0.4969])
#
# Epoch 444/500, loss_fit = 14356.28, encoder_loss = 0.83.
# var_u: tensor([1.4775]), phi: tensor([0.4974])
#
# Epoch 445/500, loss_fit = 13178.58, encoder_loss = 0.85.
# var_u: tensor([1.4795]), phi: tensor([0.4972])
#
# Epoch 446/500, loss_fit = 13478.25, encoder_loss = 0.92.
# var_u: tensor([1.4796]), phi: tensor([0.4969])
#
# Epoch 447/500, loss_fit = 12395.03, encoder_loss = 0.95.
# var_u: tensor([1.4805]), phi: tensor([0.4972])
#
# Epoch 448/500, loss_fit = 13864.71, encoder_loss = 0.92.
# var_u: tensor([1.4809]), phi: tensor([0.4969])
#
# Epoch 449/500, loss_fit = 16769.52, encoder_loss = 0.90.
# var_u: tensor([1.4805]), phi: tensor([0.4971])
#
# Epoch 450/500, loss_fit = 17035.71, encoder_loss = 0.89.
# var_u: tensor([1.4802]), phi: tensor([0.4969])
#
# Epoch 451/500, loss_fit = 14651.75, encoder_loss = 0.85.
# var_u: tensor([1.4804]), phi: tensor([0.4968])
#
# Epoch 452/500, loss_fit = 14521.01, encoder_loss = 0.84.
# var_u: tensor([1.4804]), phi: tensor([0.4972])
#
# Epoch 453/500, loss_fit = 14008.29, encoder_loss = 0.82.
# var_u: tensor([1.4805]), phi: tensor([0.4977])
#
# Epoch 454/500, loss_fit = 14255.42, encoder_loss = 0.83.
# var_u: tensor([1.4801]), phi: tensor([0.4976])
#
# Epoch 455/500, loss_fit = 14557.98, encoder_loss = 0.81.
# var_u: tensor([1.4808]), phi: tensor([0.4979])
#
# Epoch 456/500, loss_fit = 14318.52, encoder_loss = 0.82.
# var_u: tensor([1.4814]), phi: tensor([0.4981])
#
# Epoch 457/500, loss_fit = 14027.70, encoder_loss = 0.81.
# var_u: tensor([1.4817]), phi: tensor([0.4981])
#
# Epoch 458/500, loss_fit = 14665.09, encoder_loss = 0.80.
# var_u: tensor([1.4823]), phi: tensor([0.4978])
#
# Epoch 459/500, loss_fit = 13348.86, encoder_loss = 0.83.
# var_u: tensor([1.4829]), phi: tensor([0.4975])
#
# Epoch 460/500, loss_fit = 14231.11, encoder_loss = 0.84.
# var_u: tensor([1.4822]), phi: tensor([0.4970])
#
# Epoch 461/500, loss_fit = 13263.70, encoder_loss = 0.81.
# var_u: tensor([1.4816]), phi: tensor([0.4971])
#
# Epoch 462/500, loss_fit = 13219.48, encoder_loss = 0.82.
# var_u: tensor([1.4812]), phi: tensor([0.4967])
#
# Epoch 463/500, loss_fit = 14561.64, encoder_loss = 0.80.
# var_u: tensor([1.4813]), phi: tensor([0.4965])
#
# Epoch 464/500, loss_fit = 15268.57, encoder_loss = 0.82.
# var_u: tensor([1.4802]), phi: tensor([0.4966])
#
# Epoch 465/500, loss_fit = 13515.56, encoder_loss = 0.82.
# var_u: tensor([1.4797]), phi: tensor([0.4961])
#
# Epoch 466/500, loss_fit = 12239.31, encoder_loss = 0.81.
# var_u: tensor([1.4802]), phi: tensor([0.4963])
#
# Epoch 467/500, loss_fit = 13329.23, encoder_loss = 0.81.
# var_u: tensor([1.4793]), phi: tensor([0.4959])
#
# Epoch 468/500, loss_fit = 14224.89, encoder_loss = 0.81.
# var_u: tensor([1.4798]), phi: tensor([0.4957])
#
# Epoch 469/500, loss_fit = 14411.38, encoder_loss = 0.82.
# var_u: tensor([1.4797]), phi: tensor([0.4956])
#
# Epoch 470/500, loss_fit = 14237.04, encoder_loss = 0.81.
# var_u: tensor([1.4802]), phi: tensor([0.4958])
#
# Epoch 471/500, loss_fit = 15603.05, encoder_loss = 0.88.
# var_u: tensor([1.4801]), phi: tensor([0.4956])
#
# Epoch 472/500, loss_fit = 14483.78, encoder_loss = 1.01.
# var_u: tensor([1.4801]), phi: tensor([0.4956])
#
# Epoch 473/500, loss_fit = 17820.98, encoder_loss = 0.95.
# var_u: tensor([1.4793]), phi: tensor([0.4956])
#
# Epoch 474/500, loss_fit = 18012.10, encoder_loss = 0.94.
# var_u: tensor([1.4794]), phi: tensor([0.4954])
#
# Epoch 475/500, loss_fit = 13416.79, encoder_loss = 0.91.
# var_u: tensor([1.4777]), phi: tensor([0.4959])
#
# Epoch 476/500, loss_fit = 15340.09, encoder_loss = 0.88.
# var_u: tensor([1.4780]), phi: tensor([0.4957])
#
# Epoch 477/500, loss_fit = 15847.75, encoder_loss = 0.87.
# var_u: tensor([1.4776]), phi: tensor([0.4960])
#
# Epoch 478/500, loss_fit = 16302.12, encoder_loss = 0.86.
# var_u: tensor([1.4761]), phi: tensor([0.4960])
#
# Epoch 479/500, loss_fit = 16380.60, encoder_loss = 0.84.
# var_u: tensor([1.4766]), phi: tensor([0.4961])
#
# Epoch 480/500, loss_fit = 15068.34, encoder_loss = 0.83.
# var_u: tensor([1.4760]), phi: tensor([0.4956])
#
# Epoch 481/500, loss_fit = 15996.16, encoder_loss = 0.84.
# var_u: tensor([1.4752]), phi: tensor([0.4953])
#
# Epoch 482/500, loss_fit = 16182.28, encoder_loss = 0.82.
# var_u: tensor([1.4745]), phi: tensor([0.4950])
#
# Epoch 483/500, loss_fit = 15773.89, encoder_loss = 0.82.
# var_u: tensor([1.4745]), phi: tensor([0.4953])
#
# Epoch 484/500, loss_fit = 14761.44, encoder_loss = 0.81.
# var_u: tensor([1.4738]), phi: tensor([0.4955])
#
# Epoch 485/500, loss_fit = 16474.07, encoder_loss = 0.80.
# var_u: tensor([1.4740]), phi: tensor([0.4957])
#
# Epoch 486/500, loss_fit = 16574.58, encoder_loss = 0.81.
# var_u: tensor([1.4753]), phi: tensor([0.4959])
#
# Epoch 487/500, loss_fit = 15896.45, encoder_loss = 0.83.
# var_u: tensor([1.4747]), phi: tensor([0.4963])
#
# Epoch 488/500, loss_fit = 13927.90, encoder_loss = 0.83.
# var_u: tensor([1.4758]), phi: tensor([0.4962])
#
# Epoch 489/500, loss_fit = 15254.54, encoder_loss = 0.80.
# var_u: tensor([1.4761]), phi: tensor([0.4958])
#
# Epoch 490/500, loss_fit = 15952.89, encoder_loss = 0.82.
# var_u: tensor([1.4761]), phi: tensor([0.4958])
#
# Epoch 491/500, loss_fit = 17358.46, encoder_loss = 0.84.
# var_u: tensor([1.4756]), phi: tensor([0.4960])
#
# Epoch 492/500, loss_fit = 18734.58, encoder_loss = 0.82.
# var_u: tensor([1.4767]), phi: tensor([0.4960])
#
# Epoch 493/500, loss_fit = 15884.61, encoder_loss = 0.82.
# var_u: tensor([1.4768]), phi: tensor([0.4961])
#
# Epoch 494/500, loss_fit = 17174.88, encoder_loss = 0.80.
# var_u: tensor([1.4757]), phi: tensor([0.4960])
#
# Epoch 495/500, loss_fit = 17217.45, encoder_loss = 0.80.
# var_u: tensor([1.4764]), phi: tensor([0.4957])
#
# Epoch 496/500, loss_fit = 16532.89, encoder_loss = 0.78.
# var_u: tensor([1.4773]), phi: tensor([0.4956])
#
# Epoch 497/500, loss_fit = 16497.27, encoder_loss = 0.77.
# var_u: tensor([1.4769]), phi: tensor([0.4952])
#
# Epoch 498/500, loss_fit = 14892.37, encoder_loss = 0.80.
# var_u: tensor([1.4769]), phi: tensor([0.4949])
#
# Epoch 499/500, loss_fit = 15950.39, encoder_loss = 0.86.
# var_u: tensor([1.4788]), phi: tensor([0.4946])
#
# Epoch 500/500, loss_fit = 15376.67, encoder_loss = 0.81.

# %%
plt.plot(learning_rates)
plt.plot(learning_rates_encoder)

# %%
data = np.stack([tensor.flatten().numpy() for tensor in param_values], axis=0)


# Create figure and axes
fig, ax = plt.subplots()

# Loop through each feature
for i in range(data.shape[1]):
    ax.plot(data[:, i])

# Add legend and labels
ax.legend()
plt.xlabel('Time period')
plt.ylabel('Feature value')
plt.title('Evolution of features over time')

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(model_sample.decoder.wz.detach().numpy(), model.decoder.wz.detach().numpy())
plt.plot([-3,3], [-3,3], color="red")
plt.plot([-3,3], [3,-3], color="red")
plt.show()

plt.scatter(model_sample.decoder.wx.detach().numpy(), model.decoder.wx.detach().numpy())
plt.plot([-3,3], [-3,3], color="red")
plt.plot([-3,3], [3,-3], color="red")
plt.show()

# %%
model.encoder.plot(data_sample['x'], data_sample['y'], data_sample['z'], data_sample['u'])

# %% [markdown]
# # GLLVM Longitudinal

# %%
import torch
from torch import nn
from torch.optim.lr_scheduler import StepLR # scheduler
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset


# Check if CUDA is available
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("CUDA is available. Using GPU.")
else:
    device = torch.device("cpu")
    print("CUDA is not available. Using CPU.")
# Out:
# CUDA is available. Using GPU.

# %% [markdown]
# A Longitudinal GLLVM is a model with 1 variable per period for T periods, n observations, and p responses, and k covariates. We also have a random effect for each observation x response.

# %%
n = 10000
p = 13
q = 1
k = 3
T = 9

DIMENSIONS_Y = (n, T, p) 
DIMENSIONS_X = (n, T, k)
DIMENSIONS_Z = (n, T, q)
DIMENSIONS_U = (n, 1, p)

# %%
response_types = {
    'binary': [0,1,2,3,4,5,6,7],
    'ordinal': [9, 10],
    'counts': [8, 11, 12]
}

response_types = {
    'binary': [0,1,2,3,4,5,6,7, 9, 10],
    'counts': [8, 11, 12]
}

link = {
    'binary' : lambda x: torch.logit(x),
    'ordinal': lambda x: torch.logit(x),
    'counts': lambda x: torch.log(x)
}


linkinv = {
    'binary': lambda x: 1/(1+torch.exp(-x)),
    'ordinal': lambda x: 1/(1+torch.exp(-x)),
    'counts': lambda x: torch.exp(x)
}

response_transform = {
    'binary' : lambda x: 2*x - 1,
    'ordinal': lambda x: 2*x - 1,
    'counts': lambda x: torch.log(x+1)
}

# %% [markdown]
# They can be of many response types. Here for the sake of illutration we will consider 3 response types: gaussian, binary, and poisson.
#
# We allow for transformation of the data, which we account for in the estimation. In particular, Poisson data may be numerically problematic because their conditional expectation is the exponential of the linear predictor. Small differences in the latter can result in dramatic differences in the gradient. For instance, we can transform poisson with the following function $x \rightarrow \log(x+1)$. This transforms is needed in 2 places: for encoding, and at the loss function for computing the gradient.
#
# ## Computing the scale parameter
#
# The scale parameter is computed in a second step (on the fit residual). They are updated at every iteration. This is not yet implemented.
#
#
# ### Modules
#
# We need LongitudinalGLLVM as the overarching module, Sample which samples the data and takes additional arguments (such as nuisance parameters), Decoder which contains all the parameters of interest, and Encoder which encodes the data using a Neural Network.
#
# ### Design of the Encoder
# Since the estimation problem for Z is the same at each time step, we model the encoder using a RNN. At each time step, the same encoder is used to compute the Z. At the same time, the hidden state of the RNN is used to predict the U variable, which is constant over time for each observation.
#
# ### Accounting for missing values
# Missing values are simply imputed every period by their (conditional) mean.

# %%
class LongitudinalGLLVM(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
        self.sample = Sample(self.decoder)
    
    def plot_cov(self, what="linpar", x=None):
        data_sample = self.sample(x=x)
        data =  data_sample[what].detach().view(n, -1).cpu().numpy()
        cov_matrix = np.cov(data, rowvar=False)

        plt.figure(figsize=(10,10))
        sns.heatmap(cov_matrix, annot=False, fmt='g')
        plt.show()
    
    def impute(self, x, y, mask, nsteps=10):
        """ Impute the missing values provided by the mask (True is missing) and return x imputed"""
        for _ in range(nsteps):
            z, u = self.encoder(x,y, transform_response = True)
            _, mean = self.decoder(x,z,u)
            y[mask] = mean[mask]
        return y

class Sample(nn.Module):
    def __init__(self, decoder):
        super().__init__()
        self.decoder = decoder
        self.phi = torch.ones(1).to(device) * .8
        self.var_u = torch.ones(1).to(device) * 1.0

    # sampling comes here
    
    def forward(self, x, n=None):
        with torch.no_grad():
            if x is None:
                Warning("x was set to None for sampling. X is usually fixed. Are you sure you want to sample x?")
                x = torch.randn((n, T, k-1)).to(device)
                # Add intercepts and time information
                time_data = torch.from_numpy(np.linspace(0,4,9)).float().expand(x.shape[0], -1).unsqueeze(2).to(device)
                x = torch.cat([x, time_data], dim=2)
            
            n = x.shape[0]

            u = torch.randn((n, 1, p)).to(device) * torch.sqrt(self.var_u)
            d = torch.randn((n, T, q)).to(device)
            z = self.AR(d)

            linpar, mean = self.decoder(x, z, u) # decoder gives the expectation

            y = self.sample_response(mean)

            return {"x":x, "y":y, "z":z, "u":u, "linpar":linpar, "mean":mean}

    def sample_response(self, mean):
            y = torch.zeros_like(mean).to(device)
            for response_type, response_id in response_types.items():
                if response_type == "binary":
                    y[:,:,response_id] = torch.bernoulli(mean[:,:,response_id]).to(device)
                elif response_type == "ordinal":
                    cum_probs = mean[:,:,response_id]
                    # draw one uniform for the whole vector
                    random = torch.rand((*cum_probs.shape[0:2], 1)).to(device)
                    # compare with the cumulative probabilities
                    ordinal = torch.sum(random > cum_probs, dim=2)
                    ordinal = torch.nn.functional.one_hot(ordinal).squeeze().float()
                    ordinal = ordinal[:,:,1:] # discard the first column of the one_hot encoding, as it is superfluous (as a 0)
                    y[:,:,response_id] = ordinal
                elif response_type == "counts":
                    y[:,:,response_id] = torch.poisson(mean[:,:,response_id])
            return y

    def AR(self, d):
        z = d.clone()

        for t in range(1, z.shape[1]):
            z[:,t] = z[:,t] + z[:, t-1].clone() * self.phi  # we need to clone else the gradient wants to pass through it
        return z
                
    
class Decoder(nn.Module):
    # Yields the expectation
    def __init__(self):
        super().__init__()

        # decoder part (our parameters of interest)
        self.wz = nn.Parameter(torch.randn((q, p)) * 1.)
        self.wx = nn.Parameter(torch.randn((1, k, p))* 1.) # Measurement invariance!
        self.bias = nn.Parameter(torch.zeros((1, 1, p))* 1.) # Measurement invariance!

    # decoding (computing the conditional mean)
    def forward(self, x, z, u):

        xwx = (x.unsqueeze(2) @ self.wx).squeeze() # see section "details of tensorproducts"
        zwz = (z.unsqueeze(2) @ self.wz).squeeze()
        # for the ordinal variables:
        linpar = self.bias + xwx + zwz + u 

        # Apply the inverse link to get the conditional expectation
        mean  = torch.zeros_like(linpar)
        for response_type, response_id in response_types.items():
            mean[:,:,response_id] = linkinv[response_type](linpar[:,:,response_id])
        # Transform the 
        return linpar, mean



class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        # encoder part
        # input dimension is (p+k) (responses + covariates)
        # output dimension is q+p (one latent )
        input_size = p + k
        hidden_size = (p + q) * 5
        self.rnn = nn.RNN(input_size = input_size, hidden_size = hidden_size, batch_first=True)
        
        self.fc = nn.Sequential(
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
        )
        # fully connected layers for Z and U
        self.fc_Z = nn.Sequential(
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = q),
        )

        self.fc_U = nn.Sequential(
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features = hidden_size, out_features = hidden_size),
            nn.ReLU(),
            nn.Linear(in_features=hidden_size, out_features = p)
        )

        self.optimizer =  torch.optim.Adam(self.parameters(), lr=.01)
        self.scheduler = StepLR(self.optimizer, step_size=100, gamma=.95)
        self.loss = nn.MSELoss()

    
    def forward(self, x, y, transform_response = False):
        # Initialize hidden state

        # pass the input through the RNN
        if transform_response:
            y_transformed = torch.zeros_like(y)
            with torch.no_grad():
                for response_type, response_id in response_types.items():
                    y_transformed[:,:,response_id] = response_transform[response_type](y[:,:,response_id])
        else:
            y_transformed = y

        xy = torch.cat([x, y_transformed], dim=2)
        rnn_out, _ = self.rnn(xy)
        out = self.fc(rnn_out)
        z_pred = self.fc_Z(out)
        u_pred = self.fc_U(out[:, -1, :]).unsqueeze(1)
        return z_pred, u_pred
    
    def fit(self, x, y, z, u, epochs = 100, verbose = False):
        y = y.clone()
        with torch.no_grad():
            for response_type, response_id in response_types.items():
                y[:,:,response_id] = response_transform[response_type](y[:,:,response_id])
        # Fit the encoder
        for epoch in range(epochs):
            self.optimizer.zero_grad()

            z_pred, u_pred = self(x, y, transform_response = False)

            loss = self.loss(z_pred, z) + self.loss(u_pred, u)

            if verbose:
                print(f"\nEpoch {epoch}/{epochs}, loss={loss}")
            loss.backward()
            self.optimizer.step()
            self.scheduler.step()

        return loss
    
    def plot(self, x, y, z, u):
        with torch.no_grad():
            z_pred, u_pred = self(x, y, transform_response = True)

        fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,4))

        ax1.scatter(z, z_pred)
        ax1.set_xlabel('Z True')
        ax1.set_ylabel('Z Pred')
        ax1.set_title('Encoded values of Z')
        ax1.plot(ax1.get_xlim(), ax1.get_ylim(), ls="--", color="red")

        ax2.scatter(u, u_pred)
        ax2.set_xlabel('U True')
        ax2.set_ylabel('U Pred')
        ax2.set_title('Encoded values of U')
        ax2.plot(ax2.get_xlim(), ax2.get_ylim(), ls="--", color="red")


        plt.show()
        


class MELoss(nn.Module):
    def __init__(self):
        super().__init__()
    
    def forward(self, y, linpar, ys, linpars, mask=None):
        """Computes the loss. hat is recontructed y, ys is simulated"""
        y_transformed = torch.zeros_like(y)
        ys_transformed = torch.zeros_like(ys)
        with torch.no_grad():
            for response_type, response_id in response_types.items():
                y_transformed[:,:,response_id] = response_transform[response_type](y[:,:,response_id])
                ys_transformed[:,:,response_id] = response_transform[response_type](ys[:,:,response_id])


        if mask is not None:
            return -torch.sum(y_transformed* linpar * ~mask - ys_transformed * linpars* ~mask)/y.shape[0]
        else:
            return -torch.sum(y_transformed* linpar - ys_transformed * linpars) / y.shape[0]
        # return torch.mean(torch.pow(y-linpar, 2) - torch.pow(ys - linpars, 2))
        # loss = torch.mean(y.T @ linpar - ys.T @linpars)/y.shape[0]
        # return loss

# %%
model_sample = LongitudinalGLLVM().to(device)
data_sample = model_sample.sample(x=None, n=n)

# adding missing data
probability_missing = 0.4
mask = torch.rand_like(data_sample['y']).to(device) < probability_missing
data_sample['y'][mask] = 0.5

# %%
model = LongitudinalGLLVM().to(device)
criterion = MELoss()
optimizer = torch.optim.Adam(model.decoder.parameters(), lr=.1)
scheduler = StepLR(optimizer, step_size=10, gamma=.95)
mseLoss = nn.MSELoss()
epochs = 500



def compute_autocorr(z):
    # Compute the sample autocovariance and autocorrelation
    autocovariance = torch.mean((z[:, 1:] - torch.mean(z[:, 1:])) * (z[:, :-1] - torch.mean(z[:, :-1])), dim=1)
    autocorrelation = autocovariance / torch.var(z[:, :-1])

    # Estimate phi using the autocorrelation formula for AR(1)
    phi = torch.mean(autocorrelation)

    return phi

# %%
# create tensor dataset
losses = []
learning_rates = []
learning_rates_encoder = []
param_values = []

for epoch in range(1, epochs +1):
    optimizer.zero_grad()

    # impute and sample
    with torch.no_grad():
        # data_true["y"] = model.impute(data_true["x"], data_true["y"], mask=mask["y"], nsteps=5)
        # simulate data from the current parameter values, Unconditionally (!)
        data_sim = model.sample(x=data_sample["x"])
        y_masked = data_sim["y"].clone()
        y_masked[mask] = 0.5
        
        assert torch.eq(data_sim["x"], data_sample["x"]).all().item()

        # compute the imputing values without the gradients
        zhat_sample, uhat_sample = model.encoder(data_sample["x"], data_sample["y"], transform_response=True)
        zhat_sim, uhat_sim = model.encoder(data_sim["x"], y_masked, transform_response=True)


    # train the encoder on the simulated data
    encoder_loss = model.encoder.fit(data_sim["x"], data_sim["y"], data_sim["z"], data_sim["u"],  epochs= 5) 
    
    # compute the decoded value
    linpar_sample, mean_sample = model.decoder(data_sample["x"], zhat_sample, uhat_sample)
    linpar_sim, mean_sim = model.decoder(data_sim["x"], zhat_sim, uhat_sim)

    # # impute values
    # data_sample["y"] = model.impute(data_sample["x"], data_sample["y"], mask, nsteps=2)
    # data_sim["y"] = model.impute(data_sim["x"], data_sim["y"], mask, nsteps=2)

    # model.decoder.wz.grad = mygrad
    loss = criterion(data_sample["y"], linpar_sample,  y_masked, linpar_sim, mask=mask)
    loss.backward()

    # Update nuisance parameters
    with torch.no_grad():
        model.sample.var_u = .8* model.sample.var_u + .2 * torch.var(uhat_sample) * (model.sample.var_u / torch.var(uhat_sim))
        model.sample.phi = .8 * model.sample.phi + .2 * compute_autocorr(zhat_sample) * model.sample.phi / compute_autocorr(zhat_sim)
        if model.sample.phi > .9:
            model.sample.phi = torch.ones(1) * .9 
        # model.sample.phi = zhat_sample[:,1:,:] - zhat_sample[:,:-1,:]
        print(f'var_u: {model.sample.var_u}, phi: {model.sample.phi}')


    with torch.no_grad():   
        fit = mseLoss(mean_sample, data_sample["y"])


    optimizer.step()
    scheduler.step()

    losses.append(fit.item())
    learning_rates.append(optimizer.param_groups[0]['lr'])
    learning_rates_encoder.append(model.encoder.optimizer.param_groups[0]['lr'])
    param_values.append(model.decoder.wz.clone().detach())

    print(f"\nEpoch {epoch}/{epochs}, loss_fit = {fit.item():.2f}, encoder_loss = {encoder_loss.item():.2f}.")
# Out:
# var_u: tensor([1.0073], device='cuda:0'), phi: tensor([0.8427], device='cuda:0')
#
# Epoch 1/500, loss_fit = 33613.80, encoder_loss = 2.43.
# var_u: tensor([0.9824], device='cuda:0'), phi: tensor([0.8389], device='cuda:0')
#
# Epoch 2/500, loss_fit = 11381.47, encoder_loss = 2.48.
# var_u: tensor([0.9338], device='cuda:0'), phi: tensor([0.7948], device='cuda:0')
#
# Epoch 3/500, loss_fit = 11681.24, encoder_loss = 2.09.
# var_u: tensor([0.8980], device='cuda:0'), phi: tensor([0.7568], device='cuda:0')
#
# Epoch 4/500, loss_fit = 11295.74, encoder_loss = 1.62.
# var_u: tensor([0.8600], device='cuda:0'), phi: tensor([0.7258], device='cuda:0')
#
# Epoch 5/500, loss_fit = 11290.03, encoder_loss = 1.42.
# var_u: tensor([0.8197], device='cuda:0'), phi: tensor([0.6574], device='cuda:0')
#
# Epoch 6/500, loss_fit = 11331.72, encoder_loss = 1.33.
# var_u: tensor([0.7898], device='cuda:0'), phi: tensor([0.6316], device='cuda:0')
#
# Epoch 7/500, loss_fit = 11276.05, encoder_loss = 1.24.
# var_u: tensor([0.7665], device='cuda:0'), phi: tensor([0.6151], device='cuda:0')
#
# Epoch 8/500, loss_fit = 11230.21, encoder_loss = 1.21.
# var_u: tensor([0.7582], device='cuda:0'), phi: tensor([0.5989], device='cuda:0')
#
# Epoch 9/500, loss_fit = 11232.15, encoder_loss = 1.18.
# var_u: tensor([0.7568], device='cuda:0'), phi: tensor([0.5834], device='cuda:0')
#
# Epoch 10/500, loss_fit = 11260.44, encoder_loss = 1.18.
# var_u: tensor([0.7690], device='cuda:0'), phi: tensor([0.5685], device='cuda:0')
#
# Epoch 11/500, loss_fit = 11278.80, encoder_loss = 1.19.
# var_u: tensor([0.7972], device='cuda:0'), phi: tensor([0.5567], device='cuda:0')
#
# Epoch 12/500, loss_fit = 11188.46, encoder_loss = 1.21.
# var_u: tensor([0.8537], device='cuda:0'), phi: tensor([0.5455], device='cuda:0')
#
# Epoch 13/500, loss_fit = 11183.68, encoder_loss = 1.23.
# var_u: tensor([0.9174], device='cuda:0'), phi: tensor([0.5384], device='cuda:0')
#
# Epoch 14/500, loss_fit = 11169.24, encoder_loss = 1.29.
# var_u: tensor([1.0375], device='cuda:0'), phi: tensor([0.5339], device='cuda:0')
#
# Epoch 15/500, loss_fit = 11082.78, encoder_loss = 1.35.
# var_u: tensor([1.1400], device='cuda:0'), phi: tensor([0.5318], device='cuda:0')
#
# Epoch 16/500, loss_fit = 10963.53, encoder_loss = 1.47.
# var_u: tensor([1.1852], device='cuda:0'), phi: tensor([0.5327], device='cuda:0')
#
# Epoch 17/500, loss_fit = 11025.13, encoder_loss = 1.54.
# var_u: tensor([1.2755], device='cuda:0'), phi: tensor([0.5363], device='cuda:0')
#
# Epoch 18/500, loss_fit = 10976.39, encoder_loss = 1.55.
# var_u: tensor([1.3073], device='cuda:0'), phi: tensor([0.5452], device='cuda:0')
#
# Epoch 19/500, loss_fit = 10904.47, encoder_loss = 1.62.
# var_u: tensor([1.3241], device='cuda:0'), phi: tensor([0.5542], device='cuda:0')
#
# Epoch 20/500, loss_fit = 10645.11, encoder_loss = 1.59.
# var_u: tensor([1.3289], device='cuda:0'), phi: tensor([0.5628], device='cuda:0')
#
# Epoch 21/500, loss_fit = 10109.92, encoder_loss = 1.56.
# var_u: tensor([1.3462], device='cuda:0'), phi: tensor([0.5704], device='cuda:0')
#
# Epoch 22/500, loss_fit = 9616.50, encoder_loss = 1.54.
# var_u: tensor([1.3688], device='cuda:0'), phi: tensor([0.5792], device='cuda:0')
#
# Epoch 23/500, loss_fit = 9968.80, encoder_loss = 1.52.
# var_u: tensor([1.3908], device='cuda:0'), phi: tensor([0.5873], device='cuda:0')
#
# Epoch 24/500, loss_fit = 9343.29, encoder_loss = 1.51.
# var_u: tensor([1.4231], device='cuda:0'), phi: tensor([0.5957], device='cuda:0')
#
# Epoch 25/500, loss_fit = 8991.69, encoder_loss = 1.51.
# var_u: tensor([1.4514], device='cuda:0'), phi: tensor([0.6076], device='cuda:0')
#
# Epoch 26/500, loss_fit = 8272.27, encoder_loss = 1.53.
# var_u: tensor([1.4816], device='cuda:0'), phi: tensor([0.6210], device='cuda:0')
#
# Epoch 27/500, loss_fit = 6896.49, encoder_loss = 1.59.
# var_u: tensor([1.4915], device='cuda:0'), phi: tensor([0.6328], device='cuda:0')
#
# Epoch 28/500, loss_fit = 6553.98, encoder_loss = 1.57.
# var_u: tensor([1.5222], device='cuda:0'), phi: tensor([0.6456], device='cuda:0')
#
# Epoch 29/500, loss_fit = 6082.90, encoder_loss = 1.56.
# var_u: tensor([1.5384], device='cuda:0'), phi: tensor([0.6595], device='cuda:0')
#
# Epoch 30/500, loss_fit = 6172.87, encoder_loss = 1.56.
# var_u: tensor([1.5399], device='cuda:0'), phi: tensor([0.6723], device='cuda:0')
#
# Epoch 31/500, loss_fit = 5310.54, encoder_loss = 1.57.
# var_u: tensor([1.5322], device='cuda:0'), phi: tensor([0.6847], device='cuda:0')
#
# Epoch 32/500, loss_fit = 5061.00, encoder_loss = 1.57.
# var_u: tensor([1.5300], device='cuda:0'), phi: tensor([0.6973], device='cuda:0')
#
# Epoch 33/500, loss_fit = 4833.22, encoder_loss = 1.58.
# var_u: tensor([1.5092], device='cuda:0'), phi: tensor([0.7098], device='cuda:0')
#
# Epoch 34/500, loss_fit = 4965.13, encoder_loss = 1.55.
# var_u: tensor([1.5033], device='cuda:0'), phi: tensor([0.7195], device='cuda:0')
#
# Epoch 35/500, loss_fit = 4966.48, encoder_loss = 1.53.
# var_u: tensor([1.4909], device='cuda:0'), phi: tensor([0.7311], device='cuda:0')
#
# Epoch 36/500, loss_fit = 6513.55, encoder_loss = 1.52.
# var_u: tensor([1.4723], device='cuda:0'), phi: tensor([0.7420], device='cuda:0')
#
# Epoch 37/500, loss_fit = 4991.95, encoder_loss = 1.53.
# var_u: tensor([1.4520], device='cuda:0'), phi: tensor([0.7521], device='cuda:0')
#
# Epoch 38/500, loss_fit = 5927.88, encoder_loss = 1.52.
# var_u: tensor([1.4324], device='cuda:0'), phi: tensor([0.7625], device='cuda:0')
#
# Epoch 39/500, loss_fit = 5983.80, encoder_loss = 1.53.
# var_u: tensor([1.4143], device='cuda:0'), phi: tensor([0.7711], device='cuda:0')
#
# Epoch 40/500, loss_fit = 5253.49, encoder_loss = 1.52.
# var_u: tensor([1.3942], device='cuda:0'), phi: tensor([0.7772], device='cuda:0')
#
# Epoch 41/500, loss_fit = 4921.60, encoder_loss = 1.51.
# var_u: tensor([1.3777], device='cuda:0'), phi: tensor([0.7816], device='cuda:0')
#
# Epoch 42/500, loss_fit = 4774.50, encoder_loss = 1.50.
# var_u: tensor([1.3649], device='cuda:0'), phi: tensor([0.7834], device='cuda:0')
#
# Epoch 43/500, loss_fit = 4730.69, encoder_loss = 1.59.
# var_u: tensor([1.3367], device='cuda:0'), phi: tensor([0.7870], device='cuda:0')
#
# Epoch 44/500, loss_fit = 5673.28, encoder_loss = 1.52.
# var_u: tensor([1.3152], device='cuda:0'), phi: tensor([0.7880], device='cuda:0')
#
# Epoch 45/500, loss_fit = 5087.98, encoder_loss = 1.51.
# var_u: tensor([1.2977], device='cuda:0'), phi: tensor([0.7904], device='cuda:0')
#
# Epoch 46/500, loss_fit = 5879.22, encoder_loss = 1.48.
# var_u: tensor([1.2901], device='cuda:0'), phi: tensor([0.7885], device='cuda:0')
#
# Epoch 47/500, loss_fit = 6155.77, encoder_loss = 1.47.
# var_u: tensor([1.2870], device='cuda:0'), phi: tensor([0.7865], device='cuda:0')
#
# Epoch 48/500, loss_fit = 6206.45, encoder_loss = 1.47.
# var_u: tensor([1.2797], device='cuda:0'), phi: tensor([0.7880], device='cuda:0')
#
# Epoch 49/500, loss_fit = 6154.55, encoder_loss = 1.51.
# var_u: tensor([1.2658], device='cuda:0'), phi: tensor([0.7865], device='cuda:0')
#
# Epoch 50/500, loss_fit = 5770.44, encoder_loss = 1.51.
# var_u: tensor([1.2562], device='cuda:0'), phi: tensor([0.7871], device='cuda:0')
#
# Epoch 51/500, loss_fit = 7367.87, encoder_loss = 1.48.
# var_u: tensor([1.2533], device='cuda:0'), phi: tensor([0.7873], device='cuda:0')
#
# Epoch 52/500, loss_fit = 6527.78, encoder_loss = 1.45.
# var_u: tensor([1.2463], device='cuda:0'), phi: tensor([0.7858], device='cuda:0')
#
# Epoch 53/500, loss_fit = 6437.75, encoder_loss = 1.47.
# var_u: tensor([1.2463], device='cuda:0'), phi: tensor([0.7846], device='cuda:0')
#
# Epoch 54/500, loss_fit = 4491.63, encoder_loss = 1.45.
# var_u: tensor([1.2330], device='cuda:0'), phi: tensor([0.7844], device='cuda:0')
#
# Epoch 55/500, loss_fit = 6304.20, encoder_loss = 1.42.
# var_u: tensor([1.2243], device='cuda:0'), phi: tensor([0.7841], device='cuda:0')
#
# Epoch 56/500, loss_fit = 5805.07, encoder_loss = 1.41.
# var_u: tensor([1.2168], device='cuda:0'), phi: tensor([0.7840], device='cuda:0')
#
# Epoch 57/500, loss_fit = 4900.73, encoder_loss = 1.39.
# var_u: tensor([1.2096], device='cuda:0'), phi: tensor([0.7830], device='cuda:0')
#
# Epoch 58/500, loss_fit = 4801.56, encoder_loss = 1.38.
# var_u: tensor([1.2043], device='cuda:0'), phi: tensor([0.7839], device='cuda:0')
#
# Epoch 59/500, loss_fit = 3874.37, encoder_loss = 1.39.
# var_u: tensor([1.1979], device='cuda:0'), phi: tensor([0.7836], device='cuda:0')
#
# Epoch 60/500, loss_fit = 4594.28, encoder_loss = 1.36.
# var_u: tensor([1.1913], device='cuda:0'), phi: tensor([0.7833], device='cuda:0')
#
# Epoch 61/500, loss_fit = 4197.56, encoder_loss = 1.37.
# var_u: tensor([1.1845], device='cuda:0'), phi: tensor([0.7841], device='cuda:0')
#
# Epoch 62/500, loss_fit = 4274.13, encoder_loss = 1.33.
# var_u: tensor([1.1769], device='cuda:0'), phi: tensor([0.7852], device='cuda:0')
#
# Epoch 63/500, loss_fit = 3946.29, encoder_loss = 1.33.
# var_u: tensor([1.1692], device='cuda:0'), phi: tensor([0.7851], device='cuda:0')
#
# Epoch 64/500, loss_fit = 4956.37, encoder_loss = 1.32.
# var_u: tensor([1.1617], device='cuda:0'), phi: tensor([0.7819], device='cuda:0')
#
# Epoch 65/500, loss_fit = 4210.74, encoder_loss = 1.31.
# var_u: tensor([1.1550], device='cuda:0'), phi: tensor([0.7822], device='cuda:0')
#
# Epoch 66/500, loss_fit = 4684.58, encoder_loss = 1.30.
# var_u: tensor([1.1482], device='cuda:0'), phi: tensor([0.7823], device='cuda:0')
#
# Epoch 67/500, loss_fit = 4302.96, encoder_loss = 1.30.
# var_u: tensor([1.1403], device='cuda:0'), phi: tensor([0.7820], device='cuda:0')
#
# Epoch 68/500, loss_fit = 4117.93, encoder_loss = 1.31.
# var_u: tensor([1.1358], device='cuda:0'), phi: tensor([0.7822], device='cuda:0')
#
# Epoch 69/500, loss_fit = 4264.04, encoder_loss = 1.28.
# var_u: tensor([1.1345], device='cuda:0'), phi: tensor([0.7818], device='cuda:0')
#
# Epoch 70/500, loss_fit = 4239.71, encoder_loss = 1.28.
# var_u: tensor([1.1292], device='cuda:0'), phi: tensor([0.7832], device='cuda:0')
#
# Epoch 71/500, loss_fit = 4337.77, encoder_loss = 1.27.
# var_u: tensor([1.1231], device='cuda:0'), phi: tensor([0.7828], device='cuda:0')
#
# Epoch 72/500, loss_fit = 4795.99, encoder_loss = 1.27.
# var_u: tensor([1.1203], device='cuda:0'), phi: tensor([0.7841], device='cuda:0')
#
# Epoch 73/500, loss_fit = 5333.72, encoder_loss = 1.26.
# var_u: tensor([1.1166], device='cuda:0'), phi: tensor([0.7878], device='cuda:0')
#
# Epoch 74/500, loss_fit = 4477.69, encoder_loss = 1.26.
# var_u: tensor([1.1123], device='cuda:0'), phi: tensor([0.7879], device='cuda:0')
#
# Epoch 75/500, loss_fit = 4672.61, encoder_loss = 1.26.
# var_u: tensor([1.1082], device='cuda:0'), phi: tensor([0.7891], device='cuda:0')
#
# Epoch 76/500, loss_fit = 4792.04, encoder_loss = 1.27.
# var_u: tensor([1.1028], device='cuda:0'), phi: tensor([0.7901], device='cuda:0')
#
# Epoch 77/500, loss_fit = 4544.93, encoder_loss = 1.29.
# var_u: tensor([1.0966], device='cuda:0'), phi: tensor([0.7909], device='cuda:0')
#
# Epoch 78/500, loss_fit = 4842.37, encoder_loss = 1.26.
# var_u: tensor([1.0919], device='cuda:0'), phi: tensor([0.7913], device='cuda:0')
#
# Epoch 79/500, loss_fit = 4108.48, encoder_loss = 1.25.
# var_u: tensor([1.0858], device='cuda:0'), phi: tensor([0.7908], device='cuda:0')
#
# Epoch 80/500, loss_fit = 4401.84, encoder_loss = 1.24.
# var_u: tensor([1.0825], device='cuda:0'), phi: tensor([0.7903], device='cuda:0')
#
# Epoch 81/500, loss_fit = 4653.89, encoder_loss = 1.24.
# var_u: tensor([1.0788], device='cuda:0'), phi: tensor([0.7905], device='cuda:0')
#
# Epoch 82/500, loss_fit = 3745.19, encoder_loss = 1.24.
# var_u: tensor([1.0745], device='cuda:0'), phi: tensor([0.7904], device='cuda:0')
#
# Epoch 83/500, loss_fit = 4145.52, encoder_loss = 1.23.
# var_u: tensor([1.0717], device='cuda:0'), phi: tensor([0.7922], device='cuda:0')
#
# Epoch 84/500, loss_fit = 4243.94, encoder_loss = 1.23.
# var_u: tensor([1.0690], device='cuda:0'), phi: tensor([0.7912], device='cuda:0')
#
# Epoch 85/500, loss_fit = 4052.14, encoder_loss = 1.23.
# var_u: tensor([1.0651], device='cuda:0'), phi: tensor([0.7905], device='cuda:0')
#
# Epoch 86/500, loss_fit = 3953.80, encoder_loss = 1.21.
# var_u: tensor([1.0628], device='cuda:0'), phi: tensor([0.7898], device='cuda:0')
#
# Epoch 87/500, loss_fit = 3948.70, encoder_loss = 1.21.
# var_u: tensor([1.0608], device='cuda:0'), phi: tensor([0.7914], device='cuda:0')
#
# Epoch 88/500, loss_fit = 4565.85, encoder_loss = 1.20.
# var_u: tensor([1.0597], device='cuda:0'), phi: tensor([0.7918], device='cuda:0')
#
# Epoch 89/500, loss_fit = 3255.97, encoder_loss = 1.22.
# var_u: tensor([1.0560], device='cuda:0'), phi: tensor([0.7935], device='cuda:0')
#
# Epoch 90/500, loss_fit = 3446.00, encoder_loss = 1.19.
# var_u: tensor([1.0535], device='cuda:0'), phi: tensor([0.7921], device='cuda:0')
#
# Epoch 91/500, loss_fit = 3772.25, encoder_loss = 1.18.
# var_u: tensor([1.0510], device='cuda:0'), phi: tensor([0.7922], device='cuda:0')
#
# Epoch 92/500, loss_fit = 4058.90, encoder_loss = 1.18.
# var_u: tensor([1.0479], device='cuda:0'), phi: tensor([0.7910], device='cuda:0')
#
# Epoch 93/500, loss_fit = 2948.46, encoder_loss = 1.18.
# var_u: tensor([1.0465], device='cuda:0'), phi: tensor([0.7905], device='cuda:0')
#
# Epoch 94/500, loss_fit = 3365.53, encoder_loss = 1.18.
# var_u: tensor([1.0447], device='cuda:0'), phi: tensor([0.7911], device='cuda:0')
#
# Epoch 95/500, loss_fit = 3122.24, encoder_loss = 1.17.
# var_u: tensor([1.0428], device='cuda:0'), phi: tensor([0.7920], device='cuda:0')
#
# Epoch 96/500, loss_fit = 3232.22, encoder_loss = 1.20.
# var_u: tensor([1.0420], device='cuda:0'), phi: tensor([0.7911], device='cuda:0')
#
# Epoch 97/500, loss_fit = 3417.05, encoder_loss = 1.17.
# var_u: tensor([1.0413], device='cuda:0'), phi: tensor([0.7927], device='cuda:0')
#
# Epoch 98/500, loss_fit = 3672.02, encoder_loss = 1.17.
# var_u: tensor([1.0411], device='cuda:0'), phi: tensor([0.7914], device='cuda:0')
#
# Epoch 99/500, loss_fit = 3128.30, encoder_loss = 1.15.
# var_u: tensor([1.0404], device='cuda:0'), phi: tensor([0.7920], device='cuda:0')
#
# Epoch 100/500, loss_fit = 2757.22, encoder_loss = 1.16.
# var_u: tensor([1.0396], device='cuda:0'), phi: tensor([0.7905], device='cuda:0')
#
# Epoch 101/500, loss_fit = 2924.78, encoder_loss = 1.18.
# var_u: tensor([1.0356], device='cuda:0'), phi: tensor([0.7913], device='cuda:0')
#
# Epoch 102/500, loss_fit = 3281.36, encoder_loss = 1.17.
# var_u: tensor([1.0332], device='cuda:0'), phi: tensor([0.7923], device='cuda:0')
#
# Epoch 103/500, loss_fit = 3231.56, encoder_loss = 1.16.
# var_u: tensor([1.0322], device='cuda:0'), phi: tensor([0.7939], device='cuda:0')
#
# Epoch 104/500, loss_fit = 2369.87, encoder_loss = 1.16.
# var_u: tensor([1.0308], device='cuda:0'), phi: tensor([0.7937], device='cuda:0')
#
# Epoch 105/500, loss_fit = 3346.65, encoder_loss = 1.16.
# var_u: tensor([1.0302], device='cuda:0'), phi: tensor([0.7942], device='cuda:0')
#
# Epoch 106/500, loss_fit = 2369.29, encoder_loss = 1.17.
# var_u: tensor([1.0294], device='cuda:0'), phi: tensor([0.7959], device='cuda:0')
#
# Epoch 107/500, loss_fit = 2995.89, encoder_loss = 1.17.
# var_u: tensor([1.0265], device='cuda:0'), phi: tensor([0.7975], device='cuda:0')
#
# Epoch 108/500, loss_fit = 3783.95, encoder_loss = 1.21.
# var_u: tensor([1.0261], device='cuda:0'), phi: tensor([0.7983], device='cuda:0')
#
# Epoch 109/500, loss_fit = 3367.70, encoder_loss = 1.18.
# var_u: tensor([1.0262], device='cuda:0'), phi: tensor([0.7978], device='cuda:0')
#
# Epoch 110/500, loss_fit = 2777.80, encoder_loss = 1.18.
# var_u: tensor([1.0261], device='cuda:0'), phi: tensor([0.7989], device='cuda:0')
#
# Epoch 111/500, loss_fit = 3415.24, encoder_loss = 1.16.
# var_u: tensor([1.0262], device='cuda:0'), phi: tensor([0.7987], device='cuda:0')
#
# Epoch 112/500, loss_fit = 4091.28, encoder_loss = 1.16.
# var_u: tensor([1.0252], device='cuda:0'), phi: tensor([0.7981], device='cuda:0')
#
# Epoch 113/500, loss_fit = 2514.16, encoder_loss = 1.17.
# var_u: tensor([1.0248], device='cuda:0'), phi: tensor([0.7990], device='cuda:0')
#
# Epoch 114/500, loss_fit = 2847.06, encoder_loss = 1.22.
# var_u: tensor([1.0237], device='cuda:0'), phi: tensor([0.7981], device='cuda:0')
#
# Epoch 115/500, loss_fit = 5463.36, encoder_loss = 1.20.
# var_u: tensor([1.0206], device='cuda:0'), phi: tensor([0.7990], device='cuda:0')
#
# Epoch 116/500, loss_fit = 3299.72, encoder_loss = 1.19.
# var_u: tensor([1.0199], device='cuda:0'), phi: tensor([0.7977], device='cuda:0')
#
# Epoch 117/500, loss_fit = 3178.43, encoder_loss = 1.16.
# var_u: tensor([1.0198], device='cuda:0'), phi: tensor([0.7972], device='cuda:0')
#
# Epoch 118/500, loss_fit = 2631.74, encoder_loss = 1.15.
# var_u: tensor([1.0206], device='cuda:0'), phi: tensor([0.7968], device='cuda:0')
#
# Epoch 119/500, loss_fit = 3230.62, encoder_loss = 1.15.
# var_u: tensor([1.0221], device='cuda:0'), phi: tensor([0.7970], device='cuda:0')
#
# Epoch 120/500, loss_fit = 2897.01, encoder_loss = 1.15.
# var_u: tensor([1.0234], device='cuda:0'), phi: tensor([0.7985], device='cuda:0')
#
# Epoch 121/500, loss_fit = 2151.62, encoder_loss = 1.15.
# var_u: tensor([1.0246], device='cuda:0'), phi: tensor([0.7987], device='cuda:0')
#
# Epoch 122/500, loss_fit = 2088.94, encoder_loss = 1.16.
# var_u: tensor([1.0236], device='cuda:0'), phi: tensor([0.7989], device='cuda:0')
#
# Epoch 123/500, loss_fit = 2140.18, encoder_loss = 1.15.
# var_u: tensor([1.0233], device='cuda:0'), phi: tensor([0.7991], device='cuda:0')
#
# Epoch 124/500, loss_fit = 2382.61, encoder_loss = 1.14.
# var_u: tensor([1.0236], device='cuda:0'), phi: tensor([0.7996], device='cuda:0')
#
# Epoch 125/500, loss_fit = 2264.70, encoder_loss = 1.13.
# var_u: tensor([1.0228], device='cuda:0'), phi: tensor([0.7997], device='cuda:0')
#
# Epoch 126/500, loss_fit = 2673.09, encoder_loss = 1.15.
# var_u: tensor([1.0227], device='cuda:0'), phi: tensor([0.7990], device='cuda:0')
#
# Epoch 127/500, loss_fit = 2691.05, encoder_loss = 1.17.
# var_u: tensor([1.0228], device='cuda:0'), phi: tensor([0.7989], device='cuda:0')
#
# Epoch 128/500, loss_fit = 2749.03, encoder_loss = 1.15.
# var_u: tensor([1.0217], device='cuda:0'), phi: tensor([0.8005], device='cuda:0')
#
# Epoch 129/500, loss_fit = 2651.39, encoder_loss = 1.13.
# var_u: tensor([1.0213], device='cuda:0'), phi: tensor([0.8003], device='cuda:0')
#
# Epoch 130/500, loss_fit = 3244.46, encoder_loss = 1.12.
# var_u: tensor([1.0202], device='cuda:0'), phi: tensor([0.8007], device='cuda:0')
#
# Epoch 131/500, loss_fit = 2085.50, encoder_loss = 1.12.
# var_u: tensor([1.0182], device='cuda:0'), phi: tensor([0.8017], device='cuda:0')
#
# Epoch 132/500, loss_fit = 2249.34, encoder_loss = 1.14.
# var_u: tensor([1.0167], device='cuda:0'), phi: tensor([0.8009], device='cuda:0')
#
# Epoch 133/500, loss_fit = 2513.55, encoder_loss = 1.20.
# var_u: tensor([1.0150], device='cuda:0'), phi: tensor([0.8016], device='cuda:0')
#
# Epoch 134/500, loss_fit = 3484.65, encoder_loss = 1.16.
# var_u: tensor([1.0142], device='cuda:0'), phi: tensor([0.8006], device='cuda:0')
#
# Epoch 135/500, loss_fit = 3439.86, encoder_loss = 1.14.
# var_u: tensor([1.0143], device='cuda:0'), phi: tensor([0.8004], device='cuda:0')
#
# Epoch 136/500, loss_fit = 3615.73, encoder_loss = 1.12.
# var_u: tensor([1.0134], device='cuda:0'), phi: tensor([0.8018], device='cuda:0')
#
# Epoch 137/500, loss_fit = 3075.85, encoder_loss = 1.13.
# var_u: tensor([1.0124], device='cuda:0'), phi: tensor([0.8018], device='cuda:0')
#
# Epoch 138/500, loss_fit = 2552.78, encoder_loss = 1.12.
# var_u: tensor([1.0130], device='cuda:0'), phi: tensor([0.8000], device='cuda:0')
#
# Epoch 139/500, loss_fit = 2317.95, encoder_loss = 1.12.
# var_u: tensor([1.0117], device='cuda:0'), phi: tensor([0.8008], device='cuda:0')
#
# Epoch 140/500, loss_fit = 2800.85, encoder_loss = 1.11.
# var_u: tensor([1.0106], device='cuda:0'), phi: tensor([0.8009], device='cuda:0')
#
# Epoch 141/500, loss_fit = 3035.56, encoder_loss = 1.11.
# var_u: tensor([1.0101], device='cuda:0'), phi: tensor([0.8015], device='cuda:0')
#
# Epoch 142/500, loss_fit = 2586.56, encoder_loss = 1.11.
# var_u: tensor([1.0087], device='cuda:0'), phi: tensor([0.8015], device='cuda:0')
#
# Epoch 143/500, loss_fit = 2684.75, encoder_loss = 1.10.
# var_u: tensor([1.0092], device='cuda:0'), phi: tensor([0.7998], device='cuda:0')
#
# Epoch 144/500, loss_fit = 2462.10, encoder_loss = 1.10.
# var_u: tensor([1.0089], device='cuda:0'), phi: tensor([0.8006], device='cuda:0')
#
# Epoch 145/500, loss_fit = 2479.06, encoder_loss = 1.10.
# var_u: tensor([1.0086], device='cuda:0'), phi: tensor([0.7991], device='cuda:0')
#
# Epoch 146/500, loss_fit = 2601.80, encoder_loss = 1.11.
# var_u: tensor([1.0106], device='cuda:0'), phi: tensor([0.7984], device='cuda:0')
#
# Epoch 147/500, loss_fit = 2770.02, encoder_loss = 1.12.
# var_u: tensor([1.0103], device='cuda:0'), phi: tensor([0.7989], device='cuda:0')
#
# Epoch 148/500, loss_fit = 2542.51, encoder_loss = 1.11.
# var_u: tensor([1.0097], device='cuda:0'), phi: tensor([0.8001], device='cuda:0')
#
# Epoch 149/500, loss_fit = 2700.83, encoder_loss = 1.11.
# var_u: tensor([1.0094], device='cuda:0'), phi: tensor([0.7994], device='cuda:0')
#
# Epoch 150/500, loss_fit = 2460.73, encoder_loss = 1.12.
# var_u: tensor([1.0098], device='cuda:0'), phi: tensor([0.7984], device='cuda:0')
#
# Epoch 151/500, loss_fit = 2664.20, encoder_loss = 1.11.
# var_u: tensor([1.0085], device='cuda:0'), phi: tensor([0.7970], device='cuda:0')
#
# Epoch 152/500, loss_fit = 2367.12, encoder_loss = 1.11.
# var_u: tensor([1.0081], device='cuda:0'), phi: tensor([0.7952], device='cuda:0')
#
# Epoch 153/500, loss_fit = 2555.55, encoder_loss = 1.10.
# var_u: tensor([1.0077], device='cuda:0'), phi: tensor([0.7959], device='cuda:0')
#
# Epoch 154/500, loss_fit = 2224.47, encoder_loss = 1.11.
# var_u: tensor([1.0073], device='cuda:0'), phi: tensor([0.7957], device='cuda:0')
#
# Epoch 155/500, loss_fit = 2312.36, encoder_loss = 1.12.
# var_u: tensor([1.0057], device='cuda:0'), phi: tensor([0.7960], device='cuda:0')
#
# Epoch 156/500, loss_fit = 2868.14, encoder_loss = 1.10.
# var_u: tensor([1.0054], device='cuda:0'), phi: tensor([0.7963], device='cuda:0')
#
# Epoch 157/500, loss_fit = 2516.56, encoder_loss = 1.10.
# var_u: tensor([1.0039], device='cuda:0'), phi: tensor([0.7961], device='cuda:0')
#
# Epoch 158/500, loss_fit = 2492.82, encoder_loss = 1.10.
# var_u: tensor([1.0037], device='cuda:0'), phi: tensor([0.7964], device='cuda:0')
#
# Epoch 159/500, loss_fit = 2557.09, encoder_loss = 1.12.
# var_u: tensor([1.0031], device='cuda:0'), phi: tensor([0.7978], device='cuda:0')
#
# Epoch 160/500, loss_fit = 2110.23, encoder_loss = 1.10.
# var_u: tensor([1.0029], device='cuda:0'), phi: tensor([0.7989], device='cuda:0')
#
# Epoch 161/500, loss_fit = 2469.76, encoder_loss = 1.11.
# var_u: tensor([1.0021], device='cuda:0'), phi: tensor([0.8002], device='cuda:0')
#
# Epoch 162/500, loss_fit = 2871.54, encoder_loss = 1.09.
# var_u: tensor([1.0018], device='cuda:0'), phi: tensor([0.8001], device='cuda:0')
#
# Epoch 163/500, loss_fit = 2499.90, encoder_loss = 1.10.
# var_u: tensor([1.0006], device='cuda:0'), phi: tensor([0.7989], device='cuda:0')
#
# Epoch 164/500, loss_fit = 2641.40, encoder_loss = 1.09.
# var_u: tensor([0.9993], device='cuda:0'), phi: tensor([0.7978], device='cuda:0')
#
# Epoch 165/500, loss_fit = 2948.45, encoder_loss = 1.10.
# var_u: tensor([0.9992], device='cuda:0'), phi: tensor([0.7963], device='cuda:0')
#
# Epoch 166/500, loss_fit = 2333.04, encoder_loss = 1.09.
# var_u: tensor([0.9983], device='cuda:0'), phi: tensor([0.7961], device='cuda:0')
#
# Epoch 167/500, loss_fit = 2999.80, encoder_loss = 1.09.
# var_u: tensor([0.9989], device='cuda:0'), phi: tensor([0.7967], device='cuda:0')
#
# Epoch 168/500, loss_fit = 2307.10, encoder_loss = 1.10.
# var_u: tensor([0.9991], device='cuda:0'), phi: tensor([0.7974], device='cuda:0')
#
# Epoch 169/500, loss_fit = 3007.87, encoder_loss = 1.11.
# var_u: tensor([0.9991], device='cuda:0'), phi: tensor([0.7975], device='cuda:0')
#
# Epoch 170/500, loss_fit = 2736.32, encoder_loss = 1.10.
# var_u: tensor([0.9988], device='cuda:0'), phi: tensor([0.7994], device='cuda:0')
#
# Epoch 171/500, loss_fit = 2125.75, encoder_loss = 1.10.
# var_u: tensor([0.9977], device='cuda:0'), phi: tensor([0.7994], device='cuda:0')
#
# Epoch 172/500, loss_fit = 2822.32, encoder_loss = 1.08.
# var_u: tensor([0.9963], device='cuda:0'), phi: tensor([0.7987], device='cuda:0')
#
# Epoch 173/500, loss_fit = 2734.14, encoder_loss = 1.08.
# var_u: tensor([0.9960], device='cuda:0'), phi: tensor([0.7981], device='cuda:0')
#
# Epoch 174/500, loss_fit = 2360.82, encoder_loss = 1.08.
# var_u: tensor([0.9970], device='cuda:0'), phi: tensor([0.7979], device='cuda:0')
#
# Epoch 175/500, loss_fit = 2591.47, encoder_loss = 1.08.
# var_u: tensor([0.9980], device='cuda:0'), phi: tensor([0.7984], device='cuda:0')
#
# Epoch 176/500, loss_fit = 2526.18, encoder_loss = 1.12.
# var_u: tensor([0.9970], device='cuda:0'), phi: tensor([0.7998], device='cuda:0')
#
# Epoch 177/500, loss_fit = 2901.01, encoder_loss = 1.13.
# var_u: tensor([0.9972], device='cuda:0'), phi: tensor([0.7998], device='cuda:0')
#
# Epoch 178/500, loss_fit = 3583.14, encoder_loss = 1.12.
# var_u: tensor([0.9971], device='cuda:0'), phi: tensor([0.7996], device='cuda:0')
#
# Epoch 179/500, loss_fit = 4185.85, encoder_loss = 1.10.
# var_u: tensor([0.9974], device='cuda:0'), phi: tensor([0.7997], device='cuda:0')
#
# Epoch 180/500, loss_fit = 2844.22, encoder_loss = 1.10.
# var_u: tensor([0.9966], device='cuda:0'), phi: tensor([0.7998], device='cuda:0')
#
# Epoch 181/500, loss_fit = 2806.25, encoder_loss = 1.09.
# var_u: tensor([0.9961], device='cuda:0'), phi: tensor([0.7994], device='cuda:0')
#
# Epoch 182/500, loss_fit = 2717.59, encoder_loss = 1.08.
# var_u: tensor([0.9951], device='cuda:0'), phi: tensor([0.7989], device='cuda:0')
#
# Epoch 183/500, loss_fit = 2513.94, encoder_loss = 1.06.
# var_u: tensor([0.9951], device='cuda:0'), phi: tensor([0.7975], device='cuda:0')
#
# Epoch 184/500, loss_fit = 2570.20, encoder_loss = 1.07.
# var_u: tensor([0.9952], device='cuda:0'), phi: tensor([0.7987], device='cuda:0')
#
# Epoch 185/500, loss_fit = 2257.81, encoder_loss = 1.09.
# var_u: tensor([0.9942], device='cuda:0'), phi: tensor([0.7983], device='cuda:0')
#
# Epoch 186/500, loss_fit = 2272.87, encoder_loss = 1.07.
# var_u: tensor([0.9939], device='cuda:0'), phi: tensor([0.7983], device='cuda:0')
#
# Epoch 187/500, loss_fit = 2511.41, encoder_loss = 1.07.
# var_u: tensor([0.9953], device='cuda:0'), phi: tensor([0.7983], device='cuda:0')
#
# Epoch 188/500, loss_fit = 2656.85, encoder_loss = 1.06.
# var_u: tensor([0.9958], device='cuda:0'), phi: tensor([0.7978], device='cuda:0')
#
# Epoch 189/500, loss_fit = 2732.62, encoder_loss = 1.06.
# var_u: tensor([0.9962], device='cuda:0'), phi: tensor([0.7973], device='cuda:0')
#
# Epoch 190/500, loss_fit = 3082.85, encoder_loss = 1.05.
# var_u: tensor([0.9968], device='cuda:0'), phi: tensor([0.7976], device='cuda:0')
#
# Epoch 191/500, loss_fit = 2591.26, encoder_loss = 1.07.
# var_u: tensor([0.9955], device='cuda:0'), phi: tensor([0.7984], device='cuda:0')
#
# Epoch 192/500, loss_fit = 2528.97, encoder_loss = 1.08.
# var_u: tensor([0.9937], device='cuda:0'), phi: tensor([0.7976], device='cuda:0')
#
# Epoch 193/500, loss_fit = 3093.61, encoder_loss = 1.05.
# var_u: tensor([0.9916], device='cuda:0'), phi: tensor([0.7977], device='cuda:0')
#
# Epoch 194/500, loss_fit = 2224.16, encoder_loss = 1.05.
# var_u: tensor([0.9913], device='cuda:0'), phi: tensor([0.7979], device='cuda:0')
#
# Epoch 195/500, loss_fit = 2255.85, encoder_loss = 1.06.
# var_u: tensor([0.9906], device='cuda:0'), phi: tensor([0.7993], device='cuda:0')
#
# Epoch 196/500, loss_fit = 2420.73, encoder_loss = 1.06.
# var_u: tensor([0.9896], device='cuda:0'), phi: tensor([0.7985], device='cuda:0')
#
# Epoch 197/500, loss_fit = 2722.27, encoder_loss = 1.09.
# var_u: tensor([0.9915], device='cuda:0'), phi: tensor([0.7988], device='cuda:0')
#
# Epoch 198/500, loss_fit = 2504.39, encoder_loss = 1.06.
# var_u: tensor([0.9907], device='cuda:0'), phi: tensor([0.7986], device='cuda:0')
#
# Epoch 199/500, loss_fit = 2665.29, encoder_loss = 1.07.
# var_u: tensor([0.9901], device='cuda:0'), phi: tensor([0.8000], device='cuda:0')
#
# Epoch 200/500, loss_fit = 2440.01, encoder_loss = 1.06.
# var_u: tensor([0.9896], device='cuda:0'), phi: tensor([0.8017], device='cuda:0')
#
# Epoch 201/500, loss_fit = 2528.78, encoder_loss = 1.06.
# var_u: tensor([0.9877], device='cuda:0'), phi: tensor([0.8006], device='cuda:0')
#
# Epoch 202/500, loss_fit = 2335.32, encoder_loss = 1.06.
# var_u: tensor([0.9885], device='cuda:0'), phi: tensor([0.8012], device='cuda:0')
#
# Epoch 203/500, loss_fit = 1941.92, encoder_loss = 1.06.
# var_u: tensor([0.9893], device='cuda:0'), phi: tensor([0.8000], device='cuda:0')
#
# Epoch 204/500, loss_fit = 1976.65, encoder_loss = 1.05.
# var_u: tensor([0.9894], device='cuda:0'), phi: tensor([0.7998], device='cuda:0')
#
# Epoch 205/500, loss_fit = 2426.36, encoder_loss = 1.06.
# var_u: tensor([0.9895], device='cuda:0'), phi: tensor([0.8004], device='cuda:0')
#
# Epoch 206/500, loss_fit = 2536.39, encoder_loss = 1.07.
# var_u: tensor([0.9902], device='cuda:0'), phi: tensor([0.7985], device='cuda:0')
#
# Epoch 207/500, loss_fit = 2226.77, encoder_loss = 1.06.
# var_u: tensor([0.9909], device='cuda:0'), phi: tensor([0.7990], device='cuda:0')
#
# Epoch 208/500, loss_fit = 2169.01, encoder_loss = 1.05.
# var_u: tensor([0.9910], device='cuda:0'), phi: tensor([0.7993], device='cuda:0')
#
# Epoch 209/500, loss_fit = 2604.05, encoder_loss = 1.05.
# var_u: tensor([0.9905], device='cuda:0'), phi: tensor([0.7992], device='cuda:0')
#
# Epoch 210/500, loss_fit = 1801.60, encoder_loss = 1.06.
# var_u: tensor([0.9897], device='cuda:0'), phi: tensor([0.7992], device='cuda:0')
#
# Epoch 211/500, loss_fit = 1855.21, encoder_loss = 1.05.
# var_u: tensor([0.9895], device='cuda:0'), phi: tensor([0.7997], device='cuda:0')
#
# Epoch 212/500, loss_fit = 2045.68, encoder_loss = 1.04.
# var_u: tensor([0.9895], device='cuda:0'), phi: tensor([0.8003], device='cuda:0')
#
# Epoch 213/500, loss_fit = 1925.38, encoder_loss = 1.06.
# var_u: tensor([0.9885], device='cuda:0'), phi: tensor([0.7994], device='cuda:0')
#
# Epoch 214/500, loss_fit = 2523.80, encoder_loss = 1.06.
# var_u: tensor([0.9876], device='cuda:0'), phi: tensor([0.7985], device='cuda:0')
#
# Epoch 215/500, loss_fit = 2745.67, encoder_loss = 1.05.
# var_u: tensor([0.9879], device='cuda:0'), phi: tensor([0.7980], device='cuda:0')
#
# Epoch 216/500, loss_fit = 2159.41, encoder_loss = 1.05.
# var_u: tensor([0.9869], device='cuda:0'), phi: tensor([0.7960], device='cuda:0')
#
# Epoch 217/500, loss_fit = 2528.37, encoder_loss = 1.08.
# var_u: tensor([0.9863], device='cuda:0'), phi: tensor([0.7975], device='cuda:0')
#
# Epoch 218/500, loss_fit = 2317.81, encoder_loss = 1.06.
# var_u: tensor([0.9847], device='cuda:0'), phi: tensor([0.7973], device='cuda:0')
#
# Epoch 219/500, loss_fit = 2974.05, encoder_loss = 1.04.
# var_u: tensor([0.9830], device='cuda:0'), phi: tensor([0.7978], device='cuda:0')
#
# Epoch 220/500, loss_fit = 2448.02, encoder_loss = 1.06.
# var_u: tensor([0.9827], device='cuda:0'), phi: tensor([0.7978], device='cuda:0')
#
# Epoch 221/500, loss_fit = 2523.58, encoder_loss = 1.05.
# var_u: tensor([0.9833], device='cuda:0'), phi: tensor([0.7972], device='cuda:0')
#
# Epoch 222/500, loss_fit = 2879.72, encoder_loss = 1.05.
# var_u: tensor([0.9839], device='cuda:0'), phi: tensor([0.7966], device='cuda:0')
#
# Epoch 223/500, loss_fit = 2535.26, encoder_loss = 1.05.
# var_u: tensor([0.9843], device='cuda:0'), phi: tensor([0.7979], device='cuda:0')
#
# Epoch 224/500, loss_fit = 3265.07, encoder_loss = 1.05.
# var_u: tensor([0.9856], device='cuda:0'), phi: tensor([0.7961], device='cuda:0')
#
# Epoch 225/500, loss_fit = 2653.59, encoder_loss = 1.05.
# var_u: tensor([0.9859], device='cuda:0'), phi: tensor([0.7969], device='cuda:0')
#
# Epoch 226/500, loss_fit = 2034.95, encoder_loss = 1.05.
# var_u: tensor([0.9844], device='cuda:0'), phi: tensor([0.7978], device='cuda:0')
#
# Epoch 227/500, loss_fit = 2548.25, encoder_loss = 1.05.
# var_u: tensor([0.9849], device='cuda:0'), phi: tensor([0.7975], device='cuda:0')
#
# Epoch 228/500, loss_fit = 2157.19, encoder_loss = 1.05.
# var_u: tensor([0.9846], device='cuda:0'), phi: tensor([0.7979], device='cuda:0')
#
# Epoch 229/500, loss_fit = 2598.22, encoder_loss = 1.04.
# var_u: tensor([0.9852], device='cuda:0'), phi: tensor([0.7984], device='cuda:0')
#
# Epoch 230/500, loss_fit = 2558.06, encoder_loss = 1.05.
# var_u: tensor([0.9837], device='cuda:0'), phi: tensor([0.7995], device='cuda:0')
#
# Epoch 231/500, loss_fit = 2550.08, encoder_loss = 1.05.
# var_u: tensor([0.9833], device='cuda:0'), phi: tensor([0.7999], device='cuda:0')
#
# Epoch 232/500, loss_fit = 2472.17, encoder_loss = 1.05.
# var_u: tensor([0.9843], device='cuda:0'), phi: tensor([0.7994], device='cuda:0')
#
# Epoch 233/500, loss_fit = 2368.50, encoder_loss = 1.05.
# var_u: tensor([0.9837], device='cuda:0'), phi: tensor([0.8011], device='cuda:0')
#
# Epoch 234/500, loss_fit = 2415.64, encoder_loss = 1.05.
# var_u: tensor([0.9839], device='cuda:0'), phi: tensor([0.8016], device='cuda:0')
#
# Epoch 235/500, loss_fit = 1959.01, encoder_loss = 1.06.
# var_u: tensor([0.9830], device='cuda:0'), phi: tensor([0.8013], device='cuda:0')
#
# Epoch 236/500, loss_fit = 2030.96, encoder_loss = 1.04.
# var_u: tensor([0.9825], device='cuda:0'), phi: tensor([0.7995], device='cuda:0')
#
# Epoch 237/500, loss_fit = 2827.25, encoder_loss = 1.04.
# var_u: tensor([0.9822], device='cuda:0'), phi: tensor([0.7990], device='cuda:0')
#
# Epoch 238/500, loss_fit = 2299.20, encoder_loss = 1.03.
# var_u: tensor([0.9832], device='cuda:0'), phi: tensor([0.7997], device='cuda:0')
#
# Epoch 239/500, loss_fit = 2422.05, encoder_loss = 1.03.
# var_u: tensor([0.9824], device='cuda:0'), phi: tensor([0.8014], device='cuda:0')
#
# Epoch 240/500, loss_fit = 2415.73, encoder_loss = 1.05.
# var_u: tensor([0.9819], device='cuda:0'), phi: tensor([0.8016], device='cuda:0')
#
# Epoch 241/500, loss_fit = 2410.90, encoder_loss = 1.03.
# var_u: tensor([0.9812], device='cuda:0'), phi: tensor([0.7996], device='cuda:0')
#
# Epoch 242/500, loss_fit = 2355.75, encoder_loss = 1.03.
# var_u: tensor([0.9815], device='cuda:0'), phi: tensor([0.7992], device='cuda:0')
#
# Epoch 243/500, loss_fit = 2994.22, encoder_loss = 1.03.
# var_u: tensor([0.9825], device='cuda:0'), phi: tensor([0.7991], device='cuda:0')
#
# Epoch 244/500, loss_fit = 2531.86, encoder_loss = 1.03.
# var_u: tensor([0.9820], device='cuda:0'), phi: tensor([0.7974], device='cuda:0')
#
# Epoch 245/500, loss_fit = 2246.60, encoder_loss = 1.02.
# var_u: tensor([0.9813], device='cuda:0'), phi: tensor([0.7993], device='cuda:0')
#
# Epoch 246/500, loss_fit = 1984.17, encoder_loss = 1.02.
# var_u: tensor([0.9801], device='cuda:0'), phi: tensor([0.8007], device='cuda:0')
#
# Epoch 247/500, loss_fit = 1888.25, encoder_loss = 1.03.
# var_u: tensor([0.9802], device='cuda:0'), phi: tensor([0.8009], device='cuda:0')
#
# Epoch 248/500, loss_fit = 1992.91, encoder_loss = 1.02.
# var_u: tensor([0.9794], device='cuda:0'), phi: tensor([0.8012], device='cuda:0')
#
# Epoch 249/500, loss_fit = 1738.43, encoder_loss = 1.03.
# var_u: tensor([0.9788], device='cuda:0'), phi: tensor([0.8010], device='cuda:0')
#
# Epoch 250/500, loss_fit = 1876.61, encoder_loss = 1.02.
# var_u: tensor([0.9799], device='cuda:0'), phi: tensor([0.8001], device='cuda:0')
#
# Epoch 251/500, loss_fit = 2087.42, encoder_loss = 1.02.
# var_u: tensor([0.9796], device='cuda:0'), phi: tensor([0.7997], device='cuda:0')
#
# Epoch 252/500, loss_fit = 1878.74, encoder_loss = 1.01.
# var_u: tensor([0.9814], device='cuda:0'), phi: tensor([0.7992], device='cuda:0')
#
# Epoch 253/500, loss_fit = 1817.43, encoder_loss = 1.01.
# var_u: tensor([0.9806], device='cuda:0'), phi: tensor([0.8005], device='cuda:0')
#
# Epoch 254/500, loss_fit = 1634.07, encoder_loss = 1.03.
# var_u: tensor([0.9804], device='cuda:0'), phi: tensor([0.8004], device='cuda:0')
#
# Epoch 255/500, loss_fit = 1496.06, encoder_loss = 1.04.
# var_u: tensor([0.9822], device='cuda:0'), phi: tensor([0.8010], device='cuda:0')
#
# Epoch 256/500, loss_fit = 1644.98, encoder_loss = 1.02.
# var_u: tensor([0.9838], device='cuda:0'), phi: tensor([0.8011], device='cuda:0')
#
# Epoch 257/500, loss_fit = 1551.49, encoder_loss = 1.00.
# var_u: tensor([0.9828], device='cuda:0'), phi: tensor([0.8009], device='cuda:0')
#
# Epoch 258/500, loss_fit = 2242.82, encoder_loss = 1.01.
# var_u: tensor([0.9832], device='cuda:0'), phi: tensor([0.7999], device='cuda:0')
#
# Epoch 259/500, loss_fit = 2876.67, encoder_loss = 1.03.
# var_u: tensor([0.9828], device='cuda:0'), phi: tensor([0.7987], device='cuda:0')
#
# Epoch 260/500, loss_fit = 2299.85, encoder_loss = 1.01.
# var_u: tensor([0.9825], device='cuda:0'), phi: tensor([0.7996], device='cuda:0')
#
# Epoch 261/500, loss_fit = 2125.69, encoder_loss = 1.00.
# var_u: tensor([0.9818], device='cuda:0'), phi: tensor([0.7987], device='cuda:0')
#
# Epoch 262/500, loss_fit = 1883.97, encoder_loss = 1.00.
# var_u: tensor([0.9817], device='cuda:0'), phi: tensor([0.7980], device='cuda:0')
#
# Epoch 263/500, loss_fit = 1787.74, encoder_loss = 1.00.
# var_u: tensor([0.9808], device='cuda:0'), phi: tensor([0.7989], device='cuda:0')
#
# Epoch 264/500, loss_fit = 1990.91, encoder_loss = 0.99.
# var_u: tensor([0.9802], device='cuda:0'), phi: tensor([0.7994], device='cuda:0')
#
# Epoch 265/500, loss_fit = 1805.71, encoder_loss = 1.00.
# var_u: tensor([0.9798], device='cuda:0'), phi: tensor([0.7988], device='cuda:0')
#
# Epoch 266/500, loss_fit = 2243.02, encoder_loss = 0.99.
# var_u: tensor([0.9808], device='cuda:0'), phi: tensor([0.7999], device='cuda:0')
#
# Epoch 267/500, loss_fit = 1910.68, encoder_loss = 1.00.
# var_u: tensor([0.9814], device='cuda:0'), phi: tensor([0.7999], device='cuda:0')
#
# Epoch 268/500, loss_fit = 2109.78, encoder_loss = 0.99.
# var_u: tensor([0.9799], device='cuda:0'), phi: tensor([0.7984], device='cuda:0')
#
# Epoch 269/500, loss_fit = 1650.80, encoder_loss = 1.02.
# var_u: tensor([0.9801], device='cuda:0'), phi: tensor([0.7994], device='cuda:0')
#
# Epoch 270/500, loss_fit = 1914.11, encoder_loss = 0.99.
# var_u: tensor([0.9798], device='cuda:0'), phi: tensor([0.7985], device='cuda:0')
#
# Epoch 271/500, loss_fit = 1804.10, encoder_loss = 1.00.
# var_u: tensor([0.9789], device='cuda:0'), phi: tensor([0.7995], device='cuda:0')
#
# Epoch 272/500, loss_fit = 1717.97, encoder_loss = 0.99.
# var_u: tensor([0.9790], device='cuda:0'), phi: tensor([0.7994], device='cuda:0')
#
# Epoch 273/500, loss_fit = 2070.64, encoder_loss = 0.99.
# var_u: tensor([0.9799], device='cuda:0'), phi: tensor([0.7999], device='cuda:0')
#
# Epoch 274/500, loss_fit = 2233.36, encoder_loss = 1.00.
# var_u: tensor([0.9807], device='cuda:0'), phi: tensor([0.7998], device='cuda:0')
#
# Epoch 275/500, loss_fit = 2280.48, encoder_loss = 1.03.
# var_u: tensor([0.9807], device='cuda:0'), phi: tensor([0.8012], device='cuda:0')
#
# Epoch 276/500, loss_fit = 1687.11, encoder_loss = 1.00.
# var_u: tensor([0.9807], device='cuda:0'), phi: tensor([0.8018], device='cuda:0')
#
# Epoch 277/500, loss_fit = 1931.11, encoder_loss = 1.00.
# var_u: tensor([0.9797], device='cuda:0'), phi: tensor([0.8020], device='cuda:0')
#
# Epoch 278/500, loss_fit = 2260.05, encoder_loss = 0.99.
# var_u: tensor([0.9797], device='cuda:0'), phi: tensor([0.8031], device='cuda:0')
#
# Epoch 279/500, loss_fit = 2072.74, encoder_loss = 0.98.
# var_u: tensor([0.9795], device='cuda:0'), phi: tensor([0.8035], device='cuda:0')
#
# Epoch 280/500, loss_fit = 1914.61, encoder_loss = 0.98.
# var_u: tensor([0.9790], device='cuda:0'), phi: tensor([0.8033], device='cuda:0')
#
# Epoch 281/500, loss_fit = 2314.58, encoder_loss = 0.98.
# var_u: tensor([0.9786], device='cuda:0'), phi: tensor([0.8024], device='cuda:0')
#
# Epoch 282/500, loss_fit = 1907.97, encoder_loss = 0.99.
# var_u: tensor([0.9786], device='cuda:0'), phi: tensor([0.8017], device='cuda:0')
#
# Epoch 283/500, loss_fit = 2269.54, encoder_loss = 0.98.
# var_u: tensor([0.9795], device='cuda:0'), phi: tensor([0.7995], device='cuda:0')
#
# Epoch 284/500, loss_fit = 1894.69, encoder_loss = 0.98.
# var_u: tensor([0.9799], device='cuda:0'), phi: tensor([0.8007], device='cuda:0')
#
# Epoch 285/500, loss_fit = 1915.16, encoder_loss = 0.99.
# var_u: tensor([0.9796], device='cuda:0'), phi: tensor([0.8023], device='cuda:0')
#
# Epoch 286/500, loss_fit = 1781.12, encoder_loss = 1.03.
# var_u: tensor([0.9802], device='cuda:0'), phi: tensor([0.8030], device='cuda:0')
#
# Epoch 287/500, loss_fit = 2500.44, encoder_loss = 1.01.
# var_u: tensor([0.9804], device='cuda:0'), phi: tensor([0.8042], device='cuda:0')
#
# Epoch 288/500, loss_fit = 1730.00, encoder_loss = 0.99.
# var_u: tensor([0.9805], device='cuda:0'), phi: tensor([0.8034], device='cuda:0')
#
# Epoch 289/500, loss_fit = 1893.85, encoder_loss = 0.99.
# var_u: tensor([0.9814], device='cuda:0'), phi: tensor([0.8023], device='cuda:0')
#
# Epoch 290/500, loss_fit = 1924.95, encoder_loss = 0.99.
# var_u: tensor([0.9823], device='cuda:0'), phi: tensor([0.8019], device='cuda:0')
#
# Epoch 291/500, loss_fit = 2244.59, encoder_loss = 0.99.
# var_u: tensor([0.9817], device='cuda:0'), phi: tensor([0.8024], device='cuda:0')
#
# Epoch 292/500, loss_fit = 1987.93, encoder_loss = 0.99.
# var_u: tensor([0.9813], device='cuda:0'), phi: tensor([0.8011], device='cuda:0')
#
# Epoch 293/500, loss_fit = 2264.94, encoder_loss = 0.99.
# var_u: tensor([0.9807], device='cuda:0'), phi: tensor([0.8014], device='cuda:0')
#
# Epoch 294/500, loss_fit = 2146.36, encoder_loss = 1.01.
# var_u: tensor([0.9815], device='cuda:0'), phi: tensor([0.8010], device='cuda:0')
#
# Epoch 295/500, loss_fit = 2267.97, encoder_loss = 1.00.
# var_u: tensor([0.9832], device='cuda:0'), phi: tensor([0.8016], device='cuda:0')
#
# Epoch 296/500, loss_fit = 1988.30, encoder_loss = 0.99.
# var_u: tensor([0.9834], device='cuda:0'), phi: tensor([0.8007], device='cuda:0')
#
# Epoch 297/500, loss_fit = 2064.60, encoder_loss = 0.98.
# var_u: tensor([0.9827], device='cuda:0'), phi: tensor([0.8003], device='cuda:0')
#
# Epoch 298/500, loss_fit = 2175.66, encoder_loss = 0.98.
# var_u: tensor([0.9830], device='cuda:0'), phi: tensor([0.7990], device='cuda:0')
#
# Epoch 299/500, loss_fit = 1999.18, encoder_loss = 0.99.
# var_u: tensor([0.9820], device='cuda:0'), phi: tensor([0.8001], device='cuda:0')
#
# Epoch 300/500, loss_fit = 2054.43, encoder_loss = 0.99.
# var_u: tensor([0.9819], device='cuda:0'), phi: tensor([0.7994], device='cuda:0')
#
# Epoch 301/500, loss_fit = 2410.89, encoder_loss = 0.99.
# var_u: tensor([0.9823], device='cuda:0'), phi: tensor([0.8009], device='cuda:0')
#
# Epoch 302/500, loss_fit = 2261.21, encoder_loss = 0.98.
# var_u: tensor([0.9823], device='cuda:0'), phi: tensor([0.8013], device='cuda:0')
#
# Epoch 303/500, loss_fit = 2194.92, encoder_loss = 0.99.
# var_u: tensor([0.9819], device='cuda:0'), phi: tensor([0.8002], device='cuda:0')
#
# Epoch 304/500, loss_fit = 2230.99, encoder_loss = 0.98.
# var_u: tensor([0.9809], device='cuda:0'), phi: tensor([0.7995], device='cuda:0')
#
# Epoch 305/500, loss_fit = 2091.37, encoder_loss = 0.99.
# var_u: tensor([0.9822], device='cuda:0'), phi: tensor([0.7996], device='cuda:0')
#
# Epoch 306/500, loss_fit = 2289.25, encoder_loss = 0.99.
# var_u: tensor([0.9818], device='cuda:0'), phi: tensor([0.8000], device='cuda:0')
#
# Epoch 307/500, loss_fit = 2048.85, encoder_loss = 0.99.
# var_u: tensor([0.9803], device='cuda:0'), phi: tensor([0.8001], device='cuda:0')
#
# Epoch 308/500, loss_fit = 2250.52, encoder_loss = 0.98.
# var_u: tensor([0.9800], device='cuda:0'), phi: tensor([0.8001], device='cuda:0')
#
# Epoch 309/500, loss_fit = 2417.20, encoder_loss = 0.97.
# var_u: tensor([0.9806], device='cuda:0'), phi: tensor([0.8004], device='cuda:0')
#
# Epoch 310/500, loss_fit = 2366.58, encoder_loss = 1.00.
# var_u: tensor([0.9812], device='cuda:0'), phi: tensor([0.8006], device='cuda:0')
#
# Epoch 311/500, loss_fit = 2084.80, encoder_loss = 0.97.
# var_u: tensor([0.9813], device='cuda:0'), phi: tensor([0.8015], device='cuda:0')
#
# Epoch 312/500, loss_fit = 2413.65, encoder_loss = 0.97.
# var_u: tensor([0.9819], device='cuda:0'), phi: tensor([0.8031], device='cuda:0')
#
# Epoch 313/500, loss_fit = 2052.48, encoder_loss = 0.99.
# var_u: tensor([0.9816], device='cuda:0'), phi: tensor([0.8041], device='cuda:0')
#
# Epoch 314/500, loss_fit = 2089.80, encoder_loss = 0.98.
# var_u: tensor([0.9821], device='cuda:0'), phi: tensor([0.8047], device='cuda:0')
#
# Epoch 315/500, loss_fit = 2185.01, encoder_loss = 0.97.
# var_u: tensor([0.9813], device='cuda:0'), phi: tensor([0.8031], device='cuda:0')
#
# Epoch 316/500, loss_fit = 1925.11, encoder_loss = 0.98.
# var_u: tensor([0.9819], device='cuda:0'), phi: tensor([0.8042], device='cuda:0')
#
# Epoch 317/500, loss_fit = 2411.33, encoder_loss = 0.96.
# var_u: tensor([0.9806], device='cuda:0'), phi: tensor([0.8039], device='cuda:0')
#
# Epoch 318/500, loss_fit = 2525.69, encoder_loss = 0.97.
# var_u: tensor([0.9801], device='cuda:0'), phi: tensor([0.8022], device='cuda:0')
#
# Epoch 319/500, loss_fit = 2221.78, encoder_loss = 0.99.
# var_u: tensor([0.9797], device='cuda:0'), phi: tensor([0.8014], device='cuda:0')
#
# Epoch 320/500, loss_fit = 2680.05, encoder_loss = 0.99.
# var_u: tensor([0.9802], device='cuda:0'), phi: tensor([0.8012], device='cuda:0')
#
# Epoch 321/500, loss_fit = 2893.42, encoder_loss = 0.97.
# var_u: tensor([0.9799], device='cuda:0'), phi: tensor([0.8016], device='cuda:0')
#
# Epoch 322/500, loss_fit = 2459.81, encoder_loss = 0.97.
# var_u: tensor([0.9799], device='cuda:0'), phi: tensor([0.8034], device='cuda:0')
#
# Epoch 323/500, loss_fit = 2557.16, encoder_loss = 0.97.
# var_u: tensor([0.9799], device='cuda:0'), phi: tensor([0.8018], device='cuda:0')
#
# Epoch 324/500, loss_fit = 2755.23, encoder_loss = 0.96.
# var_u: tensor([0.9791], device='cuda:0'), phi: tensor([0.8017], device='cuda:0')
#
# Epoch 325/500, loss_fit = 2894.28, encoder_loss = 0.96.
# var_u: tensor([0.9790], device='cuda:0'), phi: tensor([0.8033], device='cuda:0')
#
# Epoch 326/500, loss_fit = 2837.40, encoder_loss = 0.96.
# var_u: tensor([0.9794], device='cuda:0'), phi: tensor([0.8036], device='cuda:0')
#
# Epoch 327/500, loss_fit = 2455.13, encoder_loss = 0.96.
# var_u: tensor([0.9790], device='cuda:0'), phi: tensor([0.8015], device='cuda:0')
#
# Epoch 328/500, loss_fit = 2072.31, encoder_loss = 0.97.
# var_u: tensor([0.9784], device='cuda:0'), phi: tensor([0.8005], device='cuda:0')
#
# Epoch 329/500, loss_fit = 2836.23, encoder_loss = 0.97.
# var_u: tensor([0.9772], device='cuda:0'), phi: tensor([0.8004], device='cuda:0')
#
# Epoch 330/500, loss_fit = 2840.34, encoder_loss = 0.95.
# var_u: tensor([0.9769], device='cuda:0'), phi: tensor([0.8002], device='cuda:0')
#
# Epoch 331/500, loss_fit = 2393.88, encoder_loss = 0.95.
# var_u: tensor([0.9768], device='cuda:0'), phi: tensor([0.7994], device='cuda:0')
#
# Epoch 332/500, loss_fit = 2356.85, encoder_loss = 0.95.
# var_u: tensor([0.9776], device='cuda:0'), phi: tensor([0.8001], device='cuda:0')
#
# Epoch 333/500, loss_fit = 2287.58, encoder_loss = 0.96.
# var_u: tensor([0.9781], device='cuda:0'), phi: tensor([0.8000], device='cuda:0')
#
# Epoch 334/500, loss_fit = 2859.82, encoder_loss = 0.97.
# var_u: tensor([0.9785], device='cuda:0'), phi: tensor([0.8007], device='cuda:0')
#
# Epoch 335/500, loss_fit = 2722.86, encoder_loss = 0.96.
# var_u: tensor([0.9798], device='cuda:0'), phi: tensor([0.8004], device='cuda:0')
#
# Epoch 336/500, loss_fit = 2509.78, encoder_loss = 0.96.
# var_u: tensor([0.9813], device='cuda:0'), phi: tensor([0.8014], device='cuda:0')
#
# Epoch 337/500, loss_fit = 2615.92, encoder_loss = 0.96.
# var_u: tensor([0.9795], device='cuda:0'), phi: tensor([0.8005], device='cuda:0')
#
# Epoch 338/500, loss_fit = 2672.64, encoder_loss = 0.96.
# var_u: tensor([0.9811], device='cuda:0'), phi: tensor([0.8015], device='cuda:0')
#
# Epoch 339/500, loss_fit = 2599.66, encoder_loss = 0.96.
# var_u: tensor([0.9815], device='cuda:0'), phi: tensor([0.8018], device='cuda:0')
#
# Epoch 340/500, loss_fit = 2382.16, encoder_loss = 0.95.
# var_u: tensor([0.9813], device='cuda:0'), phi: tensor([0.8022], device='cuda:0')
#
# Epoch 341/500, loss_fit = 2375.14, encoder_loss = 0.96.
# var_u: tensor([0.9811], device='cuda:0'), phi: tensor([0.8017], device='cuda:0')
#
# Epoch 342/500, loss_fit = 2778.83, encoder_loss = 0.95.
# var_u: tensor([0.9806], device='cuda:0'), phi: tensor([0.8022], device='cuda:0')
#
# Epoch 343/500, loss_fit = 2387.08, encoder_loss = 0.94.
# var_u: tensor([0.9811], device='cuda:0'), phi: tensor([0.8021], device='cuda:0')
#
# Epoch 344/500, loss_fit = 2321.67, encoder_loss = 0.96.
# var_u: tensor([0.9805], device='cuda:0'), phi: tensor([0.8020], device='cuda:0')
#
# Epoch 345/500, loss_fit = 2522.97, encoder_loss = 0.95.
# var_u: tensor([0.9819], device='cuda:0'), phi: tensor([0.8010], device='cuda:0')
#
# Epoch 346/500, loss_fit = 2467.15, encoder_loss = 0.95.
# var_u: tensor([0.9814], device='cuda:0'), phi: tensor([0.8016], device='cuda:0')
#
# Epoch 347/500, loss_fit = 1964.28, encoder_loss = 0.95.
# var_u: tensor([0.9814], device='cuda:0'), phi: tensor([0.8001], device='cuda:0')
#
# Epoch 348/500, loss_fit = 2018.05, encoder_loss = 0.98.
# ...
#
# Epoch 385/500, loss_fit = 1984.25, encoder_loss = 0.95.
# var_u: tensor([0.9828], device='cuda:0'), phi: tensor([0.8002], device='cuda:0')
#
# Epoch 386/500, loss_fit = 1954.04, encoder_loss = 0.95.
# var_u: tensor([0.9829], device='cuda:0'), phi: tensor([0.8009], device='cuda:0')
#
# Epoch 387/500, loss_fit = 1812.50, encoder_loss = 0.95.
# var_u: tensor([0.9831], device='cuda:0'), phi: tensor([0.8019], device='cuda:0')
#
# Epoch 388/500, loss_fit = 2010.80, encoder_loss = 0.96.
# var_u: tensor([0.9834], device='cuda:0'), phi: tensor([0.8025], device='cuda:0')
#
# Epoch 389/500, loss_fit = 2269.60, encoder_loss = 0.95.
# var_u: tensor([0.9832], device='cuda:0'), phi: tensor([0.8023], device='cuda:0')
#
# Epoch 390/500, loss_fit = 2242.71, encoder_loss = 0.96.
# var_u: tensor([0.9832], device='cuda:0'), phi: tensor([0.8007], device='cuda:0')
#
# Epoch 391/500, loss_fit = 1880.80, encoder_loss = 0.95.
# var_u: tensor([0.9834], device='cuda:0'), phi: tensor([0.7997], device='cuda:0')
#
# Epoch 392/500, loss_fit = 2046.02, encoder_loss = 0.96.
# var_u: tensor([0.9822], device='cuda:0'), phi: tensor([0.8004], device='cuda:0')
#
# Epoch 393/500, loss_fit = 2061.41, encoder_loss = 0.95.
# var_u: tensor([0.9818], device='cuda:0'), phi: tensor([0.8015], device='cuda:0')
#
# Epoch 394/500, loss_fit = 2226.73, encoder_loss = 0.95.
# var_u: tensor([0.9801], device='cuda:0'), phi: tensor([0.8010], device='cuda:0')
#
# Epoch 395/500, loss_fit = 2307.75, encoder_loss = 0.96.
# var_u: tensor([0.9801], device='cuda:0'), phi: tensor([0.8008], device='cuda:0')
#
# Epoch 396/500, loss_fit = 2374.26, encoder_loss = 0.96.
# var_u: tensor([0.9806], device='cuda:0'), phi: tensor([0.8001], device='cuda:0')
#
# Epoch 397/500, loss_fit = 2126.01, encoder_loss = 0.96.
# var_u: tensor([0.9800], device='cuda:0'), phi: tensor([0.7982], device='cuda:0')
#
# Epoch 398/500, loss_fit = 2099.23, encoder_loss = 0.97.
# var_u: tensor([0.9804], device='cuda:0'), phi: tensor([0.7992], device='cuda:0')
#
# Epoch 399/500, loss_fit = 2324.89, encoder_loss = 0.95.
# var_u: tensor([0.9816], device='cuda:0'), phi: tensor([0.7999], device='cuda:0')
#
# Epoch 400/500, loss_fit = 2085.75, encoder_loss = 0.95.
# var_u: tensor([0.9821], device='cuda:0'), phi: tensor([0.7993], device='cuda:0')
#
# Epoch 401/500, loss_fit = 2060.65, encoder_loss = 0.95.
# var_u: tensor([0.9825], device='cuda:0'), phi: tensor([0.8000], device='cuda:0')
#
# Epoch 402/500, loss_fit = 2154.78, encoder_loss = 0.95.
# var_u: tensor([0.9815], device='cuda:0'), phi: tensor([0.8013], device='cuda:0')
#
# Epoch 403/500, loss_fit = 2013.45, encoder_loss = 0.95.
# var_u: tensor([0.9817], device='cuda:0'), phi: tensor([0.8021], device='cuda:0')
#
# Epoch 404/500, loss_fit = 2331.06, encoder_loss = 0.95.
# var_u: tensor([0.9823], device='cuda:0'), phi: tensor([0.8017], device='cuda:0')
#
# Epoch 405/500, loss_fit = 2582.07, encoder_loss = 0.94.
# var_u: tensor([0.9827], device='cuda:0'), phi: tensor([0.8019], device='cuda:0')
#
# Epoch 406/500, loss_fit = 2230.05, encoder_loss = 0.95.
# var_u: tensor([0.9842], device='cuda:0'), phi: tensor([0.8012], device='cuda:0')
#
# Epoch 407/500, loss_fit = 2281.96, encoder_loss = 0.95.
# var_u: tensor([0.9839], device='cuda:0'), phi: tensor([0.8029], device='cuda:0')
#
# Epoch 408/500, loss_fit = 2355.79, encoder_loss = 0.96.
# var_u: tensor([0.9833], device='cuda:0'), phi: tensor([0.8013], device='cuda:0')
#
# Epoch 409/500, loss_fit = 2257.63, encoder_loss = 0.95.
# var_u: tensor([0.9830], device='cuda:0'), phi: tensor([0.8009], device='cuda:0')
#
# Epoch 410/500, loss_fit = 2200.20, encoder_loss = 0.95.
# var_u: tensor([0.9842], device='cuda:0'), phi: tensor([0.8021], device='cuda:0')
#
# Epoch 411/500, loss_fit = 1953.10, encoder_loss = 0.94.
# var_u: tensor([0.9845], device='cuda:0'), phi: tensor([0.8039], device='cuda:0')
#
# Epoch 412/500, loss_fit = 2209.28, encoder_loss = 0.95.
# var_u: tensor([0.9831], device='cuda:0'), phi: tensor([0.8044], device='cuda:0')
#
# Epoch 413/500, loss_fit = 2164.50, encoder_loss = 0.98.
# var_u: tensor([0.9836], device='cuda:0'), phi: tensor([0.8037], device='cuda:0')
#
# Epoch 414/500, loss_fit = 1855.27, encoder_loss = 0.97.
# var_u: tensor([0.9837], device='cuda:0'), phi: tensor([0.8032], device='cuda:0')
#
# Epoch 415/500, loss_fit = 1968.50, encoder_loss = 0.96.
# var_u: tensor([0.9839], device='cuda:0'), phi: tensor([0.8034], device='cuda:0')
#
# Epoch 416/500, loss_fit = 2141.58, encoder_loss = 0.96.
# var_u: tensor([0.9844], device='cuda:0'), phi: tensor([0.8039], device='cuda:0')
#
# Epoch 417/500, loss_fit = 2394.40, encoder_loss = 0.96.
# var_u: tensor([0.9836], device='cuda:0'), phi: tensor([0.8037], device='cuda:0')
#
# Epoch 418/500, loss_fit = 2229.95, encoder_loss = 0.94.
# var_u: tensor([0.9836], device='cuda:0'), phi: tensor([0.8055], device='cuda:0')
#
# Epoch 419/500, loss_fit = 2208.56, encoder_loss = 0.94.
# var_u: tensor([0.9850], device='cuda:0'), phi: tensor([0.8063], device='cuda:0')
#
# Epoch 420/500, loss_fit = 1817.92, encoder_loss = 0.96.
# var_u: tensor([0.9847], device='cuda:0'), phi: tensor([0.8060], device='cuda:0')
#
# Epoch 421/500, loss_fit = 1955.91, encoder_loss = 0.95.
# var_u: tensor([0.9841], device='cuda:0'), phi: tensor([0.8049], device='cuda:0')
#
# Epoch 422/500, loss_fit = 2507.45, encoder_loss = 0.96.
# var_u: tensor([0.9836], device='cuda:0'), phi: tensor([0.8045], device='cuda:0')
#
# Epoch 423/500, loss_fit = 2344.24, encoder_loss = 0.96.
# var_u: tensor([0.9839], device='cuda:0'), phi: tensor([0.8029], device='cuda:0')
#
# Epoch 424/500, loss_fit = 2138.55, encoder_loss = 0.95.
# var_u: tensor([0.9835], device='cuda:0'), phi: tensor([0.8030], device='cuda:0')
#
# Epoch 425/500, loss_fit = 2070.64, encoder_loss = 0.95.
# var_u: tensor([0.9841], device='cuda:0'), phi: tensor([0.8016], device='cuda:0')
#
# Epoch 426/500, loss_fit = 2017.00, encoder_loss = 0.95.
# var_u: tensor([0.9844], device='cuda:0'), phi: tensor([0.8013], device='cuda:0')
#
# Epoch 427/500, loss_fit = 1899.93, encoder_loss = 0.94.
# var_u: tensor([0.9848], device='cuda:0'), phi: tensor([0.8017], device='cuda:0')
#
# Epoch 428/500, loss_fit = 1957.82, encoder_loss = 0.95.
# var_u: tensor([0.9852], device='cuda:0'), phi: tensor([0.8019], device='cuda:0')
#
# Epoch 429/500, loss_fit = 2031.11, encoder_loss = 0.95.
# var_u: tensor([0.9847], device='cuda:0'), phi: tensor([0.8006], device='cuda:0')
#
# Epoch 430/500, loss_fit = 2183.22, encoder_loss = 0.96.
# var_u: tensor([0.9860], device='cuda:0'), phi: tensor([0.8009], device='cuda:0')
#
# Epoch 431/500, loss_fit = 1793.83, encoder_loss = 0.98.
# var_u: tensor([0.9869], device='cuda:0'), phi: tensor([0.8004], device='cuda:0')
#
# Epoch 432/500, loss_fit = 2194.55, encoder_loss = 0.95.
# var_u: tensor([0.9871], device='cuda:0'), phi: tensor([0.8006], device='cuda:0')
#
# Epoch 433/500, loss_fit = 1664.02, encoder_loss = 0.96.
# var_u: tensor([0.9863], device='cuda:0'), phi: tensor([0.8012], device='cuda:0')
#
# Epoch 434/500, loss_fit = 2023.40, encoder_loss = 0.95.
# var_u: tensor([0.9850], device='cuda:0'), phi: tensor([0.8020], device='cuda:0')
#
# Epoch 435/500, loss_fit = 2137.32, encoder_loss = 0.95.
# var_u: tensor([0.9844], device='cuda:0'), phi: tensor([0.8021], device='cuda:0')
#
# Epoch 436/500, loss_fit = 1738.43, encoder_loss = 0.94.
# var_u: tensor([0.9834], device='cuda:0'), phi: tensor([0.8023], device='cuda:0')
#
# Epoch 437/500, loss_fit = 2073.68, encoder_loss = 0.95.
# var_u: tensor([0.9834], device='cuda:0'), phi: tensor([0.8003], device='cuda:0')
#
# Epoch 438/500, loss_fit = 2008.02, encoder_loss = 0.95.
# var_u: tensor([0.9831], device='cuda:0'), phi: tensor([0.8000], device='cuda:0')
#
# Epoch 439/500, loss_fit = 2179.15, encoder_loss = 0.95.
# var_u: tensor([0.9832], device='cuda:0'), phi: tensor([0.8009], device='cuda:0')
#
# Epoch 440/500, loss_fit = 2134.68, encoder_loss = 0.96.
# var_u: tensor([0.9843], device='cuda:0'), phi: tensor([0.7988], device='cuda:0')
#
# Epoch 441/500, loss_fit = 2105.91, encoder_loss = 0.95.
# var_u: tensor([0.9840], device='cuda:0'), phi: tensor([0.7973], device='cuda:0')
#
# Epoch 442/500, loss_fit = 2130.52, encoder_loss = 0.96.
# var_u: tensor([0.9850], device='cuda:0'), phi: tensor([0.7978], device='cuda:0')
#
# Epoch 443/500, loss_fit = 1846.93, encoder_loss = 0.95.
# var_u: tensor([0.9848], device='cuda:0'), phi: tensor([0.7974], device='cuda:0')
#
# Epoch 444/500, loss_fit = 1896.73, encoder_loss = 0.95.
# var_u: tensor([0.9847], device='cuda:0'), phi: tensor([0.7985], device='cuda:0')
#
# Epoch 445/500, loss_fit = 2040.35, encoder_loss = 0.95.
# var_u: tensor([0.9848], device='cuda:0'), phi: tensor([0.7992], device='cuda:0')
#
# Epoch 446/500, loss_fit = 2417.82, encoder_loss = 0.94.
# var_u: tensor([0.9850], device='cuda:0'), phi: tensor([0.7991], device='cuda:0')
#
# Epoch 447/500, loss_fit = 2200.38, encoder_loss = 0.95.
# var_u: tensor([0.9845], device='cuda:0'), phi: tensor([0.7995], device='cuda:0')
#
# Epoch 448/500, loss_fit = 2186.00, encoder_loss = 0.95.
# var_u: tensor([0.9841], device='cuda:0'), phi: tensor([0.7984], device='cuda:0')
#
# Epoch 449/500, loss_fit = 2302.35, encoder_loss = 0.94.
# var_u: tensor([0.9844], device='cuda:0'), phi: tensor([0.7982], device='cuda:0')
#
# Epoch 450/500, loss_fit = 1944.23, encoder_loss = 0.95.
# var_u: tensor([0.9846], device='cuda:0'), phi: tensor([0.7977], device='cuda:0')
#
# Epoch 451/500, loss_fit = 1687.49, encoder_loss = 0.95.
# var_u: tensor([0.9838], device='cuda:0'), phi: tensor([0.7993], device='cuda:0')
#
# Epoch 452/500, loss_fit = 1858.13, encoder_loss = 0.95.
# var_u: tensor([0.9831], device='cuda:0'), phi: tensor([0.7982], device='cuda:0')
#
# Epoch 453/500, loss_fit = 2030.65, encoder_loss = 0.94.
# var_u: tensor([0.9827], device='cuda:0'), phi: tensor([0.7982], device='cuda:0')
#
# Epoch 454/500, loss_fit = 2649.82, encoder_loss = 0.94.
# var_u: tensor([0.9834], device='cuda:0'), phi: tensor([0.7985], device='cuda:0')
#
# Epoch 455/500, loss_fit = 2093.48, encoder_loss = 0.95.
# var_u: tensor([0.9850], device='cuda:0'), phi: tensor([0.7995], device='cuda:0')
#
# Epoch 456/500, loss_fit = 2124.56, encoder_loss = 0.94.
# var_u: tensor([0.9843], device='cuda:0'), phi: tensor([0.7989], device='cuda:0')
#
# Epoch 457/500, loss_fit = 1916.20, encoder_loss = 0.94.
# var_u: tensor([0.9845], device='cuda:0'), phi: tensor([0.7987], device='cuda:0')
#
# Epoch 458/500, loss_fit = 2110.64, encoder_loss = 0.94.
# var_u: tensor([0.9843], device='cuda:0'), phi: tensor([0.7996], device='cuda:0')
#
# Epoch 459/500, loss_fit = 1879.26, encoder_loss = 0.95.
# var_u: tensor([0.9854], device='cuda:0'), phi: tensor([0.8004], device='cuda:0')
#
# Epoch 460/500, loss_fit = 1829.28, encoder_loss = 0.94.
# var_u: tensor([0.9853], device='cuda:0'), phi: tensor([0.8011], device='cuda:0')
#
# Epoch 461/500, loss_fit = 1929.14, encoder_loss = 0.94.
# var_u: tensor([0.9850], device='cuda:0'), phi: tensor([0.8018], device='cuda:0')
#
# Epoch 462/500, loss_fit = 1908.09, encoder_loss = 0.94.
# var_u: tensor([0.9850], device='cuda:0'), phi: tensor([0.8008], device='cuda:0')
#
# Epoch 463/500, loss_fit = 1918.38, encoder_loss = 0.95.
# var_u: tensor([0.9849], device='cuda:0'), phi: tensor([0.8007], device='cuda:0')
#
# Epoch 464/500, loss_fit = 1861.97, encoder_loss = 0.95.
# var_u: tensor([0.9851], device='cuda:0'), phi: tensor([0.8000], device='cuda:0')
#
# Epoch 465/500, loss_fit = 1942.69, encoder_loss = 0.94.
# var_u: tensor([0.9856], device='cuda:0'), phi: tensor([0.8000], device='cuda:0')
#
# Epoch 466/500, loss_fit = 1801.68, encoder_loss = 0.94.
# var_u: tensor([0.9857], device='cuda:0'), phi: tensor([0.8005], device='cuda:0')
#
# Epoch 467/500, loss_fit = 1769.60, encoder_loss = 0.94.
# var_u: tensor([0.9854], device='cuda:0'), phi: tensor([0.7988], device='cuda:0')
#
# Epoch 468/500, loss_fit = 1920.70, encoder_loss = 0.94.
# var_u: tensor([0.9852], device='cuda:0'), phi: tensor([0.7992], device='cuda:0')
#
# Epoch 469/500, loss_fit = 1735.36, encoder_loss = 0.94.
# var_u: tensor([0.9847], device='cuda:0'), phi: tensor([0.8019], device='cuda:0')
#
# Epoch 470/500, loss_fit = 2152.16, encoder_loss = 0.93.
# var_u: tensor([0.9843], device='cuda:0'), phi: tensor([0.8024], device='cuda:0')
#
# Epoch 471/500, loss_fit = 2092.28, encoder_loss = 0.93.
# var_u: tensor([0.9840], device='cuda:0'), phi: tensor([0.8020], device='cuda:0')
#
# Epoch 472/500, loss_fit = 1882.57, encoder_loss = 0.93.
# var_u: tensor([0.9835], device='cuda:0'), phi: tensor([0.8037], device='cuda:0')
#
# Epoch 473/500, loss_fit = 1881.89, encoder_loss = 0.94.
# var_u: tensor([0.9837], device='cuda:0'), phi: tensor([0.8024], device='cuda:0')
#
# Epoch 474/500, loss_fit = 1914.07, encoder_loss = 0.94.
# var_u: tensor([0.9832], device='cuda:0'), phi: tensor([0.8025], device='cuda:0')
#
# Epoch 475/500, loss_fit = 1920.99, encoder_loss = 0.93.
# var_u: tensor([0.9835], device='cuda:0'), phi: tensor([0.8012], device='cuda:0')
#
# Epoch 476/500, loss_fit = 1945.53, encoder_loss = 0.94.
# var_u: tensor([0.9830], device='cuda:0'), phi: tensor([0.7999], device='cuda:0')
#
# Epoch 477/500, loss_fit = 1710.05, encoder_loss = 0.93.
# var_u: tensor([0.9834], device='cuda:0'), phi: tensor([0.8005], device='cuda:0')
#
# Epoch 478/500, loss_fit = 1723.67, encoder_loss = 0.95.
# var_u: tensor([0.9834], device='cuda:0'), phi: tensor([0.8000], device='cuda:0')
#
# Epoch 479/500, loss_fit = 1802.61, encoder_loss = 0.94.
# var_u: tensor([0.9833], device='cuda:0'), phi: tensor([0.7990], device='cuda:0')
#
# Epoch 480/500, loss_fit = 1987.30, encoder_loss = 0.94.
# var_u: tensor([0.9835], device='cuda:0'), phi: tensor([0.8000], device='cuda:0')
#
# Epoch 481/500, loss_fit = 1985.77, encoder_loss = 0.94.
# var_u: tensor([0.9831], device='cuda:0'), phi: tensor([0.7998], device='cuda:0')
#
# Epoch 482/500, loss_fit = 1879.94, encoder_loss = 0.94.
# var_u: tensor([0.9823], device='cuda:0'), phi: tensor([0.8012], device='cuda:0')
#
# Epoch 483/500, loss_fit = 1666.60, encoder_loss = 0.94.
# var_u: tensor([0.9811], device='cuda:0'), phi: tensor([0.8022], device='cuda:0')
#
# Epoch 484/500, loss_fit = 1948.95, encoder_loss = 0.94.
# var_u: tensor([0.9815], device='cuda:0'), phi: tensor([0.8010], device='cuda:0')
#
# Epoch 485/500, loss_fit = 1489.30, encoder_loss = 0.94.
# var_u: tensor([0.9814], device='cuda:0'), phi: tensor([0.8015], device='cuda:0')
#
# Epoch 486/500, loss_fit = 2021.15, encoder_loss = 0.94.
# var_u: tensor([0.9825], device='cuda:0'), phi: tensor([0.8031], device='cuda:0')
#
# Epoch 487/500, loss_fit = 1793.92, encoder_loss = 0.93.
# var_u: tensor([0.9824], device='cuda:0'), phi: tensor([0.8023], device='cuda:0')
#
# Epoch 488/500, loss_fit = 1941.94, encoder_loss = 0.94.
# var_u: tensor([0.9832], device='cuda:0'), phi: tensor([0.8022], device='cuda:0')
#
# Epoch 489/500, loss_fit = 1777.39, encoder_loss = 0.94.
# var_u: tensor([0.9851], device='cuda:0'), phi: tensor([0.8025], device='cuda:0')
#
# Epoch 490/500, loss_fit = 1846.07, encoder_loss = 0.94.
# var_u: tensor([0.9857], device='cuda:0'), phi: tensor([0.8024], device='cuda:0')
#
# Epoch 491/500, loss_fit = 1746.73, encoder_loss = 0.94.
# var_u: tensor([0.9864], device='cuda:0'), phi: tensor([0.8028], device='cuda:0')
#
# Epoch 492/500, loss_fit = 1675.27, encoder_loss = 0.94.
# var_u: tensor([0.9859], device='cuda:0'), phi: tensor([0.8026], device='cuda:0')
#
# Epoch 493/500, loss_fit = 1858.47, encoder_loss = 0.94.
# var_u: tensor([0.9858], device='cuda:0'), phi: tensor([0.8012], device='cuda:0')
#
# Epoch 494/500, loss_fit = 1868.41, encoder_loss = 0.95.
# var_u: tensor([0.9872], device='cuda:0'), phi: tensor([0.8011], device='cuda:0')
#
# Epoch 495/500, loss_fit = 1587.49, encoder_loss = 0.94.
# var_u: tensor([0.9870], device='cuda:0'), phi: tensor([0.8014], device='cuda:0')
#
# Epoch 496/500, loss_fit = 1349.81, encoder_loss = 0.95.
# var_u: tensor([0.9862], device='cuda:0'), phi: tensor([0.8005], device='cuda:0')
#
# Epoch 497/500, loss_fit = 1882.65, encoder_loss = 0.94.
# var_u: tensor([0.9869], device='cuda:0'), phi: tensor([0.8021], device='cuda:0')
#
# Epoch 498/500, loss_fit = 2019.15, encoder_loss = 0.94.
# var_u: tensor([0.9874], device='cuda:0'), phi: tensor([0.8002], device='cuda:0')
#
# Epoch 499/500, loss_fit = 1885.25, encoder_loss = 0.96.
# var_u: tensor([0.9881], device='cuda:0'), phi: tensor([0.8007], device='cuda:0')
#
# Epoch 500/500, loss_fit = 1992.33, encoder_loss = 0.95.

# %%
plt.plot(learning_rates)
plt.plot(learning_rates_encoder)

# %%
data = np.stack([tensor.flatten().cpu().numpy() for tensor in param_values], axis=0)


# Create figure and axes
fig, ax = plt.subplots()

# Loop through each feature
for i in range(data.shape[1]):
    ax.plot(data[:, i])

# Add legend and labels
ax.legend()
plt.xlabel('Time period')
plt.ylabel('Feature value')
plt.title('Evolution of features over time')

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(model_sample.decoder.wz.detach().cpu().numpy(), model.decoder.wz.detach().cpu().numpy())
plt.plot([-3,3], [-3,3], color="red")
plt.plot([-3,3], [3,-3], color="red")
plt.show()

plt.scatter(model_sample.decoder.wx.detach().cpu().numpy(), model.decoder.wx.detach().cpu().numpy())
plt.plot([-3,3], [-3,3], color="red")
plt.plot([-3,3], [3,-3], color="red")
plt.show()

# %%
dat1 = torch.reshape(model_sample.sample(x=data_sample['x'])['y'].detach().cpu(), (data_sample['y'].shape[0], -1))
cor1 = np.corrcoef(dat1, rowvar=False)
dat2 = torch.reshape(model.sample(x=data_sample['x'])['y'].detach().cpu(), (data_sample['y'].shape[0], -1))
cor2 = np.corrcoef(dat2, rowvar=False)

plt.scatter(cor1, cor2)
plt.show()
